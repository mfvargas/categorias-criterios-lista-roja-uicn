# %% [markdown]
# # Categorías y criterios de la Lista Roja de la UICN

# %% [markdown]
# Este [Jupyter Notebook](https://jupyter.org/), desarrollado en el lenguaje de programación [Python](https://www.python.org/), aplica las categorías y criterios de la [Lista Roja de la Unión Internacional para la Conservación de la Naturaleza (UICN)](https://www.iucnredlist.org/es/).

# %% [markdown]
# **Entradas**
# - Un archivo CSV con nombres científicos de especies.
# - Las especificadas en la sección de **Constantes**.
#
# **Procesamiento**
# - Se obtienen las llaves (*keys*) de las especies en el [API de GBIF](https://www.gbif.org/developer/summary).
# - En caso de ser necesario, se filtran las llaves (ej. se conservan solo las de nombres que tengan coincidencia exacta o solo las de nombres aceptados).
# - Con base en la lista de llaves, se construye una consulta para el [portal de GBIF](https://www.gbif.org/).
# - El archivo CSV retornado por el portal se descarga y se renombra con el valor de la constante OCCURRENCES_CSV.
# - Se recorre el archivo CSV para generar las salidas que se describen seguidamente.
#
# **Salidas**
# Para cada especie en la lista de entrada, se genera:
# - Un archivo CSV con los registros de presencia.
# - Un mapa interactivo de distribución basado en los registros de presencia.
# - Un mapa interactivo de registros de presencia agrupados (_clustered_).
# - Un registro en otro archivo CSV, que resume los resultados de la evaluación, con las siguientes columnas:
#   - La extensión de presencia de la especie.
#   - El área de ocupación de la especie.
#   - La altitud mínima y la altitud máxima en las que la especie ha sido reportada.
#   - La lista de países en los que está presente la especie.
#   - La lista de áreas protegidas en las que está presente la especie.
#   - Los enlaces a los otros mapas y archivos.

# %% [markdown]
# **Bibliotecas de Python**

# %%
import requests
import json
import io

import csv

import pandas as pd
import geopandas as gpd
import numpy as np
from scipy.spatial import ConvexHull

import folium
from folium import plugins

import fiona
from shapely.geometry import shape, Point

from pyproj import Proj, transform

import matplotlib.pyplot as plt
# %matplotlib inline

import calendar

# El siguiente archivo debe estar en el mismo directorio que este notebook
from functions_query_from_species_list import *

# %% [markdown]
# **Constantes**

# %%
# Credenciales para el API de GBIF
GBIF_USER_NAME = "usuario"
GBIF_PASSWORD = "clave"
GBIF_NOTIFICATION_ADDRESSES = "email"
GBIF_DOWNLOAD_FORMAT = "SIMPLE_CSV"

# Proyecciones cartográficas para los cálculos de EOO y AOO
INPUT_PROJECTION = Proj(init='epsg:4326')
OUTPUT_PROJECTION = Proj(init='epsg:3857')

# Límites y dimensiones de la cuadrícula para el cálculo del AOO.
# Deben especificarse en las unidades del sistema espacial de referencia (SRS) que se utiliza.
# Por ejemplo, para el caso de Web Mercator (EPSG:3857), deben especificarse en metros.
# Límites de la cuadrícula
AOO_GRID_X_MIN = -15000000
AOO_GRID_X_MAX = -4000000
AOO_GRID_Y_MIN = -7000000
AOO_GRID_Y_MAX = 7000000
# Dimensiones de la cuadrícula
AOO_GRID_CELL_X_WIDTH = 2000
AOO_GRID_CELL_Y_WIDTH = 2000
AOO_GRID_CELL_AREA = AOO_GRID_CELL_X_WIDTH * AOO_GRID_CELL_Y_WIDTH

# Directorio de entrada
INPUT_DIR = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/"

# Archivo CSV de entrada con lista de especies a procesar
INPUT_CHECKLIST = INPUT_DIR + "Abutilon_purpusii-Zygia_rubiginosa-20191101-lista-especies.csv"
# Columna con el nombre científico de la especie
INPUT_SCINAME_COL = "Taxon Name"

# Archivo CSV con registros de presencia
OCCURRENCES_CSV = INPUT_DIR + "Abutilon_purpusii-Zygia_rubiginosa-20191101-registros-presencia.csv"

# Archivo CSV con especies del archivo de entrada que no se procesan
INPUT_CHECKLIST_NON_PROCESSED = INPUT_DIR + "Abutilon_purpusii-Zygia_rubiginosa-20191101-lista-especies-no-procesadas.csv"

# Directorio de salida
OUTPUT_DIR = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abutilon_purpusii-Zygia_rubiginosa-20191101/"
# Archivo CSV de salida
OUTPUT_CSV = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abutilon_purpusii-Zygia_rubiginosa-20191101-evaluacion.csv"
# Archivo HTML de salida
OUTPUT_HTML = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abutilon_purpusii-Zygia_rubiginosa-20191101-evaluacion.html"
# URL de salida
OUTPUT_BASE_URL_MAP = "https://evaluacion-arboles-mesoamerica.github.io/Abutilon_purpusii-Zygia_rubiginosa-20191101/"
OUTPUT_BASE_URL_CSV = "https://github.com/evaluacion-arboles-mesoamerica/Abutilon_purpusii-Zygia_rubiginosa-20191101/blob/master/"

# Capa geoespacial de áreas protegidas
PROTECTED_AREAS_LAYER = "C:/Users/mfvargas/geodatos/wdpa/WDPA_Mesoamerica.shp"

# Número máximo de registros a desplegar en los dataframes de Pandas
pd.options.display.max_rows = 15

# %% [markdown]
# ## Carga de datos

# %%
# Carga del archivo CSV de entrada en un dataframe de Pandas
input_species_df = pd.read_csv(INPUT_CHECKLIST, encoding='utf_8')

input_species_df
# Out:
#             Family            Genus         Species  \
# 0        MALVACEAE         Abutilon        purpusii
# 1    EUPHORBIACEAE         Acalypha      ferdinandi
# 2        LAMIACEAE        Aegiphila      panamensis
# 3        LAURACEAE           Aiouea        brenesii
# 4        LAURACEAE           Aiouea    chavarrianum
# 5        LAURACEAE           Aiouea     neurophylla
# 6        LAURACEAE           Aiouea         obscura
# ..             ...              ...             ...
# 492      LAURACEAE  Williamodendron   glaucophyllum
# 493   CELASTRACEAE         Wimmeria         sternii
# 494   CELASTRACEAE       Zinowiewia   costaricensis
# 495       FABACEAE            Zygia        brenesii
# 496       FABACEAE            Zygia         confusa
# 497       FABACEAE            Zygia  gigantifoliola
# 498       FABACEAE            Zygia      rubiginosa
#
#                         Taxon Name
# 0                Abutilon purpusii
# 1              Acalypha ferdinandi
# 2             Aegiphila panamensis
# 3                  Aiouea brenesii
# 4              Aiouea chavarrianum
# 5               Aiouea neurophylla
# 6                   Aiouea obscura
# ..                             ...
# 492  Williamodendron glaucophyllum
# 493               Wimmeria sternii
# 494       Zinowiewia costaricensis
# 495                 Zygia brenesii
# 496                  Zygia confusa
# 497           Zygia gigantifoliola
# 498               Zygia rubiginosa
#
# [499 rows x 4 columns]

# %% [markdown]
# Se consulta el API de GBIF para obtener las llaves (*keys*) de las especies

# %%
# Se obtienen las llaves de las especies a través del API de GBIF
gbif_species_df = match_species(input_species_df, INPUT_SCINAME_COL)

gbif_species_df[['inputName', 'species', 'genus', 'family', 'matchType', 'status', 'synonym', 'speciesKey', 'usageKey', 'rank', 'alternatives']]
# Out:
#                          inputName                        species  \
# 0                Abutilon purpusii            Callianthe purpusii
# 1              Acalypha ferdinandi            Acalypha ferdinandi
# 2             Aegiphila panamensis           Aegiphila panamensis
# 3                  Aiouea brenesii                Aiouea brenesii
# 4              Aiouea chavarrianum             Aiouea chavarriana
# 5               Aiouea neurophylla             Aiouea neurophylla
# 6                   Aiouea obscura                 Aiouea obscura
# ..                             ...                            ...
# 492  Williamodendron glaucophyllum  Williamodendron glaucophyllum
# 493               Wimmeria sternii               Wimmeria sternii
# 494       Zinowiewia costaricensis         Zinowiewia integerrima
# 495                 Zygia brenesii                 Zygia brenesii
# 496                  Zygia confusa                  Zygia confusa
# 497           Zygia gigantifoliola           Zygia gigantifoliola
# 498               Zygia rubiginosa               Zygia rubiginosa
#
#                genus         family matchType    status  synonym  speciesKey  \
# 0         Callianthe      Malvaceae     EXACT   SYNONYM     True     8418086
# 1           Acalypha  Euphorbiaceae     EXACT  ACCEPTED    False     7276169
# 2          Aegiphila      Lamiaceae     EXACT  ACCEPTED    False     3891222
# 3             Aiouea      Lauraceae     EXACT  ACCEPTED    False     9665460
# 4             Aiouea      Lauraceae     FUZZY  ACCEPTED    False     9695833
# 5             Aiouea      Lauraceae     EXACT  ACCEPTED    False     9810051
# 6             Aiouea      Lauraceae     EXACT  ACCEPTED    False     4183412
# ..               ...            ...       ...       ...      ...         ...
# 492  Williamodendron      Lauraceae     EXACT  ACCEPTED    False    10657507
# 493         Wimmeria   Celastraceae     EXACT  ACCEPTED    False     3790969
# 494       Zinowiewia   Celastraceae     EXACT   SYNONYM     True     3790814
# 495            Zygia       Fabaceae     EXACT  ACCEPTED    False     5347427
# 496            Zygia       Fabaceae     EXACT  ACCEPTED    False     5347439
# 497            Zygia       Fabaceae     EXACT  ACCEPTED    False     5347424
# 498            Zygia       Fabaceae     EXACT  ACCEPTED    False     5347461
#
#      usageKey     rank                                       alternatives
# 0     3936341  SPECIES                                               NULL
# 1     7276169  SPECIES                                               NULL
# 2     3891222  SPECIES  [{'usageKey': 3891182, 'scientificName': 'Aegi...
# 3     9665460  SPECIES                                               NULL
# 4     9695833  SPECIES                                               NULL
# 5     9810051  SPECIES                                               NULL
# 6     4183412  SPECIES  [{'usageKey': 2358012, 'acceptedUsageKey': 520...
# ..        ...      ...                                                ...
# 492  10657507  SPECIES  [{'usageKey': 4181354, 'scientificName': 'Will...
# 493   3790969  SPECIES                                               NULL
# 494   3790861  SPECIES                                               NULL
# 495   5347427  SPECIES                                               NULL
# 496   5347439  SPECIES                                               NULL
# 497   5347424  SPECIES  [{'usageKey': 5347368, 'acceptedUsageKey': 534...
# 498   5347461  SPECIES  [{'usageKey': 7995395, 'scientificName': 'Zygi...
#
# [499 rows x 11 columns]

# %%
# Se construye una lista de nombres excluídos por no ser aceptados o con coincidencia no exacta
gbif_species_df = gbif_species_df[['inputName', 'species', 'genus', 'family', 'matchType', 'status', 'synonym', 'speciesKey', 'usageKey', 'rank', 'alternatives']]
gbif_species_non_processed_df = gbif_species_df.loc[~((gbif_species_df["matchType"]=="EXACT") & (gbif_species_df["status"]=="ACCEPTED"))]

gbif_species_non_processed_df.to_csv(INPUT_CHECKLIST_NON_PROCESSED)

# %%
# Se separa la lista de llaves

# Se filtran las llaves (en caso de ser necesario)
gbif_species_df = gbif_species_df.loc[(gbif_species_df["matchType"]=="EXACT") & (gbif_species_df["status"]=="ACCEPTED")]
key_list = gbif_species_df.usageKey.tolist()

key_list
# Out:
# [7276169,
#  3891222,
#  9665460,
#  9810051,
#  4183412,
#  9700381,
#  9744148,
#  2738670,
#  3796445,
#  4205554,
#  4094049,
#  4094040,
#  5558134,
#  5558011,
#  5557693,
#  5557608,
#  5557440,
#  5557397,
#  5558831,
#  5558457,
#  5558632,
#  5558559,
#  5558476,
#  7331075,
#  5558442,
#  5557750,
#  5557482,
#  5558709,
#  5558656,
#  7331093,
#  5557619,
#  5557514,
#  5557395,
#  5558834,
#  2738123,
#  2738088,
#  2738130,
#  5361723,
#  5601145,
#  2733338,
#  2733340,
#  2733382,
#  2732907,
#  2733373,
#  2732932,
#  3939568,
#  3134409,
#  4176975,
#  4175787,
#  4182861,
#  3980937,
#  3982161,
#  7644896,
#  5600561,
#  5600487,
#  5600384,
#  8093189,
#  5600039,
#  4063410,
#  4063171,
#  4063146,
#  4062683,
#  5643499,
#  5643531,
#  8251755,
#  3983656,
#  3983502,
#  3983329,
#  3982960,
#  3982935,
#  3982927,
#  3982919,
#  3994195,
#  3994069,
#  3985798,
#  2981941,
#  2982318,
#  4180183,
#  4073280,
#  2734403,
#  5555705,
#  3718164,
#  3718137,
#  7914410,
#  5555512,
#  5556030,
#  5555891,
#  5555861,
#  3073647,
#  2981360,
#  2736925,
#  3859866,
#  9474434,
#  9602788,
#  9602206,
#  9260728,
#  9335482,
#  9331413,
#  9580671,
#  3859150,
#  9597927,
#  3858910,
#  3858861,
#  9397013,
#  3858686,
#  3932205,
#  5662457,
#  5661693,
#  7322007,
#  8784468,
#  9214504,
#  8928847,
#  3083111,
#  3083108,
#  3082562,
#  2959354,
#  3871414,
#  5580288,
#  5580184,
#  3059876,
#  3058795,
#  3060276,
#  3058314,
#  3058892,
#  3058571,
#  3059563,
#  3059365,
#  3059644,
#  3058469,
#  3060010,
#  3060296,
#  2731948,
#  2731932,
#  2731924,
#  3722388,
#  9326856,
#  9290106,
#  9458122,
#  3035205,
#  3035162,
#  3035053,
#  3035192,
#  3035040,
#  4195865,
#  4195830,
#  4195813,
#  4195721,
#  4195690,
#  4071026,
#  5357264,
#  2968242,
#  5349573,
#  5349520,
#  5349657,
#  5349762,
#  4161406,
#  4161390,
#  3083214,
#  3083215,
#  3083407,
#  4161402,
#  3083418,
#  3083417,
#  3083352,
#  3083357,
#  5571209,
#  5571043,
#  5570340,
#  5571745,
#  3033026,
#  2734302,
#  2734229,
#  2734051,
#  2734052,
#  3849951,
#  3852751,
#  3852684,
#  8392036,
#  3851874,
#  3851471,
#  3850481,
#  3850402,
#  3850011,
#  3849902,
#  3849888,
#  3852953,
#  5383823,
#  7279624,
#  8397006,
#  3139463,
#  3750566,
#  3685430,
#  3685355,
#  2985213,
#  2985184,
#  2985197,
#  2985100,
#  4073178,
#  3831036,
#  3830822,
#  8303726,
#  5534036,
#  5534548,
#  5534472,
#  5533815,
#  5534080,
#  2971796,
#  5357901,
#  5357703,
#  5357614,
#  5357981,
#  5357785,
#  5357897,
#  5357510,
#  5357845,
#  5357875,
#  5357861,
#  5357595,
#  5357750,
#  5357544,
#  5357539,
#  3072745,
#  3119954,
#  3145047,
#  3144979,
#  3145039,
#  3617666,
#  3189382,
#  3082427,
#  3082391,
#  5357468,
#  3088906,
#  2970407,
#  8876662,
#  2985292,
#  2985471,
#  2985532,
#  2985254,
#  2985366,
#  2985476,
#  2985406,
#  9479823,
#  2985533,
#  2985270,
#  4183098,
#  4182940,
#  4182571,
#  4182457,
#  4182099,
#  4181893,
#  4181615,
#  8032520,
#  2969121,
#  2969126,
#  2969071,
#  2969106,
#  3908528,
#  2969088,
#  2969231,
#  3908297,
#  2969109,
#  7354262,
#  5634536,
#  5355119,
#  5354908,
#  5355082,
#  3621126,
#  3841088,
#  3840383,
#  4260447,
#  2948910,
#  2948876,
#  2948880,
#  7285012,
#  8020309,
#  2984748,
#  7963111,
#  4073497,
#  3793051,
#  3792911,
#  5599769,
#  5599677,
#  5599647,
#  7314445,
#  3860400,
#  7652663,
#  7661217,
#  3858763,
#  3871060,
#  3870266,
#  3869499,
#  3869047,
#  3868274,
#  7810489,
#  3867582,
#  7790289,
#  5938715,
#  7557909,
#  3859299,
#  3867517,
#  3865158,
#  3864099,
#  3863108,
#  3702593,
#  8350277,
#  3782931,
#  5355421,
#  5355420,
#  4259362,
#  4259343,
#  4261941,
#  3870789,
#  3870112,
#  3869754,
#  3722100,
#  7262846,
#  3767014,
#  5685205,
#  5686016,
#  4177448,
#  4176940,
#  4176675,
#  4181369,
#  4181065,
#  7928563,
#  4180552,
#  4180162,
#  4179723,
#  4179270,
#  4178429,
#  4178294,
#  4178202,
#  4177086,
#  4176741,
#  4176657,
#  4176462,
#  4176394,
#  4176240,
#  4183409,
#  4183195,
#  4182239,
#  4181592,
#  4181156,
#  3596797,
#  4205518,
#  3036743,
#  3036754,
#  3036602,
#  3036528,
#  6307010,
#  3036755,
#  3036648,
#  3036542,
#  5629990,
#  5355604,
#  3743798,
#  4073616,
#  2959530,
#  3719269,
#  3723184,
#  3723012,
#  3722904,
#  3722763,
#  3722731,
#  3722563,
#  2984969,
#  5668542,
#  2952734,
#  4073351,
#  7429495,
#  4176621,
#  4175861,
#  4181364,
#  4180281,
#  4178767,
#  9444565,
#  2962799,
#  2962812,
#  2962814,
#  3912400,
#  5685782,
#  5685770,
#  5685765,
#  5685763,
#  5685722,
#  8466001,
#  5685688,
#  4019672,
#  9249370,
#  9488623,
#  9417439,
#  3993834,
#  3993721,
#  3668189,
#  8278028,
#  4073480,
#  4073321,
#  4073153,
#  4073820,
#  4073802,
#  4073797,
#  4073788,
#  3794588,
#  5294718,
#  7278781,
#  5660276,
#  5380009,
#  3038090,
#  3038213,
#  3038725,
#  3037796,
#  3038409,
#  3038452,
#  3038458,
#  3038540,
#  3038453,
#  2957923,
#  2957366,
#  5651100,
#  5651028,
#  9317427,
#  9434514,
#  5651236,
#  5651224,
#  5651190,
#  8580218,
#  5651146,
#  5651319,
#  5651191,
#  3984599,
#  4195742,
#  4195655,
#  5645566,
#  3913358,
#  3912612,
#  5630316,
#  5351889,
#  8366960,
#  7463839,
#  3190484,
#  4092106,
#  7425200,
#  7661037,
#  8180584,
#  2945191,
#  3698942,
#  9275822,
#  3062900,
#  3062915,
#  3152207,
#  3862208,
#  4065279,
#  3992709,
#  3190491,
#  3852028,
#  4261066,
#  3766623,
#  2943400,
#  7328886,
#  3795442,
#  3147875,
#  3152848,
#  3881425,
#  3613565,
#  7333908,
#  3613444,
#  3934887,
#  3934868,
#  3934830,
#  10657507,
#  3790969,
#  5347427,
#  5347439,
#  5347424,
#  5347461]

# %% [markdown]
# Se construye una consulta para descarga en el portal de GBIF

# %%
# Se construye una consulta para descarga en el portal de GBIF
download_query = {}
download_query["creator"] = GBIF_USER_NAME
download_query["notificationAddresses"] = [GBIF_NOTIFICATION_ADDRESSES]
download_query["sendNotification"] = True
download_query["format"] = GBIF_DOWNLOAD_FORMAT
download_query["predicate"] =   {"type":"and", "predicates": 
                                 [
                                    {"type":"equals", "key":"HAS_COORDINATE",       "value":"true"},
                                    {"type":"equals", "key":"HAS_GEOSPATIAL_ISSUE", "value":"false"}, 
                                    {"type":"in",     "key": "TAXON_KEY",           "values":key_list}
                                 ]
                                }

download_query
# Out:
# {'creator': 'mvargas',
#  'notificationAddresses': ['mvargas@inbio.ac.cr'],
#  'sendNotification': True,
#  'format': 'SIMPLE_CSV',
#  'predicate': {'type': 'and',
#   'predicates': [{'type': 'equals', 'key': 'HAS_COORDINATE', 'value': 'true'},
#    {'type': 'equals', 'key': 'HAS_GEOSPATIAL_ISSUE', 'value': 'false'},
#    {'type': 'in',
#     'key': 'TAXON_KEY',
#     'values': [7276169,
#      3891222,
#      9665460,
#      9810051,
#      4183412,
#      9700381,
#      9744148,
#      2738670,
#      3796445,
#      4205554,
#      4094049,
#      4094040,
#      5558134,
#      5558011,
#      5557693,
#      5557608,
#      5557440,
#      5557397,
#      5558831,
#      5558457,
#      5558632,
#      5558559,
#      5558476,
#      7331075,
#      5558442,
#      5557750,
#      5557482,
#      5558709,
#      5558656,
#      7331093,
#      5557619,
#      5557514,
#      5557395,
#      5558834,
#      2738123,
#      2738088,
#      2738130,
#      5361723,
#      5601145,
#      2733338,
#      2733340,
#      2733382,
#      2732907,
#      2733373,
#      2732932,
#      3939568,
#      3134409,
#      4176975,
#      4175787,
#      4182861,
#      3980937,
#      3982161,
#      7644896,
#      5600561,
#      5600487,
#      5600384,
#      8093189,
#      5600039,
#      4063410,
#      4063171,
#      4063146,
#      4062683,
#      5643499,
#      5643531,
#      8251755,
#      3983656,
#      3983502,
#      3983329,
#      3982960,
#      3982935,
#      3982927,
#      3982919,
#      3994195,
#      3994069,
#      3985798,
#      2981941,
#      2982318,
#      4180183,
#      4073280,
#      2734403,
#      5555705,
#      3718164,
#      3718137,
#      7914410,
#      5555512,
#      5556030,
#      5555891,
#      5555861,
#      3073647,
#      2981360,
#      2736925,
#      3859866,
#      9474434,
#      9602788,
#      9602206,
#      9260728,
#      9335482,
#      9331413,
#      9580671,
#      3859150,
#      9597927,
#      3858910,
#      3858861,
#      9397013,
#      3858686,
#      3932205,
#      5662457,
#      5661693,
#      7322007,
#      8784468,
#      9214504,
#      8928847,
#      3083111,
#      3083108,
#      3082562,
#      2959354,
#      3871414,
#      5580288,
#      5580184,
#      3059876,
#      3058795,
#      3060276,
#      3058314,
#      3058892,
#      3058571,
#      3059563,
#      3059365,
#      3059644,
#      3058469,
#      3060010,
#      3060296,
#      2731948,
#      2731932,
#      2731924,
#      3722388,
#      9326856,
#      9290106,
#      9458122,
#      3035205,
#      3035162,
#      3035053,
#      3035192,
#      3035040,
#      4195865,
#      4195830,
#      4195813,
#      4195721,
#      4195690,
#      4071026,
#      5357264,
#      2968242,
#      5349573,
#      5349520,
#      5349657,
#      5349762,
#      4161406,
#      4161390,
#      3083214,
#      3083215,
#      3083407,
#      4161402,
#      3083418,
#      3083417,
#      3083352,
#      3083357,
#      5571209,
#      5571043,
#      5570340,
#      5571745,
#      3033026,
#      2734302,
#      2734229,
#      2734051,
#      2734052,
#      3849951,
#      3852751,
#      3852684,
#      8392036,
#      3851874,
#      3851471,
#      3850481,
#      3850402,
#      3850011,
#      3849902,
#      3849888,
#      3852953,
#      5383823,
#      7279624,
#      8397006,
#      3139463,
#      3750566,
#      3685430,
#      3685355,
#      2985213,
#      2985184,
#      2985197,
#      2985100,
#      4073178,
#      3831036,
#      3830822,
#      8303726,
#      5534036,
#      5534548,
#      5534472,
#      5533815,
#      5534080,
#      2971796,
#      5357901,
#      5357703,
#      5357614,
#      5357981,
#      5357785,
#      5357897,
#      5357510,
#      5357845,
#      5357875,
#      5357861,
#      5357595,
#      5357750,
#      5357544,
#      5357539,
#      3072745,
#      3119954,
#      3145047,
#      3144979,
#      3145039,
#      3617666,
#      3189382,
#      3082427,
#      3082391,
#      5357468,
#      3088906,
#      2970407,
#      8876662,
#      2985292,
#      2985471,
#      2985532,
#      2985254,
#      2985366,
#      2985476,
#      2985406,
#      9479823,
#      2985533,
#      2985270,
#      4183098,
#      4182940,
#      4182571,
#      4182457,
#      4182099,
#      4181893,
#      4181615,
#      8032520,
#      2969121,
#      2969126,
#      2969071,
#      2969106,
#      3908528,
#      2969088,
#      2969231,
#      3908297,
#      2969109,
#      7354262,
#      5634536,
#      5355119,
#      5354908,
#      5355082,
#      3621126,
#      3841088,
#      3840383,
#      4260447,
#      2948910,
#      2948876,
#      2948880,
#      7285012,
#      8020309,
#      2984748,
#      7963111,
#      4073497,
#      3793051,
#      3792911,
#      5599769,
#      5599677,
#      5599647,
#      7314445,
#      3860400,
#      7652663,
#      7661217,
#      3858763,
#      3871060,
#      3870266,
#      3869499,
#      3869047,
#      3868274,
#      7810489,
#      3867582,
#      7790289,
#      5938715,
#      7557909,
#      3859299,
#      3867517,
#      3865158,
#      3864099,
#      3863108,
#      3702593,
#      8350277,
#      3782931,
#      5355421,
#      5355420,
#      4259362,
#      4259343,
#      4261941,
#      3870789,
#      3870112,
#      3869754,
#      3722100,
#      7262846,
#      3767014,
#      5685205,
#      5686016,
#      4177448,
#      4176940,
#      4176675,
#      4181369,
#      4181065,
#      7928563,
#      4180552,
#      4180162,
#      4179723,
#      4179270,
#      4178429,
#      4178294,
#      4178202,
#      4177086,
#      4176741,
#      4176657,
#      4176462,
#      4176394,
#      4176240,
#      4183409,
#      4183195,
#      4182239,
#      4181592,
#      4181156,
#      3596797,
#      4205518,
#      3036743,
#      3036754,
#      3036602,
#      3036528,
#      6307010,
#      3036755,
#      3036648,
#      3036542,
#      5629990,
#      5355604,
#      3743798,
#      4073616,
#      2959530,
#      3719269,
#      3723184,
#      3723012,
#      3722904,
#      3722763,
#      3722731,
#      3722563,
#      2984969,
#      5668542,
#      2952734,
#      4073351,
#      7429495,
#      4176621,
#      4175861,
#      4181364,
#      4180281,
#      4178767,
#      9444565,
#      2962799,
#      2962812,
#      2962814,
#      3912400,
#      5685782,
#      5685770,
#      5685765,
#      5685763,
#      5685722,
#      8466001,
#      5685688,
#      4019672,
#      9249370,
#      9488623,
#      9417439,
#      3993834,
#      3993721,
#      3668189,
#      8278028,
#      4073480,
#      4073321,
#      4073153,
#      4073820,
#      4073802,
#      4073797,
#      4073788,
#      3794588,
#      5294718,
#      7278781,
#      5660276,
#      5380009,
#      3038090,
#      3038213,
#      3038725,
#      3037796,
#      3038409,
#      3038452,
#      3038458,
#      3038540,
#      3038453,
#      2957923,
#      2957366,
#      5651100,
#      5651028,
#      9317427,
#      9434514,
#      5651236,
#      5651224,
#      5651190,
#      8580218,
#      5651146,
#      5651319,
#      5651191,
#      3984599,
#      4195742,
#      4195655,
#      5645566,
#      3913358,
#      3912612,
#      5630316,
#      5351889,
#      8366960,
#      7463839,
#      3190484,
#      4092106,
#      7425200,
#      7661037,
#      8180584,
#      2945191,
#      3698942,
#      9275822,
#      3062900,
#      3062915,
#      3152207,
#      3862208,
#      4065279,
#      3992709,
#      3190491,
#      3852028,
#      4261066,
#      3766623,
#      2943400,
#      7328886,
#      3795442,
#      3147875,
#      3152848,
#      3881425,
#      3613565,
#      7333908,
#      3613444,
#      3934887,
#      3934868,
#      3934830,
#      10657507,
#      3790969,
#      5347427,
#      5347439,
#      5347424,
#      5347461]}]}}

# %%
# Submit query to GBIF API
create_download_given_query(GBIF_USER_NAME, GBIF_PASSWORD, download_query)

# Respuesta esperada:
# ok
# <Response [201]>
# Out:
# ok
# <Response [201]>

# %% [markdown]
# **After downloading the file from the GBIF portal if has to be unzipped and renamed with the name defined in OCCURRENCES_CSV**

# %%
occurrences_df = pd.read_csv(OCCURRENCES_CSV, sep='\t')

occurrences_df
# Out:
#            gbifID                            datasetKey  \
# 0      1828917274  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 1      1828921752  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 2      1828925115  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 3      1828926964  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 4      1828947008  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 5      1828947840  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 6      1829084064  16ed67e5-fd70-4fd4-85c3-70ea2da627fe
# ...           ...                                   ...
# 56772  1984193084  dba87678-ffa3-4a06-a2f7-cf4892e1e057
# 56773  1984193126  dba87678-ffa3-4a06-a2f7-cf4892e1e057
# 56774  1984193210  dba87678-ffa3-4a06-a2f7-cf4892e1e057
# 56775  1984193343  dba87678-ffa3-4a06-a2f7-cf4892e1e057
# 56776  2397440434  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 56777  2397461090  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 56778  2397464854  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                             occurrenceID  kingdom  \
# 0      http://n2t.net/ark:/65665/31d1924d0-bb40-4e2f-...  Plantae
# 1      http://n2t.net/ark:/65665/336a35463-38b2-4094-...  Plantae
# 2      http://n2t.net/ark:/65665/34a3cd8ac-5543-45c0-...  Plantae
# 3      http://n2t.net/ark:/65665/354c3f1df-7815-4bd0-...  Plantae
# 4      http://n2t.net/ark:/65665/3a013c42f-76a8-4b94-...  Plantae
# 5      http://n2t.net/ark:/65665/3a40bd132-17ce-47fb-...  Plantae
# 6                                 BRA:IF:SPSF:0000052167  Plantae
# ...                                                  ...      ...
# 56772                             FEDENA:Flora:Flora-400  Plantae
# 56773                             FEDENA:Flora:Flora-420  Plantae
# 56774                             FEDENA:Flora:Flora-435  Plantae
# 56775                             FEDENA:Flora:Flora-385  Plantae
# 56776  https://www.inaturalist.org/observations/13277705  Plantae
# 56777  https://www.inaturalist.org/observations/17517932  Plantae
# 56778  https://www.inaturalist.org/observations/20702624  Plantae
#
#              phylum          class         order            family  \
# 0      Tracheophyta  Magnoliopsida       Fabales          Fabaceae
# 1      Tracheophyta  Magnoliopsida       Fabales          Fabaceae
# 2      Tracheophyta  Magnoliopsida       Fabales          Fabaceae
# 3      Tracheophyta  Magnoliopsida       Fabales          Fabaceae
# 4      Tracheophyta  Magnoliopsida       Fabales          Fabaceae
# 5      Tracheophyta  Magnoliopsida       Fabales          Fabaceae
# 6      Tracheophyta  Magnoliopsida    Sapindales         Meliaceae
# ...             ...            ...           ...               ...
# 56772  Tracheophyta  Magnoliopsida   Gentianales      Gentianaceae
# 56773  Tracheophyta  Magnoliopsida  Malpighiales  Chrysobalanaceae
# 56774  Tracheophyta  Magnoliopsida   Gentianales      Gentianaceae
# 56775  Tracheophyta  Magnoliopsida  Malpighiales  Chrysobalanaceae
# 56776  Tracheophyta  Magnoliopsida      Myrtales      Combretaceae
# 56777  Tracheophyta  Magnoliopsida      Myrtales      Combretaceae
# 56778  Tracheophyta     Liliopsida      Arecales         Arecaceae
#
#               genus                     species  ...       identifiedBy  \
# 0        Machaerium      Machaerium milleflorum  ...                NaN
# 1      Lonchocarpus    Lonchocarpus ferrugineus  ...                NaN
# 2      Lonchocarpus  Lonchocarpus costaricensis  ...                NaN
# 3        Machaerium      Machaerium milleflorum  ...                NaN
# 4        Machaerium      Machaerium milleflorum  ...                NaN
# 5        Machaerium      Machaerium milleflorum  ...                NaN
# 6         Trichilia           Trichilia pallida  ...        T.M.Ribeiro
# ...             ...                         ...  ...                ...
# 56772  Macrocarpaea    Macrocarpaea macrophylla  ...  Leonardo Valencia
# 56773       Licania          Licania platycalyx  ...  Leonardo Valencia
# 56774  Macrocarpaea    Macrocarpaea macrophylla  ...  Leonardo Valencia
# 56775       Licania          Licania platycalyx  ...  Leonardo Valencia
# 56776  Laguncularia       Laguncularia racemosa  ...                NaN
# 56777  Laguncularia       Laguncularia racemosa  ...                NaN
# 56778   Astrocaryum    Astrocaryum standleyanum  ...                NaN
#
#              dateIdentified       license  \
# 0                       NaN       CC0_1_0
# 1                       NaN       CC0_1_0
# 2                       NaN       CC0_1_0
# 3                       NaN       CC0_1_0
# 4                       NaN       CC0_1_0
# 5                       NaN       CC0_1_0
# 6      2010-06-22T00:00:00Z  CC_BY_NC_4_0
# ...                     ...           ...
# 56772                   NaN  CC_BY_NC_4_0
# 56773                   NaN  CC_BY_NC_4_0
# 56774                   NaN  CC_BY_NC_4_0
# 56775                   NaN  CC_BY_NC_4_0
# 56776  2018-06-09T22:57:59Z  CC_BY_NC_4_0
# 56777  2019-08-31T13:15:27Z  CC_BY_NC_4_0
# 56778  2019-02-24T19:57:47Z  CC_BY_NC_4_0
#
#                                 rightsHolder  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6      SPSF - Herbário Dom Bento José Pickel
# ...                                      ...
# 56772                                    NaN
# 56773                                    NaN
# 56774                                    NaN
# 56775                                    NaN
# 56776                           Wayne Fidler
# 56777                          sfitzgerald86
# 56778                                  Dario
#
#                                      recordedBy typeStatus establishmentMeans  \
# 0                                     A. Dugand        NaN                NaN
# 1      C. Hamilton, A. H. Gentry & H. Stockwell        NaN                NaN
# 2                                  B. E. Hammel        NaN                NaN
# 3                D. Neill & QCNE botany interns        NaN                NaN
# 4                                     A. Dugand        NaN                NaN
# 5                                    T. Delinks        NaN                NaN
# 6      T.M.Ribeiro & R.L.R.Santos & R.T.Polisel        NaN                NaN
# ...                                         ...        ...                ...
# 56772                         Leonardo Valencia        NaN                NaN
# 56773                         Leonardo Valencia        NaN                NaN
# 56774                         Leonardo Valencia        NaN                NaN
# 56775                         Leonardo Valencia        NaN                NaN
# 56776                              Wayne Fidler        NaN                NaN
# 56777                             sfitzgerald86        NaN                NaN
# 56778                                     Dario        NaN                NaN
#
#                 lastInterpreted   mediaType  \
# 0      2019-10-16T19:58:13.539Z         NaN
# 1      2019-10-16T20:04:47.143Z         NaN
# 2      2019-10-16T20:18:03.267Z         NaN
# 3      2019-10-16T20:30:57.808Z         NaN
# 4      2019-10-16T21:06:25.906Z         NaN
# 5      2019-10-16T21:10:29.685Z         NaN
# 6      2019-09-21T00:00:57.983Z         NaN
# ...                         ...         ...
# 56772  2019-09-20T22:27:52.961Z         NaN
# 56773  2019-09-20T17:44:36.448Z         NaN
# 56774  2019-09-20T22:28:00.261Z         NaN
# 56775  2019-09-20T17:44:36.459Z         NaN
# 56776  2019-09-20T19:36:31.774Z  STILLIMAGE
# 56777  2019-09-20T19:36:31.773Z  STILLIMAGE
# 56778  2019-10-31T15:49:44.969Z  STILLIMAGE
#
#                                                  issue
# 0                         GEODETIC_DATUM_ASSUMED_WGS84
# 1                         GEODETIC_DATUM_ASSUMED_WGS84
# 2                         GEODETIC_DATUM_ASSUMED_WGS84
# 3                         GEODETIC_DATUM_ASSUMED_WGS84
# 4                         GEODETIC_DATUM_ASSUMED_WGS84
# 5                         GEODETIC_DATUM_ASSUMED_WGS84
# 6                         GEODETIC_DATUM_ASSUMED_WGS84
# ...                                                ...
# 56772                                              NaN
# 56773                                              NaN
# 56774                                              NaN
# 56775                                              NaN
# 56776  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 56777  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
# 56778  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84
#
# [56779 rows x 50 columns]

# %%
# Change "eventDate" data type to dateTime
occurrences_df["eventDate"] = pd.to_datetime(occurrences_df["eventDate"])

# %%
# ==================== CREACIÓN DEL DATAFRAME DE ÁREAS PROTEGIDAS ====================
wdpa_gdf = gpd.read_file(PROTECTED_AREAS_LAYER, encoding="latin-1")
wdpa_gdf.index.name = "index_wdpa"


# ==================== CREACIÓN DE LOS ARCHIVOS DE SALIDA ====================

# Archivo CSV
results_csv = open(OUTPUT_CSV, mode='w', newline='', encoding="latin-1")
results_csv_writer = csv.writer(results_csv, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
results_csv_writer.writerow(['Nombre cientifico de entrada', 
                             'Familia (GBIF)', 
                             'Genero (GBIF)', 
                             'Especie (GBIF)', 
                             'EOO (km2)', 
                             'AOO (km2)',
                             'Altitud minima (m)', 
                             'Altitud maxima (m)',
                             'Países', 
                             'Areas protegidas',
                             'Mapa de registros de presencia', 
                             'Mapa agrupado',
                             'Archivo CSV con registros de presencia'])

# Archivo HTML
results_html = open(OUTPUT_HTML, mode='w', newline='', encoding="latin-1")
results_html.write("<!DOCTYPE html>")
results_html.write('<html lang="es">')
results_html.write("<head>")
results_html.write("<title>Evaluacion de arboles de Mesoamerica</title>")
results_html.write("<style>table, th, td {border: 1px solid black;}</style>")
results_html.write("</head>")
results_html.write("<body>")
results_html.write("<table>")
results_html.write("<tr><th>Nombre cientifico de entrada</th><th>Familia (GBIF)</th><th>Genero (GBIF)</th><th>Especie (GBIF)</th><th>EOO (km2)</th><th>AOO (km2)</th><th>Altitud minima (m)</th><th>Altitud maxima (m)</th><th>Paises</th><th>Areas protegidas</th><th>Mapa de registros de presencia</th><th>Mapa agrupado</th><th>Archivo CSV con registros de presencia</th></tr>")
results_html.write("<tbody>")


# ==================== RECORRIDO DE LA LISTA DE ESPECIES ====================

for index, row in gbif_species_df.iterrows():
    species_input = row["inputName"]
    family_gbif = row["family"]
    genus_gbif = row["genus"]
    species_gbif = row["species"]
    print(species_gbif)

    current_taxon_df = occurrences_df[occurrences_df['species'] == species_gbif]    
    if current_taxon_df.size > 0:   
        # ==================== ESTRUCTURAS PARA EL CÁLCULO DEL EOO Y DEL AOO ====================    

        # Lista de puntos para el cálculo del EOO
        eoo_points = []   

        # Lista de valores de (x,y) para el cálculo del AOO
        aoo_x_values = []
        aoo_y_values = []   


        # ==================== ESTRUCTURAS PARA EL CÁLCULO DE LAS ALTITUDES MÍNIMA Y MÁXIMA ====================    

        altitude_values = []


        # ==================== ESTRUCTURAS PARA LA GENERACIÓN DE LA LISTA DE PAÍSES ====================    

        # Conjunto de códigos de países en los que hay registros de presencia
        countries = set()


        # ==================== ESTRUCTURAS PARA LA GENERACIÓN DE LA LISTA DE ÁREAS PROTEGIDAS ====================    

        # Arreglo de códigos de países en los que hay registros de presencia    
        current_taxon_geom = [Point(xy) for xy in zip(current_taxon_df["decimalLongitude"], 
                                                      current_taxon_df["decimalLatitude"])]
        current_taxon_gdf = gpd.GeoDataFrame(current_taxon_df, 
                                             crs={"init": "epsg:4326"}, 
                                             geometry=current_taxon_geom)

        wdpa_ocuppied = gpd.sjoin(wdpa_gdf, current_taxon_gdf, how="inner", op='intersects')
        protected_areas = wdpa_ocuppied.NAME.unique()    


        # ==================== INICIALIZACIÓN DE MAPAS ====================

        # Mapa de registros de presencia
        occurrences_map = folium.Map(location=[9.63, -84], 
                                     tiles='OpenStreetMap', 
                                     attr='OpenStreetMap', 
                                     zoom_start=5, 
                                     control_scale=True)
        folium.TileLayer(tiles='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/MapServer/tile/{z}/{y}/{x}',
                         name='ESRI World Imagery',
                         attr='ESRI World Imagery').add_to(occurrences_map)

        # Mapa de registros de presencia agrupados (cluster)
        cluster_map = folium.Map(location=[9.63, -84], 
                                 tiles='OpenStreetMap', 
                                 attr='OpenStreetMap', 
                                 zoom_start=5, 
                                 control_scale=True)
        folium.TileLayer(tiles='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/MapServer/tile/{z}/{y}/{x}',
                         name='ESRI World Imagery',
                         attr='ESRI World Imagery').add_to(cluster_map)    
        occurrences_cluster = plugins.MarkerCluster().add_to(cluster_map)


        # ==================== RECORRIDO DE LOS REGISTROS DE PRESENCIA ====================
        for lat, lng, alt, country, m, label in zip(current_taxon_df.decimalLatitude,
                                   current_taxon_df.decimalLongitude,
                                   current_taxon_df.elevation,
                                   current_taxon_df.countryCode,
                                   current_taxon_df.eventDate.dt.month,
                                   "<strong>Localidad:</strong> "       + current_taxon_df.locality.astype(str)   + "\n"    +
                                   "<strong>Elevación:</strong> "       + current_taxon_df.elevation.astype(str)  + " m \n" +
                                   "<strong>Fecha:</strong> "           + current_taxon_df.eventDate.astype(str)  + "\n"    +
                                   "<strong>Recolectores:</strong> "    + current_taxon_df.recordedBy.astype(str) + "\n"    +
                                   "<strong>Identificadores:</strong> " + current_taxon_df.identifiedBy.astype(str)):

            # Adición de valores para el cálculo de las altitudes mínima y máxima
            altitude_values.append(alt)

            # Adición de puntos para el cálculo del EOO
            x,y = transform(INPUT_PROJECTION, OUTPUT_PROJECTION, lng, lat)
            eoo_point = []
            eoo_point.append(x)
            eoo_point.append(y)
            eoo_points.append(eoo_point)        

            # Adición de valores x,y para el cálculo del AOO
            x,y = transform(INPUT_PROJECTION, OUTPUT_PROJECTION, lng, lat)
            aoo_x_values.append(x)
            aoo_y_values.append(y)

            # Adición de códigos de países
            if country and not(country == '' or pd.isnull(country)):
                countries.add(country)      

            # Adición de registros de presencia al mapa de registros de presencia
            folium.CircleMarker(location=[lat, lng], 
                                radius=3, 
                                color='red', 
                                fill=True,
                                popup=label,
                                fill_color='darkred',
                                fill_opacity=0.6).add_to(occurrences_map)

            # Adición de registros de presencia agrupados al mapa de registros de presencia agrupados (cluster)
            folium.Marker(
                location=[lat, lng],
                icon=None,
                popup=label,
            ).add_to(occurrences_cluster)


        # Cálculo de las altitudes mínima y máxima
        altitude_min = min(altitude_values)
        if (np.isnan(altitude_min)):
            altitude_min_str = ""
        else:
            altitude_min_str = "{:.2f}".format(altitude_min)
        altitude_max = max(altitude_values)
        if (np.isnan(altitude_max)):
            altitude_max_str = ""
        else:
            altitude_max_str = "{:.2f}".format(altitude_max)

        print("Altitud mínima:", altitude_min_str)
        print("Altitud máxima:", altitude_max_str)

        # Cálculo del EOO
        if (len(eoo_points) > 2):
            a = np.array(eoo_points)
            a = np.unique(a, axis=0)
            if (len(a) > 2):
                hull = ConvexHull(a)
                eoo = hull.volume / 1000000
            else:
                eoo = 0
        else:
            eoo = 0
        print("Área de extensión de presencia (EOO):", "{:.2f}".format(eoo), "km2")

        # Cálculo del AOO
        x = np.array(aoo_x_values)
        y = np.array(aoo_y_values)
        gridx = np.arange(AOO_GRID_X_MIN, AOO_GRID_X_MAX, AOO_GRID_CELL_X_WIDTH)
        gridy = np.arange(AOO_GRID_Y_MIN, AOO_GRID_Y_MAX, AOO_GRID_CELL_Y_WIDTH)
        grid, _, _ = np.histogram2d(x, y, bins=[gridx, gridy])
        occupied_cells = (grid > 0) 
        aoo = len(grid[occupied_cells]) * (AOO_GRID_CELL_AREA / 1000000)
        print("Área de ocupación (AOO):", "{:.2f}".format(aoo), "km2")

        # Lista de países con registros de presencia
        print("Países no ordenados:", countries)
        countries = sorted(countries)
        print("Países (ordenados) con registros de presencia:", countries)

        # Lista de áreas protegidas con registros de presencia
        protected_areas = sorted(protected_areas)
        print("Áreas protegidas con registros de presencia:", protected_areas)      

        # Adición de controles de capas
        folium.LayerControl().add_to(occurrences_map)
        folium.LayerControl().add_to(cluster_map)


        # Grabado de archivos HTML con los mapas
        occurrences_map.save(OUTPUT_DIR + species_input.replace(" ", "_") + "-mapa_registros_presencia.html")
        cluster_map.save(OUTPUT_DIR + species_input.replace(" ", "_") + "-mapa_agrupado.html")  

        # Adición de línea en el archivo CSV de salida
        results_csv_writer.writerow([species_input, 
                                     family_gbif, 
                                     genus_gbif, 
                                     species_gbif, 
                                     "{:.2f}".format(eoo), 
                                     "{:.2f}".format(aoo),
                                     altitude_min_str, 
                                     altitude_max_str,                                  
                                     ', '.join(countries),
                                     ', '.join(protected_areas),
                                     '=HYPERLINK("'+OUTPUT_BASE_URL_MAP + species_input.replace(" ", "_") + '-mapa_registros_presencia.html' + '", "' + 'Enlace al mapa")',
                                     '=HYPERLINK("'+OUTPUT_BASE_URL_MAP + species_input.replace(" ", "_") + '-mapa_agrupado.html'            + '", "' + 'Enlace al mapa")',
                                     '=HYPERLINK("'+OUTPUT_BASE_URL_CSV + species_input.replace(" ", "_") + '-registros_presencia.csv'       + '", "' + 'Enlace al archivo")'])

        # Adición de línea en el archivo HTML de salida
        results_html.write("<tr>")
        results_html.write("<td>"+ species_input                 +"</td>")
        results_html.write("<td>"+ family_gbif                   +"</td>")
        results_html.write("<td>"+ genus_gbif                    +"</td>")
        results_html.write("<td>"+ species_gbif                  +"</td>")
        results_html.write("<td>"+ "{:.2f}".format(eoo)          +"</td>")
        results_html.write("<td>"+ "{:.2f}".format(aoo)          +"</td>")
        results_html.write("<td>"+ altitude_min_str              +"</td>")
        results_html.write("<td>"+ altitude_max_str              +"</td>")    
        results_html.write("<td>"+ ', '.join(countries)          +"</td>")
        results_html.write("<td>"+ ', '.join(protected_areas)    +"</td>")
        results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL_MAP + species_input.replace(' ', '_') + '-mapa_registros_presencia.html' +'">Enlace</a>' + "</td>")
        results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL_MAP + species_input.replace(' ', '_') + '-mapa_agrupado.html'            +'">Enlace</a>' + "</td>")
        results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL_CSV + species_input.replace(' ', '_') + '-registros_presencia.csv'       +'">Enlace</a>' + "</td>")    
        results_html.write("</tr>")

        # Creación de archivo de registros de presencia de la especie en archivo CSV
        current_taxon_df = current_taxon_df[['basisOfRecord', 'species', 'catalogNumber', 'recordNumber', 'decimalLatitude', 'decimalLongitude', 'locality', 'year', 'recordedBy']]
        current_taxon_df.columns = ['BasisOfRec', 'Binomial', 'CatalogNo', 'CollectID', 'Dec_Lat', 'Dec_Long', 'Dist_comm', 'Event_Year', 'recordedBy']
        current_taxon_df.insert(3,  "Citation",  "GBIF")
        current_taxon_df.insert(5,  "Compiler",  "Manuel Vargas")
        current_taxon_df.insert(6,  "Data_sens", "")    
        current_taxon_df.insert(11, "Origin", 1)    
        current_taxon_df.insert(12, "Presence", 1)
        current_taxon_df.insert(13, "Seasonal", 1)        
        current_taxon_df.insert(14, "Sens_comm", "")
        current_taxon_df.insert(15, "SpatialRef", "WGS84")
        current_taxon_df.insert(16, "YrCompiled", 2019)    
        current_taxon_df.to_csv(OUTPUT_DIR + species_input.replace(" ", "_") + "-registros_presencia.csv")
    
# ==================== CIERRE DE LOS ARCHIVOS DE SALIDA ====================

# Archivo CSV
results_csv.close()

# Archivo HTML
results_html.write("</tbody></table></body></html>")
results_html.close()
# Out:
# Acalypha ferdinandi
# Altitud mínima: 0.00
# Altitud máxima: 1550.00
# Área de extensión de presencia (EOO): 803644.48 km2
# Área de ocupación (AOO): 288.00 km2
# Países no ordenados: {'CR', 'HN', 'MX', 'PE', 'GT'}
# Países (ordenados) con registros de presencia: ['CR', 'GT', 'HN', 'MX', 'PE']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Carara', 'Cerro San Gil', 'Cerro de Escazu', 'Cerros de Turrubares', 'El Rodeo', 'La Cangreja', 'Lancetilla', 'Palenque', 'Santa Rosa', 'Volcan Tenorio']
# Aegiphila panamensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 8450100.76 km2
# Área de ocupación (AOO): 1660.00 km2
# Países no ordenados: {'VE', 'BR', 'CR', 'CO', 'HN', 'SV', 'BO', 'PA', 'MX', 'PE', 'GF', 'EC', 'NI', 'GT'}
# Países (ordenados) con registros de presencia: ['BO', 'BR', 'CO', 'CR', 'EC', 'GF', 'GT', 'HN', 'MX', 'NI', 'PA', 'PE', 'SV', 'VE']
# Áreas protegidas con registros de presencia: ['Alto Orinoco-Casiquiare', 'Amacayacu', 'Antisana', 'Apaneca-Llamatepec', 'ArchipiÃ©lago  de Zapatera', 'Area Natural Protegida Laguna del Jocotal', 'Area de ConservaciÃ³n Guanacaste', 'Barra Honda', 'Barra del Colorado', 'Barro Colorado', 'Bosawas', 'Cahuita', 'Camino de Cruces', 'Cano Negro', 'Carara', 'CaÃ±o Negro', 'Cerro Cumaica Cerro Alegre', 'Cerro El Arenal', 'Cerro Gaital', 'Cerro Mombachito La Vieja', 'Cerro Nara', 'Cerro Silva', 'Cerro Tomabu', 'Cerros de Turrubares', 'Chagres', 'Chirripo', 'Coiba', 'Coiba National Park and its Special Zone of Marine Protection', 'Complejo Laguna GÃ¼ija', 'Complejo VolcÃ¡nico San Cristobal Casitas', 'Complejo de Humedales Cuyabeno Lagartococha YasunÃ\xad', 'Corcovado', 'Cueva de los Guacharos', 'Cuyabeno', 'Darien National Park', 'DariÃ©n', 'Diria', 'Donoso', 'El CajÃ³n', 'El Caura', 'El Montuoso', 'El Rodeo', 'El TamÃ¡', 'Embalse CerrÃ³n Grande', 'Encanto de los manglares del Bajo Baudo', 'Formaciones de Tepuyes', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Guanacaste', 'Humedal Caribe Noreste', 'Indio Maiz', 'Internacional La Amistad', 'La Cangreja', 'La Joya', 'La Paragua', 'Laguna El Jocotal', 'Laguna de Apoyo', 'Las Tablas', 'Los Corales del Rosario y San Bernardo', 'Los Guatuzos', 'Los Santos', 'Manuel Antonio', 'Metropolitano', 'Miraflor/Moropotente', 'Miravalles', 'Nancuchiname (Mata de PiÃ±a, La Maroma, PorciÃ³n 5 y 6)', 'NarganÃ¡', 'Nukak', 'Parque Nacional Montecristo', 'Parque do Xingu', 'Piedras Blancas', 'Plan de Amayo', 'Punchina', 'Punta Gorda', 'Reserva de la BiÃ³sfera de Yasuni', 'Rincon de la Vieja', 'Rio Negro', 'RÃ\xado San Juan', 'San Diego La Barra, laguna, cerro, San felipe (12)', 'Santa Rosa', 'Serrania de los Yariguies', 'SerranÃ\xada de la Neblina', 'Sierra Amerrisque', 'Soberania', 'Sur del Estado BolÃ\xadvar', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero', 'Volcan BarÃº', 'VolcÃ¡n  Masaya', 'VolcÃ¡n Cosiguina', 'Xiriualtique-Jiquilisco', 'Yanesha', 'YasunÃ\xad', 'Zona de Amortiguamiento (Bosawas)', 'Zona de Amortiguamiento (Tisey Estanzuela)', 'Ã\x81rea De ProteÃ§Ã£o Ambiental  Tapuruquara', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Do Lago De Tucurui']
# Aiouea brenesii
# Altitud mínima: 20.00
# Altitud máxima: 2000.00
# Área de extensión de presencia (EOO): 701285.15 km2
# Área de ocupación (AOO): 168.00 km2
# Países no ordenados: {'CO', 'CR', 'HN', 'PA', 'MX'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'HN', 'MX', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Coiba', 'Coiba National Park and its Special Zone of Marine Protection', 'El Rodeo', 'Guanacaste', 'Internacional La Amistad', 'Las Tablas', 'Penas Blancas', 'Rincon de la Vieja', 'Santa Fe', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº', 'YaxchilÃ¡n']
# Aiouea neurophylla
# Altitud mínima: 0.00
# Altitud máxima: 1550.00
# Área de extensión de presencia (EOO): 603005.04 km2
# Área de ocupación (AOO): 156.00 km2
# Países no ordenados: {'CR', 'HN', 'PA', 'MX', 'NI'}
# Países (ordenados) con registros de presencia: ['CR', 'HN', 'MX', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Bosawas', 'Cerro Guabule', 'Cerros de Turrubares', 'Corcovado', 'Golfito', 'Golfo Dulce', 'Humedal Caribe Noreste', 'Lancetilla', 'Las Tablas', 'Piedras Blancas', 'Punta Rio Claro', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero']
# Aiouea obscura
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 111491.53 km2
# Área de ocupación (AOO): 76.00 km2
# Países no ordenados: {'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Golfo Dulce']
# Aiouea pittieri
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 98080.68 km2
# Área de ocupación (AOO): 284.00 km2
# Países no ordenados: {'NI', 'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Cerro El Arenal', 'Cerro Hoya', 'Cerro Tisey Estanzuela', 'Cerros de Turrubares', 'Corcovado', 'Fortuna', 'Guanacaste', 'Internacional La Amistad', 'La Cangreja', 'Las Tablas', 'Miraflor/Moropotente', 'Rincon de la Vieja', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Aiouea tonduzii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 102675.80 km2
# Área de ocupación (AOO): 192.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Cerro de Escazu', 'Chirripo', 'Darien National Park', 'DariÃ©n', 'Fortuna', 'Guanacaste', 'La Amistad', 'Las Tablas', 'Los Santos', 'NarganÃ¡', 'Rincon de la Vieja', 'Rio Banano', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Ã\x81rea de Manejo Especial Municipal de Chame (Manglares)']
# Aiphanes hirsuta
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 558283.91 km2
# Área de ocupación (AOO): 372.00 km2
# Países no ordenados: {'CR', 'EC', 'PA', 'CO'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'EC', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Camelias', 'Canones de los rios Melcocho y Santo Domingo', 'Carauta', 'Cerro Gaital', 'Chagres', 'Cotacachi Cayapas', 'Darien', 'Darien National Park', 'DariÃ©n', 'De Urrao', 'Embalse el Penol y Cuenca Alta del Rio Guatape', 'Fortuna', 'General de DivisiÃ³n Omar Torrijos Herrera', 'La Tebaida', 'Las Orquideas', 'Paramillo', 'Punchina', 'Rio Anchicaya', 'Santa Fe']
# Albizia duckeana
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 3966291.11 km2
# Área de ocupación (AOO): 40.00 km2
# Países no ordenados: {'HN', 'BR', 'GY'}
# Países (ordenados) con registros de presencia: ['BR', 'GY', 'HN']
# Áreas protegidas con registros de presencia: ['Parque Estadual Cristalino', 'Tawahka Asangni']
# Alfaroa manningii
# Altitud mínima: 0.00
# Altitud máxima: 2150.00
# Área de extensión de presencia (EOO): 73899.22 km2
# Área de ocupación (AOO): 184.00 km2
# Países no ordenados: {'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Barbilla', 'Guanacaste', 'Miravalles', 'Monumento Nacional Guayabo', 'Rincon de la Vieja', 'Rio Pacuare', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan Tenorio']
# Amphitecna gentryi
# Altitud mínima: 300.00
# Altitud máxima: 1840.00
# Área de extensión de presencia (EOO): 6421.35 km2
# Área de ocupación (AOO): 108.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Guanacaste', 'Tenorio', 'Volcan Tenorio']
# Amphitecna isthmica
# Altitud mínima: 1.00
# Altitud máxima: 1840.00
# Área de extensión de presencia (EOO): 124145.86 km2
# Área de ocupación (AOO): 196.00 km2
# Países no ordenados: {'CR', 'PA', 'CO'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Carara', 'Cerro Gaital', 'Corcovado', 'Darien National Park', 'DariÃ©n', 'Donoso', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Golfito', 'Golfo Dulce', 'La Cangreja', 'Las Tablas', 'Los Santos', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia alajuelae
# Altitud mínima: 1200.00
# Altitud máxima: 1200.00
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 4.00 km2
# Países no ordenados: {'NI'}
# Países (ordenados) con registros de presencia: ['NI']
# Áreas protegidas con registros de presencia: []
# Ardisia angucianensis
# Altitud mínima: 1500.00
# Altitud máxima: 1500.00
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 4.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: []
# Ardisia blepharodes
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 12104.87 km2
# Área de ocupación (AOO): 40.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Barbilla', 'Golfo Dulce', 'Palo Seco', 'Rio Banano', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia brenesii
# Altitud mínima: 0.00
# Altitud máxima: 1500.00
# Área de extensión de presencia (EOO): 40557.87 km2
# Área de ocupación (AOO): 172.00 km2
# Países no ordenados: {'NI', 'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Arenal Monteverde', 'Barra del Colorado', 'Cordillera Volcanica Central', 'Corredor Fronterizo', 'Humedal Caribe Noreste', 'Indio Maiz', 'Maquenque', 'NarganÃ¡', 'RÃ\xado San Juan', 'Sureste de Nicaragua']
# Ardisia capitellata
# Altitud mínima: 1160.00
# Altitud máxima: 2050.00
# Área de extensión de presencia (EOO): 10309.71 km2
# Área de ocupación (AOO): 72.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Estero Puntarenas y Manglares Asociados', 'Internacional La Amistad', 'Las Tablas', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia cartagoana
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 14315.67 km2
# Área de ocupación (AOO): 44.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Terraba-Sierpe']
# Ardisia crassiramea
# Altitud mínima: 650.00
# Altitud máxima: 1720.00
# Área de extensión de presencia (EOO): 3346.75 km2
# Área de ocupación (AOO): 88.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Guanacaste', 'Rincon de la Vieja', 'Volcan Tenorio']
# Ardisia dodgei
# Altitud mínima: 27.50
# Altitud máxima: 2550.00
# Área de extensión de presencia (EOO): 472335.61 km2
# Área de ocupación (AOO): 128.00 km2
# Países no ordenados: {'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Cueva de los Guacharos', 'Golfito', 'Golfo Dulce', 'Paramos de Guantiva y la Rusia', 'Piedras Blancas']
# Ardisia dunlapiana
# Altitud mínima: 0.00
# Altitud máxima: 900.00
# Área de extensión de presencia (EOO): 13171.14 km2
# Área de ocupación (AOO): 100.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Golfito', 'Golfo Dulce', 'Piedras Blancas']
# Ardisia fendleri
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1436494.38 km2
# Área de ocupación (AOO): 548.00 km2
# Países no ordenados: {'CR', 'HN', 'PA', 'MX', 'NI'}
# Países (ordenados) con registros de presencia: ['CR', 'HN', 'MX', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Area de ConservaciÃ³n Guanacaste', 'Barro Colorado', 'Bosawas', 'Braulio Carrillo', 'Carara', 'Cerro Mombachito La Vieja', 'Cerro Saslaya', 'Cerro Silva', 'Chagres', 'Chirripo', 'Corcovado', 'Donoso', 'El Montuoso', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Guanacaste', 'Indio Maiz', 'Internacional La Amistad', 'La Cangreja', 'La Selva', 'Lacustrino Laguna del Paraguas', 'Las Tablas', 'Los Santos', 'Maquenque', 'Punta Gorda', 'RÃ\xado San Juan', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tawahka Asangni', 'Volcan Tenorio', 'Zona de Amortiguamiento (Bosawas)', 'Ã\x81rea de Manejo Especial Municipal de Chame (Manglares)']
# Ardisia furfuracea
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 7560.76 km2
# Área de ocupación (AOO): 60.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cordillera Volcanica Central', 'Golfo Dulce', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Ardisia furfuracella
# Altitud mínima: 10.00
# Altitud máxima: 2115.50
# Área de extensión de presencia (EOO): 80892.02 km2
# Área de ocupación (AOO): 128.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Corcovado', 'El Montuoso', 'Golfo Dulce', 'Las Tablas', 'Los Santos', 'Osa', 'Palo Seco', 'Rincon de la Vieja', 'Rio Navarro-Rio Sombrero', 'Santa Fe', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia generalensis
# Altitud mínima: 300.00
# Altitud máxima: 300.00
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 4.00 km2
# Países no ordenados: {'PA'}
# Países (ordenados) con registros de presencia: ['PA']
# Áreas protegidas con registros de presencia: []
# Ardisia liesneri
# Altitud mínima: 5.50
# Altitud máxima: 495.00
# Área de extensión de presencia (EOO): 1386.71 km2
# Área de ocupación (AOO): 100.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Golfo Dulce']
# Ardisia maxonii
# Altitud mínima: 1150.00
# Altitud máxima: 2850.00
# Área de extensión de presencia (EOO): 17690.61 km2
# Área de ocupación (AOO): 60.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Chirripo', 'Internacional La Amistad', 'Las Tablas', 'Los Santos', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº']
# Ardisia opaca
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 236360.73 km2
# Área de ocupación (AOO): 20.00 km2
# Países no ordenados: {'CR', 'PA', 'CO'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Darien National Park', 'DariÃ©n', 'Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia palmana
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1230596.26 km2
# Área de ocupación (AOO): 336.00 km2
# Países no ordenados: {'CO', 'CR', 'PA', 'GY', 'NI'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'GY', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Carauta', 'Cerro de Escazu', 'Cerros de Turrubares', 'Cordillera Volcanica Central', 'Curi cancha', 'Estero Puntarenas y Manglares Asociados', 'Fortuna', 'Guanacaste', 'Indio Maiz', 'Internacional La Amistad', 'La Amistad', 'La Selva', 'Las Tablas', 'Los Santos', 'Macizo de PeÃ±as Blancas', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Banano', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tenorio', 'Utria', 'Volcan BarÃº', 'Volcan Tenorio', 'VolcÃ¡n Maderas']
# Ardisia pleurobotrya
# Altitud mínima: 0.00
# Altitud máxima: 3100.00
# Área de extensión de presencia (EOO): 19182.55 km2
# Área de ocupación (AOO): 192.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Estero Puntarenas y Manglares Asociados', 'Internacional La Amistad', 'La Amistad', 'Las Tablas', 'Reserva de la BiÃ³sfera de La Amistad', 'Rincon de la Vieja', 'Rio Macho', 'Rio Toro', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan Poas']
# Ardisia storkii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 4.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: []
# Ardisia tarariae
# Altitud mínima: 2100.00
# Altitud máxima: 2698.00
# Área de extensión de presencia (EOO): 144.75 km2
# Área de ocupación (AOO): 40.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia tortuguerensis
# Altitud mínima: 100.00
# Altitud máxima: 100.00
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 8.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Humedal Caribe Noreste', 'Tortuguero']
# Ardisia wedelii
# Altitud mínima: 6.00
# Altitud máxima: 1799.00
# Área de extensión de presencia (EOO): 190324.92 km2
# Área de ocupación (AOO): 248.00 km2
# Países no ordenados: {'NI', 'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Bosawas', 'Braulio Carrillo', 'Carara', 'Cerro Kilambe', 'Cerro Silva', 'Fortuna', 'Humedal Caribe Noreste', 'Indio Maiz', 'La Selva', 'Palo Seco', 'RÃ\xado San Juan', 'Santa Fe', 'Sureste de Nicaragua', 'Tortuguero', 'Zona de Amortiguamiento (Bosawas)', 'Zona de Emergencia Volcan Arenal']
# Astrocaryum alatum
# Altitud mínima: 1.00
# Altitud máxima: 1000.00
# Área de extensión de presencia (EOO): 246601.63 km2
# Área de ocupación (AOO): 260.00 km2
# Países no ordenados: {'HN', 'NI', 'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'HN', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Barra del Colorado', 'Braulio Carrillo', 'Carara', 'Cerro Bana Cruz', 'Chagres', 'Donoso', 'Estero Puntarenas y Manglares Asociados', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Guanacaste', 'Humedal Caribe Noreste', 'Indio Maiz', 'Santa Fe', 'Soberania', 'Sureste de Nicaragua', 'Zona de Amortiguamiento (Bosawas)']
# Astrocaryum confertum
# Altitud mínima: 50.00
# Altitud máxima: 350.00
# Área de extensión de presencia (EOO): 44098.46 km2
# Área de ocupación (AOO): 40.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Donoso', 'Humedal Caribe Noreste', 'La Selva', 'NarganÃ¡', 'Tortuguero']
# Astrocaryum standleyanum
# Altitud mínima: 5.00
# Altitud máxima: 2800.00
# Área de extensión de presencia (EOO): 1177688.75 km2
# Área de ocupación (AOO): 312.00 km2
# Países no ordenados: {'CR', 'EC', 'PA', 'CO'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'EC', 'PA']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Barro Colorado', 'Darien', 'Darien National Park', 'DariÃ©n', 'De Los Humedales Entre Los RÃ\xados Leon Y SuriquÃ\xad', 'En el Territorio Colectivo del Consejo Comunitario de la Comunidad Negra de la Plata', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Humedales entre los Rios Leon y Suriqui', 'La Sierpe', 'Los Katios', 'Los KatÃ\xados National Park', 'Machalilla', 'Manglares Churute', 'Manuel Antonio', 'NarganÃ¡', 'Soberania', 'Zona Marina Parque Nacional Machalilla']
# Ateleia herbert-smithii
# Altitud mínima: 0.00
# Altitud máxima: 500.00
# Área de extensión de presencia (EOO): 710708.30 km2
# Área de ocupación (AOO): 80.00 km2
# Países no ordenados: {'NI', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'NI']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'RÃ\xado Escalante Chacocente', 'Santa Rosa', 'Tayrona']
# Axinaea costaricensis
# Altitud mínima: 216.00
# Altitud máxima: 3230.00
# Área de extensión de presencia (EOO): 502241.54 km2
# Área de ocupación (AOO): 224.00 km2
# Países no ordenados: {'VE', 'PA', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'PA', 'VE']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cerro de Escazu', 'Chirripo', 'Cordillera Volcanica Central', 'Guaramacal', 'Internacional La Amistad', 'Juan Castro Blanco', 'La Amistad', 'Los Quetzales', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Toro', 'Sisavita', 'Sureste del Lago de Maracaibo Sto. Domingo-MotatÃ¡n', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº', 'Volcan Poas']
# Bactris caudata
# Altitud mínima: 5.00
# Altitud máxima: 1250.00
# Área de extensión de presencia (EOO): 111721.05 km2
# Área de ocupación (AOO): 80.00 km2
# Países no ordenados: {'NI', 'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Cerro Silva', 'Chagres', 'Indio Maiz', 'Sureste de Nicaragua']
# Bactris glandulosa
# Altitud mínima: 0.00
# Altitud máxima: 1200.00
# Área de extensión de presencia (EOO): 257958.62 km2
# Área de ocupación (AOO): 320.00 km2
# Países no ordenados: {'CR', 'PA', 'CO'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Carara', 'Carauta', 'Cerro Gaital', 'Cerro Nara', 'Corcovado', 'Darien', 'El Montuoso', 'El Rodeo', 'Finca Baru del Pacifico', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfito', 'Golfo Dulce', 'La Cangreja', 'NarganÃ¡', 'Piedras Blancas', 'Rancho La Merced']
# Bactris herrerana
# Altitud mínima: 50.00
# Altitud máxima: 700.00
# Área de extensión de presencia (EOO): 4133.82 km2
# Área de ocupación (AOO): 44.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Golfo Dulce', 'La Cangreja', 'Piedras Blancas']
# Bactris longiseta
# Altitud mínima: 50.00
# Altitud máxima: 1000.00
# Área de extensión de presencia (EOO): 1936.26 km2
# Área de ocupación (AOO): 24.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo']
# Bactris militaris
# Altitud mínima: 0.00
# Altitud máxima: 350.00
# Área de extensión de presencia (EOO): 847412.51 km2
# Área de ocupación (AOO): 64.00 km2
# Países no ordenados: {'PA', 'US', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA', 'US']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Braulio Carrillo', 'Donoso', 'Gandoca Manzanillo', 'Gandoca-Manzanillo']
# Bactris polystachya
# Altitud mínima: 10.00
# Altitud máxima: 700.00
# Área de extensión de presencia (EOO): 6126.00 km2
# Área de ocupación (AOO): 40.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Maquenque']
# Bakeridesia vulcanicola
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 17678.49 km2
# Área de ocupación (AOO): 24.00 km2
# Países no ordenados: {'SV', 'CR', 'GT'}
# Países (ordenados) con registros de presencia: ['CR', 'GT', 'SV']
# Áreas protegidas con registros de presencia: ['Caraigres']
# Bartlettina prionophylla
# Altitud mínima: 1350.00
# Altitud máxima: 2804.16
# Área de extensión de presencia (EOO): 14354.87 km2
# Área de ocupación (AOO): 56.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Las Tablas', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº']
# Beilschmiedia immersinervis
# Altitud mínima: 300.00
# Altitud máxima: 1400.00
# Área de extensión de presencia (EOO): 243.62 km2
# Área de ocupación (AOO): 24.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Cuenca del Rio Abangares']
# Beilschmiedia ovalis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 639587.98 km2
# Área de ocupación (AOO): 208.00 km2
# Países no ordenados: {'CO', 'CR', 'HN', 'PA', 'MX'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'HN', 'MX', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Azul MeÃ¡mbar', 'Braulio Carrillo', 'Camelias', 'Corcovado', 'Cordillera Volcanica Central', 'Divisoria Valle de Aburra Rio Cauca', 'Golfo Dulce', 'Internacional La Amistad', 'La Tierra del FaisÃ¡n', 'Rio Nare', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº', 'Volcan TacanÃ¡', 'VolcÃ¡n TacanÃ¡']
# Beilschmiedia tilaranensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 251388.15 km2
# Área de ocupación (AOO): 60.00 km2
# Países no ordenados: {'EC', 'PA', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'EC', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Guanacaste']
# Berberis hemsleyi
# Altitud mínima: 340.00
# Altitud máxima: 3450.00
# Área de extensión de presencia (EOO): 940364.15 km2
# Área de ocupación (AOO): 204.00 km2
# Países no ordenados: {'HN', 'MX', 'CR', 'GT'}
# Países (ordenados) con registros de presencia: ['CR', 'GT', 'HN', 'MX']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Chirripo', 'Cordillera Volcanica Central', 'El Cielo', 'Las Tablas', 'Los Santos', 'MontaÃ±a Santa BÃ¡rbara', 'Reserva de la Biosfera El Cielo', 'Sierra de las Minas', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan Irazu', 'Volcan Poas', 'VolcÃ¡n Acatenango', 'VolcÃ¡n Pacaya', 'VolcÃ¡n de Pacaya y  Laguna de Calderas']
# Berberis volcania
# Altitud mínima: 1000.00
# Altitud máxima: 3900.00
# Área de extensión de presencia (EOO): 149658.21 km2
# Área de ocupación (AOO): 228.00 km2
# Países no ordenados: {'MX', 'CR', 'GT'}
# Países (ordenados) con registros de presencia: ['CR', 'GT', 'MX']
# Áreas protegidas con registros de presencia: ['Chirripo', "K'ojlab'l TzeÂ´ te Tnom Todos Santos CuchumatÃ¡n", 'Los Santos', 'Rancho Nuevo', 'San Sebastian', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'VolcÃ¡n Agua', 'VolcÃ¡n Pacaya']
# Blakea amplifolia
# Altitud mínima: 1200.00
# Altitud máxima: 1335.00
# Área de extensión de presencia (EOO): 52.75 km2
# Área de ocupación (AOO): 8.00 km2
# Países no ordenados: {'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Las Orquideas', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Blakea austin-smithii
# Altitud mínima: 0.00
# Altitud máxima: 2200.00
# Área de extensión de presencia (EOO): 3228.77 km2
# Área de ocupación (AOO): 104.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Braulio Carrillo', 'Juan Castro Blanco', 'Rincon de la Vieja', 'Rio Toro', 'Volcan Tenorio']
# Blakea chlorantha
# Altitud mínima: 900.00
# Altitud máxima: 2100.00
# Área de extensión de presencia (EOO): 5683.71 km2
# Área de ocupación (AOO): 92.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'El Chayote', 'Guanacaste', 'Rincon de la Vieja', 'Volcan Tenorio']
# Blakea grandiflora
# Altitud mínima: 0.00
# Altitud máxima: 2750.00
# Área de extensión de presencia (EOO): 99013.62 km2
# Área de ocupación (AOO): 284.00 km2
# Países no ordenados: {'PA', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Fortuna', 'Internacional La Amistad', 'Juan Castro Blanco', 'La Amistad', 'La Planada', 'Las Tablas', 'Reserva de la BiÃ³sfera de La Amistad', 'Rincon de la Vieja', 'Rio Macho', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Tenorio']
# Blakea henripittieri
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1121863.35 km2
# Área de ocupación (AOO): 796.00 km2
# Países no ordenados: {'CR', 'CO', 'PA', 'PE', 'EC'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'EC', 'PA', 'PE']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Antisana', 'Arenal Monteverde', 'Barbilla', 'Braulio Carrillo', 'Canones de los rios Melcocho y Santo Domingo', 'Darien National Park', 'DariÃ©n', 'De Bitaco', 'De Urrao', 'Fortuna', 'Internacional La Amistad', 'Juan Castro Blanco', 'La Amistad', 'La Planada', 'Las Orquideas', 'Llanganates', 'Los Santos', 'Mache Chindul', 'Palo Seco', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Banano', 'Sangay', 'Sangay National Park', 'Santa Fe', 'Sumaco', 'Sumaco Napo-Galeras', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Blakea wilsoniorum
# Altitud mínima: 1070.00
# Altitud máxima: 1750.00
# Área de extensión de presencia (EOO): 7373.50 km2
# Área de ocupación (AOO): 36.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Estero Puntarenas y Manglares Asociados', 'Laguna de VolcÃ¡n']
# Bourreria andrieuxii
# Altitud mínima: 0.00
# Altitud máxima: 2600.00
# Área de extensión de presencia (EOO): 1734858.64 km2
# Área de ocupación (AOO): 1140.00 km2
# Países no ordenados: {'CR', 'HN', 'MX', 'NI', 'GT'}
# Países (ordenados) con registros de presencia: ['CR', 'GT', 'HN', 'MX', 'NI']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Bahia Junquillal', 'CaÃ±Ã³n del Sumidero', 'Cerro El Arenal', 'Cerro Meyapac', 'Chamela-Cuixmala', 'Cuenca Alimentadora del Distrito Nacional de Riego 043 Estado de Nayarit', 'Cuencas y corales de la zona costera de Huatulco', 'El Zapotal', 'Huatulco', 'Islas La Pajarera, Cocinas, Mamut, Colorada, San Pedro, San AgustÃ\xadn, San AndrÃ©s y Negrita y los Islotes Los Anegados, Novillas, Mosca y Submarino', 'Miraflor/Moropotente', 'Parque Nacional CaÃ±Ã³n del Sumidero', 'Reserva Comunal Mascalco', 'Reserva de la Biosfera Chamela-Cuixmala', 'Santa Rosa', 'TehuacÃ¡n-CuicatlÃ¡n', 'TehuacÃ¡n-CuicatlÃ¡n Valley', 'Ã\x81rea Comunitaria Protegida de San Isidro']
# Bourreria grandicalyx
# Altitud mínima: 20.00
# Altitud máxima: 350.00
# Área de extensión de presencia (EOO): 333.68 km2
# Área de ocupación (AOO): 36.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Golfo Dulce', 'Terraba-Sierpe']
# Bourreria grayumii
# Altitud mínima: 40.00
# Altitud máxima: 1100.00
# Área de extensión de presencia (EOO): 15770.81 km2
# Área de ocupación (AOO): 80.00 km2
# Países no ordenados: {'NI', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'NI']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Cano Negro', 'CaÃ±o Negro', 'Guanacaste', 'Sureste de Nicaragua']
# Bourreria rinconensis
# Altitud mínima: 1.00
# Altitud máxima: 200.00
# Área de extensión de presencia (EOO): 2138.05 km2
# Área de ocupación (AOO): 44.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Piedras Blancas']
# Brunellia costaricensis
# Altitud mínima: 0.00
# Altitud máxima: 2950.00
# Área de extensión de presencia (EOO): 11606.14 km2
# Área de ocupación (AOO): 236.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Cerro de Escazu', 'Cordillera Volcanica Central', 'Curi cancha', 'Internacional La Amistad', 'La Amistad', 'Los Quetzales', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Macho', 'Rio Navarro-Rio Sombrero', 'Rio Toro', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan Poas']
# Brunellia standleyana
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 55764.94 km2
# Área de ocupación (AOO): 96.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Arenal Monteverde', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'NarganÃ¡', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Bunchosia costaricensis
# Altitud mínima: 550.00
# Altitud máxima: 1500.00
# Área de extensión de presencia (EOO): 9534.07 km2
# Área de ocupación (AOO): 60.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Braulio Carrillo', 'Guanacaste', 'Rio Banano', 'Volcan Tenorio']
# Bunchosia grayumii
# Altitud mínima: 40.00
# Altitud máxima: 850.00
# Área de extensión de presencia (EOO): 8951.42 km2
# Área de ocupación (AOO): 72.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Barbilla', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Hitoy Cerere', 'Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Bunchosia lanieri
# Altitud mínima: 45.00
# Altitud máxima: 310.00
# Área de extensión de presencia (EOO): 8279.78 km2
# Área de ocupación (AOO): 36.00 km2
# Países no ordenados: {'HN', 'BZ', 'GT'}
# Países (ordenados) con registros de presencia: ['BZ', 'GT', 'HN']
# Áreas protegidas con registros de presencia: ['Cerro San Gil', 'Lancetilla']
# Bunchosia mesoamericana
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 100276.48 km2
# Área de ocupación (AOO): 136.00 km2
# Países no ordenados: {'CR', 'HN', 'SV', 'NI', 'GT'}
# Países (ordenados) con registros de presencia: ['CR', 'GT', 'HN', 'NI', 'SV']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Complejo Laguna GÃ¼ija', 'Guanacaste', 'La Tigra', 'Miraflor/Moropotente', 'Palo Verde', 'Rincon de la Vieja', 'San Diego La Barra, laguna, cerro, San felipe (12)', 'Santa Rosa']
# Bunchosia ternata
# Altitud mínima: 700.00
# Altitud máxima: 2430.00
# Área de extensión de presencia (EOO): 30140.13 km2
# Área de ocupación (AOO): 140.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Fortuna', 'Internacional La Amistad', 'La Amistad', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº']
# Bunchosia ursana
# Altitud mínima: 20.00
# Altitud máxima: 2250.00
# Área de extensión de presencia (EOO): 19465.89 km2
# Área de ocupación (AOO): 180.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Cerro de Escazu', 'Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Golfito', 'Golfo Dulce', 'Hitoy Cerere', 'La Cangreja', 'Piedras Blancas', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Bunchosia veluticarpa
# Altitud mínima: 550.00
# Altitud máxima: 1450.00
# Área de extensión de presencia (EOO): 11165.09 km2
# Área de ocupación (AOO): 80.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Cordillera Volcanica Central', 'Guanacaste', 'Rincon de la Vieja']
# Bunchosia volcanica
# Altitud mínima: 419.10
# Altitud máxima: 1650.00
# Área de extensión de presencia (EOO): 587.30 km2
# Área de ocupación (AOO): 48.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Guanacaste', 'Rincon de la Vieja', 'Volcan Tenorio']
# Bursera glabra
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 3608523.18 km2
# Área de ocupación (AOO): 108.00 km2
# Países no ordenados: {'VE', 'CR', 'CO', 'BS', 'EC', 'NI'}
# Países (ordenados) con registros de presencia: ['BS', 'CO', 'CR', 'EC', 'NI', 'VE']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Palo Verde', 'Santa Rosa', 'Sierra Nevada']
# Bursera standleyana
# Altitud mínima: 0.00
# Altitud máxima: 600.00
# Área de extensión de presencia (EOO): 9374.08 km2
# Área de ocupación (AOO): 92.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Golfo Dulce', 'La Cangreja', 'Piedras Blancas', 'Terraba-Sierpe']
# Byrsonima herrerae
# Altitud mínima: 450.00
# Altitud máxima: 1700.00
# Área de extensión de presencia (EOO): 9881.87 km2
# Área de ocupación (AOO): 40.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Fortuna', 'Internacional La Amistad', 'Rio Banano', 'Rio Macho', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Calliandra goldmanii
# Calliandra grandifolia
# Altitud mínima: 0.00
# Altitud máxima: 2440.00
# Área de extensión de presencia (EOO): 808374.10 km2
# Área de ocupación (AOO): 136.00 km2
# Países no ordenados: {'NI', 'MX', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'MX', 'NI']
# Áreas protegidas con registros de presencia: ['CaÃ±Ã³n del RÃ\xado Blanco', 'CaÃ±Ã³n del Sumidero', 'Cerro Saslaya', 'Golfo Dulce', 'Indio Maiz', 'La Primavera', 'Parque Nacional CaÃ±Ã³n del Sumidero', 'Piedras Blancas', 'Sureste de Nicaragua']
# Caryodaphnopsis burgeri
# Altitud mínima: 10.00
# Altitud máxima: 900.00
# Área de extensión de presencia (EOO): 189979.74 km2
# Área de ocupación (AOO): 128.00 km2
# Países no ordenados: {'PA', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Cerro Nara', 'Corcovado', 'Del Rio Minero y sus Zonas Aledanas', 'Golfo Dulce', 'La Cangreja', 'Los Santos', 'NarganÃ¡', 'Piedras Blancas']
# Cavanillesia platanifolia
# Altitud mínima: 10.00
# Altitud máxima: 650.00
# Área de extensión de presencia (EOO): 1452886.25 km2
# Área de ocupación (AOO): 340.00 km2
# Países no ordenados: {'CR', 'CO', 'PA', 'PE', 'EC'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'EC', 'PA', 'PE']
# Áreas protegidas con registros de presencia: ['Barro Colorado', 'Bosques de Paz', 'CanglÃ³n', 'Cerros de Amotape', 'Chagres', 'Darien', 'Darien National Park', 'DariÃ©n', 'Encanto de los manglares del Bajo Baudo', 'La Tronosa', 'Los Colorados', 'Los Katios', 'Los KatÃ\xados National Park', 'Palo Verde', 'Serrania de Coraza y Montes de Maria', 'SerranÃ\xada Filo del Tallo', 'Soberania']
# Chamaedorea deckeriana
# Altitud mínima: 1.00
# Altitud máxima: 1250.00
# Área de extensión de presencia (EOO): 250791.60 km2
# Área de ocupación (AOO): 436.00 km2
# Países no ordenados: {'NI', 'PA', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Arenal', 'Arenal Monteverde', 'Barra del Colorado', 'Braulio Carrillo', 'Carauta', 'Chagres', 'Cordillera Volcanica Central', 'Fortuna', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Humedal Caribe Noreste', 'Indio Maiz', 'Internacional La Amistad', 'La Cangreja', 'La Selva', 'Maquenque', 'NarganÃ¡', 'Palo Seco', 'Piedras Blancas', 'Punta Gorda', 'Rio Banano', 'Rio Pacuare', 'RÃ\xado San Juan', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tenorio', 'Tortuguero']
# Chrysochlamys skutchii
# Altitud mínima: 0.00
# Altitud máxima: 1300.00
# Área de extensión de presencia (EOO): 29756.01 km2
# Área de ocupación (AOO): 124.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Corcovado', 'Donoso', 'Golfo Dulce', 'Los Santos', 'Piedras Blancas']
# Clethra formosa
# Altitud mínima: 1475.00
# Altitud máxima: 3400.00
# Área de extensión de presencia (EOO): 35758.76 km2
# Área de ocupación (AOO): 84.00 km2
# Países no ordenados: {'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cordillera Volcanica Central', 'Internacional La Amistad', 'Las Tablas', 'Los Quetzales', 'Los Santos', 'Rio Macho', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Clethra talamancana
# Altitud mínima: 2250.00
# Altitud máxima: 2700.00
# Área de extensión de presencia (EOO): 2648.22 km2
# Área de ocupación (AOO): 28.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Internacional La Amistad', 'Los Santos', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Clidemia costaricensis
# Altitud mínima: 0.00
# Altitud máxima: 1875.00
# Área de extensión de presencia (EOO): 342904.17 km2
# Área de ocupación (AOO): 296.00 km2
# Países no ordenados: {'PA', 'MX', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'MX', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Chirripo', 'Cordillera Volcanica Central', 'Fortuna', 'Golfo Dulce', 'Guanacaste', 'Internacional La Amistad', 'La Amistad', 'Lagunas de Montebello', 'NarganÃ¡', 'Parque Nacional Lagunas de Montebello', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Banano', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Tenorio', 'Volcan Tenorio']
# Clusia cylindrica
# Altitud mínima: 1.00
# Altitud máxima: 2170.00
# Área de extensión de presencia (EOO): 1292470.32 km2
# Área de ocupación (AOO): 424.00 km2
# Países no ordenados: {'CO', 'CR', 'PA', 'EC', 'NI'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'EC', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Amacayacu', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Barra del Colorado', 'Bosques Andinos Humedos el Rasgon', 'Braulio Carrillo', 'Cerro Musun', 'Cerro Silva', 'Chagres', 'Cordillera Volcanica Central', 'Corredor Fronterizo', 'Donoso', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Golfito', 'Golfo Dulce', 'Guanacaste', 'Humedal Caribe Noreste', 'Indio Maiz', 'Isla Bastimentos', 'La Selva', 'Maquenque', 'NarganÃ¡', 'Palo Seco', 'Piedras Blancas', 'Punchina', 'Rincon de la Vieja', 'RÃ\xado San Juan', 'Santa Fe', 'Sureste de Nicaragua', 'Tortuguero', 'Zona de Amortiguamiento (Bosawas)']
# Clusia rotundata
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1702929.32 km2
# Área de ocupación (AOO): 272.00 km2
# Países no ordenados: {'VE', 'CR', 'CO', 'PA', 'EC'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'EC', 'PA', 'VE']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Chagres', 'Chirripo', 'Farallones de Cali', 'Internacional La Amistad', 'La Tebaida', 'Las Orquideas', 'Las Tablas', 'Llanganates', 'Los Santos', 'PenÃ\xadnsula de Paria', 'Rio Anchicaya', 'Rio Macho', 'RÃ\xados Guanare, BoconÃ³, Tucupido, La Yuca y Masparro', 'Santa Fe', 'Sierra de Aroa', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº', 'Volcan Poas']
# Clusia torresii
# Altitud mínima: 50.00
# Altitud máxima: 2000.00
# Área de extensión de presencia (EOO): 272338.45 km2
# Área de ocupación (AOO): 284.00 km2
# Países no ordenados: {'NI', 'MX', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'MX', 'NI']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Barbilla', 'Braulio Carrillo', 'Caraigres', 'Cerro Cola Blanca', 'Cerro Musun', 'Cordillera Volcanica Central', 'Juan Castro Blanco', 'Los Santos', 'Miravalles', 'Rincon de la Vieja', 'Rio Navarro-Rio Sombrero', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Tenorio', 'Volcan Tenorio']
# Clusia valerii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1502484.72 km2
# Área de ocupación (AOO): 304.00 km2
# Países no ordenados: {'CO', 'CR', 'PA', 'US', 'NI'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'NI', 'PA', 'US']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Barra del Colorado', 'Cerro Silva', 'Chagres', 'Corcovado', 'Darien National Park', 'DariÃ©n', 'Donoso', 'Fernando Castro Cervantes', 'Fortuna', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Golfo Dulce', 'Humedal Caribe Noreste', 'La Cangreja', 'NarganÃ¡', 'Osa', 'Piedras Blancas', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Tortuguero']
# Cnidoscolus megacanthus
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 20473.98 km2
# Área de ocupación (AOO): 168.00 km2
# Países no ordenados: {'MX'}
# Países (ordenados) con registros de presencia: ['MX']
# Áreas protegidas con registros de presencia: ['Cuencas y corales de la zona costera de Huatulco', 'Huatulco']
# Cojoba costaricensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 83423.14 km2
# Área de ocupación (AOO): 296.00 km2
# Países no ordenados: {'SV', 'PA', 'MX', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'MX', 'PA', 'SV']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Cerro de Escazu', 'Cerros de La Carpintera', 'Cerros de Turrubares', 'Cordillera Volcanica Central', 'Curi cancha', 'Grecia', 'Guanacaste', 'Internacional La Amistad', 'La Cangreja', 'Los Santos', 'Rincon de la Vieja', 'Rio Navarro-Rio Sombrero', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº', 'Volcan Tenorio']
# Colpothrinax aphanopetala
# Altitud mínima: 365.00
# Altitud máxima: 1400.00
# Área de extensión de presencia (EOO): 60520.80 km2
# ...
# Trichilia pittieri
# Altitud mínima: 200.00
# Altitud máxima: 2040.00
# Área de extensión de presencia (EOO): 743552.44 km2
# Área de ocupación (AOO): 120.00 km2
# Países no ordenados: {'EC', 'CR', 'PE'}
# Países (ordenados) con registros de presencia: ['CR', 'EC', 'PE']
# Áreas protegidas con registros de presencia: ['Limoncocha', 'Miravalles', 'Reserva BiolÃ³gica Limoncocha', 'Reserva de la BiÃ³sfera de Yasuni', 'Rio Banano', 'Yanesha', 'YasunÃ\xad']
# Triumfetta arborescens
# Altitud mínima: 800.00
# Altitud máxima: 1250.00
# Área de extensión de presencia (EOO): 4574.16 km2
# Área de ocupación (AOO): 20.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['El Rodeo']
# Trophis involucrata
# Altitud mínima: 0.00
# Altitud máxima: 1100.00
# Área de extensión de presencia (EOO): 33698.33 km2
# Área de ocupación (AOO): 300.00 km2
# Países no ordenados: {'NI', 'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Barbilla', 'Braulio Carrillo', 'Cerros de Turrubares', 'Cordillera Volcanica Central', 'Gandoca-Manzanillo', 'Guanacaste', 'Hitoy Cerere', 'Indio Maiz', 'La Selva', 'Lapa Verde', 'Maquenque', 'Rio Pacuare', 'RÃ\xado San Juan', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan Tenorio']
# Uribea tamarindoides
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1123143.67 km2
# Área de ocupación (AOO): 140.00 km2
# Países no ordenados: {'MX', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'MX']
# Áreas protegidas con registros de presencia: ['Carara', 'Corcovado', 'Golfo Dulce', 'Los Colorados', 'Los Tuxtlas']
# Vaccinium consanguineum
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 478152.94 km2
# Área de ocupación (AOO): 692.00 km2
# Países no ordenados: {'HN', 'PA', 'MX', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'HN', 'MX', 'PA']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cacique Lempira, SenÌ\x83or de las MontanÌ\x83as', 'Caraigres', 'Cerro Las Vueltas', 'Cerro de Escazu', 'Chirripo', 'Cordillera Volcanica Central', 'El Chayote', 'Internacional La Amistad', 'La Amistad', 'La Tierra del FaisÃ¡n', 'Las Tablas', 'Los Quetzales', 'Los Santos', 'MontaÃ±a de Celaque', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Macho', 'Rio Toro', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº', 'Volcan Irazu', 'Volcan Poas', 'Volcan Turrialba']
# Vachellia mayana
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 296489.69 km2
# Área de ocupación (AOO): 232.00 km2
# Países no ordenados: {'MX', 'GT'}
# Países (ordenados) con registros de presencia: ['GT', 'MX']
# Áreas protegidas con registros de presencia: ['CaÃ±Ã³n del Usumacinta', 'La Encrucijada', 'Los Tuxtlas', 'Montes Azules', 'Palenque', 'Reserva de la Biosfera La Encrucijada', 'Zona de ProtecciÃ³n Forestal en los terrenos que se encuentran en los municipios de La Concordia, Angel Albino Corzo, Villa Flores y Jiquipilas']
# Verbesina tapantiana
# Altitud mínima: 600.00
# Altitud máxima: 2208.00
# Área de extensión de presencia (EOO): 1749.62 km2
# Área de ocupación (AOO): 40.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Virola surinamensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 66445908.64 km2
# Área de ocupación (AOO): 1820.00 km2
# Países no ordenados: {'VE', 'BR', 'CO', 'CR', 'BO', 'PA', 'GY', 'SR', 'MX', 'PE', 'ZA', 'ID', 'EC', 'TT', 'GF'}
# Países (ordenados) con registros de presencia: ['BO', 'BR', 'CO', 'CR', 'EC', 'GF', 'GY', 'ID', 'MX', 'PA', 'PE', 'SR', 'TT', 'VE', 'ZA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Alto Orinoco-Casiquiare', 'Amazon Estuary and its Mangroves', 'Ampiyacu Apayacu', 'Arenal Monteverde', 'Barro Colorado', 'Cahuinari', 'Canaima', 'Canaima National Park', 'Capoto/Jarina', 'Carara', 'Central Amazon Conservation Complex', 'Central Suriname', 'Central Suriname Nature Reserve', 'Chagres', 'Complejo de Humedales Cuyabeno Lagartococha YasunÃ\xad', 'Corcovado', 'Cuyabeno', 'Delta del Orinoco', 'Ebio Kiabamene', 'El Caura', 'EstaÃ§Ã£o EcolÃ³gica De MaracÃ¡', 'Estero Puntarenas y Manglares Asociados', 'Floresta Nacional De CaxiuanÃ£', 'Floresta Nacional De Purus', 'Floresta Nacional De SaracÃ¡-Taquera', 'Floresta Nacional De TapajÃ³s', 'Formaciones de Tepuyes', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Golfito', 'Golfo Dulce', 'Guarapiche', "Guyane (parc amazonien) [aire d'adhÃ©sion]", 'Hacienda Villa Mery', 'Hitoy Cerere', 'Imataca', 'Itixi Mitari', 'Iwokrama', 'Jaua SarisariÃ±ama', 'Kanashen', 'Kanuku Mountains Protected Area', 'KayapÃ³', 'Kraolandia', 'Limoncocha', 'Long Stretch Reserve', 'Madidi', 'Manuripi', 'MÃ©dio Rio Negro I', 'NarganÃ¡', 'Nouragues', 'Osa', 'Pacaya - Samiria', 'Pacaya Samiria', 'Palo Seco', 'Parque Estadual Do Bacanga', 'Parque Estadual Do Utinga', 'Parque Estadual Serra Do AracÃ¡', 'Parque Estadual Serra Do Ouro Branco', 'Parque Nacional De Sete Cidades', 'Parque Nacional Do Cabo Orange', 'Parque Nacional Do JaÃº', 'Parque Nacional Do Juruena', 'Parque Nacional Montanhas Do Tumucumaque', 'Parque do Xingu', 'Paumari do Lago MarahÃ£', 'Piedras Blancas', 'Reentrancias Maranhenses', 'Reserva BiolÃ³gica Limoncocha', 'Reserva De Desenvolvimento SustentÃ¡vel Do UatumÃ£', 'Reserva Extrativista Alto JuruÃ¡', 'Reserva Extrativista Do Rio Unini', 'Reserva de la BiÃ³sfera de Yasuni', 'Rio Negro', 'San Pedro', 'Santa Inez', 'Serrania de Chiribiquete', 'SerranÃ\xada de la Neblina', 'Sipapo', 'Sur del Estado BolÃ\xadvar', 'SÃ£o Gabriel/SÃ£o Salvador', 'SÃ£o Marcos - RR', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tambopata', 'Tequeje', 'Trombetas/Mapuera', 'UaÃ§a', 'Yanachaga - ChemillÃ©n', 'Yanesha', 'Yanomami', 'YasunÃ\xad', 'de la Playona y la Loma de Caleta', 'Ã\x81rea De ProteÃ§Ã£o Ambiental  Tapuruquara', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Da RegiÃ£o Metrolpolitana De BelÃ©m', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Das ReentrÃ¢ncias Maranhenses', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Do ArquipÃ©lago Do MarajÃ³', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Ilha Do Bananal/CantÃ£o', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Serra Da Ibiapaba', 'Ã\x81rea De Relevante Interesse EcolÃ³gico Japiim Pentecoste']
# Vitex cooperi
# Altitud mínima: 0.00
# Altitud máxima: 1500.00
# Área de extensión de presencia (EOO): 903370.22 km2
# Área de ocupación (AOO): 448.00 km2
# Países no ordenados: {'CR', 'HN', 'PA', 'MX', 'NI', 'GT'}
# Países (ordenados) con registros de presencia: ['CR', 'GT', 'HN', 'MX', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Barra del Colorado', 'Barro Colorado', 'Carara', 'Cerro Musun', 'Cerro Nara', 'Cerro Wawashang', 'Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Golfo Dulce', 'Guanacaste', 'Indio Maiz', 'La Cangreja', 'La Selva', 'Lancetilla', 'Manuel Antonio', 'Maquenque', 'Palo Seco', 'Piedras Blancas', 'RÃ\xado San Juan', 'Santa Fe', 'Sierra Quirragua', 'Sureste de Nicaragua']
# Weinmannia karsteniana
# Altitud mínima: 2200.00
# Altitud máxima: 3300.00
# Área de extensión de presencia (EOO): 1106405.95 km2
# Área de ocupación (AOO): 88.00 km2
# Países no ordenados: {'VE', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'VE']
# Áreas protegidas con registros de presencia: ['Cerro Pintao - Serrania del Perija', 'Cerro Saroche', 'Guaramacal', 'Los Santos', 'Rio Macho', 'Rio Navarro-Rio Sombrero', 'Sureste del Lago de Maracaibo Sto. Domingo-MotatÃ¡n', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Weinmannia polyphylla
# Altitud mínima: 2150.00
# Altitud máxima: 2850.00
# Área de extensión de presencia (EOO): 115189.87 km2
# Área de ocupación (AOO): 48.00 km2
# Países no ordenados: {'EC', 'CO'}
# Países (ordenados) con registros de presencia: ['CO', 'EC']
# Áreas protegidas con registros de presencia: ['Nevado del Huila', 'Podocarpus', 'Podocarpus-El Condor']
# Weinmannia vulcanicola
# Altitud mínima: 1565.00
# Altitud máxima: 2874.00
# Área de extensión de presencia (EOO): 4260.41 km2
# Área de ocupación (AOO): 64.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Internacional La Amistad', 'Los Santos', 'Rio Toro', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan Poas']
# Wercklea insignis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 15555.50 km2
# Área de ocupación (AOO): 176.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal', 'Arenal Monteverde', 'Braulio Carrillo', 'Fortuna', 'Rincon de la Vieja', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan Tenorio']
# Wercklea lutea
# Altitud mínima: 700.00
# Altitud máxima: 2900.00
# Área de extensión de presencia (EOO): 26748.50 km2
# Área de ocupación (AOO): 84.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cordillera Volcanica Central', 'Internacional La Amistad', 'Los Santos', 'Palo Seco', 'Rio Toro', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Wercklea woodsonii
# Altitud mínima: 762.00
# Altitud máxima: 2900.00
# Área de extensión de presencia (EOO): 17363.96 km2
# Área de ocupación (AOO): 144.00 km2
# Países no ordenados: {'PA', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'La Amistad', 'Las Tablas', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº']
# Williamodendron glaucophyllum
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 54950.44 km2
# Área de ocupación (AOO): 68.00 km2
# Países no ordenados: {'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Golfo Dulce', 'La Cangreja', 'Punta Rio Claro']
# Wimmeria sternii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 435174.32 km2
# Área de ocupación (AOO): 84.00 km2
# Países no ordenados: {'NI', 'PA', 'MX', 'CR'}
# Países (ordenados) con registros de presencia: ['CR', 'MX', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['CaÃ±Ã³n del Sumidero', 'Cerro El Arenal', 'Las Tablas', 'Parque Nacional CaÃ±Ã³n del Sumidero', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'TehuacÃ¡n-CuicatlÃ¡n', 'TehuacÃ¡n-CuicatlÃ¡n Valley', 'Volcan BarÃº']
# Zygia brenesii
# Altitud mínima: 0.00
# Altitud máxima: 1750.00
# Área de extensión de presencia (EOO): 13394.23 km2
# Área de ocupación (AOO): 256.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal', 'Arenal Monteverde', 'Braulio Carrillo', 'Cerro de Escazu', 'Cerros de Turrubares', 'Guanacaste', 'La Cangreja', 'Palo Verde', 'Rincon de la Vieja', 'Tenorio', 'Volcan Tenorio']
# Zygia confusa
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 21664.61 km2
# Área de ocupación (AOO): 60.00 km2
# Países no ordenados: {'NI', 'BZ', 'CR'}
# Países (ordenados) con registros de presencia: ['BZ', 'CR', 'NI']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Bladen', 'Indio Maiz', 'Maquenque', 'Sureste de Nicaragua']
# Zygia gigantifoliola
# Altitud mínima: 1.00
# Altitud máxima: 1600.00
# Área de extensión de presencia (EOO): 139204.06 km2
# Área de ocupación (AOO): 164.00 km2
# Países no ordenados: {'NI', 'PA', 'CO', 'CR'}
# Países (ordenados) con registros de presencia: ['CO', 'CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Barra del Colorado', 'Braulio Carrillo', 'CaÃ±o Negro', 'Corcovado', 'Donoso', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Hitoy Cerere', 'Humedal Caribe Noreste', 'Indio Maiz', 'La Selva', 'Maquenque', 'Paramillo', 'RÃ\xado San Juan', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero']
# Zygia rubiginosa
# Altitud mínima: 20.00
# Altitud máxima: 600.00
# Área de extensión de presencia (EOO): 143.84 km2
# Área de ocupación (AOO): 44.00 km2
# Países no ordenados: {'CR'}
# Países (ordenados) con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Golfo Dulce']

# %%
a
# Out:
# array([[-9288065.39029105,   975976.76177299],
#        [-9272913.58307969,   977853.92961681]])

# %%
np.unique(a)
# Out:
# array([-9288065.39029105, -9272913.58307969,   975976.76177299,
#          977853.92961681])

# %%
np.unique(a, axis=0)
# Out:
# array([[-9288065.39029105,   975976.76177299],
#        [-9272913.58307969,   977853.92961681]])

# %%
len(a)
# Out:
# 2
