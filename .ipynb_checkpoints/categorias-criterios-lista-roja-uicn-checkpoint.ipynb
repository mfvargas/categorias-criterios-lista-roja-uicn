# %% [markdown]
# # Categorías y criterios de la Lista Roja de la UICN

# %% [markdown]
# Este [Jupyter Notebook](https://jupyter.org/), desarrollado en el lenguaje de programación [Python](https://www.python.org/), aplica las categorías y criterios de la [Lista Roja de la Unión Internacional para la Conservación de la Naturaleza (UICN)](https://www.iucnredlist.org/es/).

# %% [markdown]
# **Entradas**
# - Un archivo CSV con nombres científicos de especies.
#
# **Procesamiento**
# - Se obtienen las llaves (*keys*) de las especies en el [API de GBIF](https://www.gbif.org/developer/summary).
# - En caso de ser necesario, se filtran las llaves (ej. se conservan solo las de nombres que tengan coincidencia exacta o solo las de nombres aceptados).
# - Con base en la lista de llaves, se construye una consulta para el [portal de GBIF](https://www.gbif.org/).
# - El resultado de la consulta al portal se descarga y se renombra como "occurrences.csv".
# - Se recorre el archivo "occurrences.csv" para generar las salidas que se describen seguidamente.
#
# **Salidas**
#
# Para cada especie en el archivo de entrada, se genera:
# - Un registro en un archivo CSV con las siguientes columnas:
#   - Extensión de presencia (EOO).
#   - Área de ocupación (AOO).
#   - Lista de países con registros de presencia.
# - Un mapa de registros de presencia.
# - Un mapa de registros de presencia agrupados (en *clusters*).
# - Un mapa de calor.

# %% [markdown]
# **Bibliotecas de Python**

# %%
import requests
import json
import io

import csv

import pandas as pd
import geopandas as gpd
import numpy as np
from scipy.spatial import ConvexHull

import folium
from folium import plugins
from folium.plugins import HeatMapWithTime

import fiona
from shapely.geometry import shape, Point

from pyproj import Proj, transform

import matplotlib.pyplot as plt
# %matplotlib inline

import calendar

# El siguiente archivo debe estar en el mismo directorio que este notebook
from functions_query_from_species_list import *

# %% [markdown]
# **Constantes**

# %%
# Credenciales para el API de GBIF
GBIF_USER_NAME = "mvargas"
GBIF_PASSWORD = "grizabella"
GBIF_NOTIFICATION_ADDRESSES = "mvargas@inbio.ac.cr"
GBIF_DOWNLOAD_FORMAT = "SIMPLE_CSV"

# Proyecciones cartográficas para los cálculos de EOO y AOO
INPUT_PROJECTION = Proj(init='epsg:4326')
OUTPUT_PROJECTION = Proj(init='epsg:3857')

# Límites y dimensiones de la cuadrícula para el cálculo del AOO.
# Deben especificarse en las unidades del sistema espacial de referencia (SRS) que se utiliza.
# Por ejemplo, para el caso de Web Mercator (EPSG:3857), deben especificarse en metros.
# Límites de la cuadrícula
AOO_GRID_X_MIN = -15000000
AOO_GRID_X_MAX = -4000000
AOO_GRID_Y_MIN = -7000000
AOO_GRID_Y_MAX = 7000000
# Dimensiones de la cuadrícula
AOO_GRID_CELL_X_WIDTH = 2000
AOO_GRID_CELL_Y_WIDTH = 2000
AOO_GRID_CELL_AREA = AOO_GRID_CELL_X_WIDTH * AOO_GRID_CELL_Y_WIDTH

# Directorio de entrada
INPUT_DIR = "../evaluacion-arboles-mesoamerica/AMARANTHACEAE-AVICENNIACEAE/"

# Archivo CSV de entrada con lista de especies a procesar
INPUT_CHECKLIST = INPUT_DIR + "AMARANTHACEAE-AVICENNIACEAE-lista-especies.csv"
# Columna con el nombre científico de la especie
INPUT_SCINAME_COL = "Taxon Name"

# Archivo CSV con registros de presencia
OCCURRENCES_CSV = INPUT_DIR + "AMARANTHACEAE-AVICENNIACEAE-registros-presencia.csv"

# Directorio de salida
OUTPUT_DIR = "../evaluacion-arboles-mesoamerica/AMARANTHACEAE-AVICENNIACEAE/"
# Archivo CSV de salida
OUTPUT_CSV = OUTPUT_DIR + "AMARANTHACEAE-AVICENNIACEAE-evaluacion.csv"
# Archivo MD de salida
OUTPUT_MD = OUTPUT_DIR + "AMARANTHACEAE-AVICENNIACEAE-evaluacion.md"
# Archivo HTML de salida
OUTPUT_HTML = OUTPUT_DIR + "AMARANTHACEAE-AVICENNIACEAE-evaluacion.html"
# URL de salida
OUTPUT_BASE_URL = "https://evaluacion-arboles-mesoamerica.github.io/AMARANTHACEAE-AVICENNIACEAE/"

# Capa geoespacial de áreas protegidas
PROTECTED_AREAS_LAYER = "C:/Users/mfvargas/geodatos/wdpa/WDPA_Mesoamerica.shp"

# Número máximo de registros a desplegar en los dataframes de Pandas
pd.options.display.max_rows = 15

# %% [markdown]
# ## Carga de datos

# %%
# Carga del archivo CSV de entrada en un dataframe de Pandas
input_species_df = pd.read_csv(INPUT_CHECKLIST, encoding='latin-1')

input_species_df
# Out:
#            Family           Genus        Species                Taxon Name  \
# 0   AMARANTHACEAE   Pleuropetalum     pleiogynum  Pleuropetalum pleiogynum
# 1   ANACARDIACEAE  Amphipterygium          molle      Amphipterygium molle
# 2   ANACARDIACEAE        Tapirira       lepidota         Tapirira lepidota
# 3      ANNONACEAE      Anaxagorea     phaeocarpa     Anaxagorea phaeocarpa
# 4      ANNONACEAE          Annona     danforthii         Annona danforthii
# 5      ANNONACEAE    Cymbopetalum      torulosum    Cymbopetalum torulosum
# 6      ANNONACEAE       Mosannona  costaricensis   Mosannona costaricensis
# ..            ...             ...            ...                       ...
# 64     ASTERACEAE    Koanophyllon       hylonoma     Koanophyllon hylonoma
# 65     ASTERACEAE    Koanophyllon       pittieri     Koanophyllon pittieri
# 66     ASTERACEAE    Koanophyllon       wetmorei     Koanophyllon wetmorei
# 67     ASTERACEAE       Lepidonia     lankesteri      Lepidonia lankesteri
# 68     ASTERACEAE       Verbesina     tapantiana      Verbesina tapantiana
# 69  AVICENNIACEAE       Avicennia        bicolor         Avicennia bicolor
# 70  AVICENNIACEAE       Avicennia      germinans       Avicennia germinans
#
#    Category   Criteria  IUCN Assessment completed  \
# 0       NaN        NaN                        NaN
# 1         x        NaN                        NaN
# 2       NaN        NaN                        NaN
# 3        LC        NaN                        NaN
# 4        LC        NaN                        NaN
# 5        LC        NaN                        NaN
# 6        NT  B2ab(iii)                        NaN
# ..      ...        ...                        ...
# 64      NaN        NaN                        NaN
# 65      NaN        NaN                        NaN
# 66      NaN        NaN                        NaN
# 67      NaN        NaN                        NaN
# 68      NaN        NaN                        NaN
# 69       VU       A2cd                        NaN
# 70       LC        NaN                        NaN
#
#                                                 Notes  Endemic?  \
# 0                                                 NaN       NaN
# 1   Taxonomic Issue - not found in Costa Rica. Rem...       NaN
# 2                                                 NaN       NaN
# 3                                     1998 assessment       NaN
# 4                       1998 assessment not published       NaN
# 5                                     1998 assessment       NaN
# 6                                                 NaN       NaN
# ..                                                ...       ...
# 64                                                NaN       NaN
# 65                                                NaN       NaN
# 66                                                NaN       NaN
# 67                                                NaN       NaN
# 68                                                NaN       NaN
# 69                                    2008 assessment       NaN
# 70                                    2007 assessment       NaN
#
#     Information inputted into SIS  Assessment reviewed  Map completed  \
# 0                             NaN                  NaN            NaN
# 1                             NaN                  NaN            NaN
# 2                             NaN                  NaN            NaN
# 3                             NaN                  NaN            NaN
# 4                             NaN                  NaN            NaN
# 5                             NaN                  NaN            NaN
# 6                             NaN                  NaN            NaN
# ..                            ...                  ...            ...
# 64                            NaN                  NaN            NaN
# 65                            NaN                  NaN            NaN
# 66                            NaN                  NaN            NaN
# 67                            NaN                  NaN            NaN
# 68                            NaN                  NaN            NaN
# 69                            NaN                  NaN            NaN
# 70                            NaN                  NaN            NaN
#
#     Submitted to IUCN
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# ..                ...
# 64                NaN
# 65                NaN
# 66                NaN
# 67                NaN
# 68                NaN
# 69                NaN
# 70                NaN
#
# [71 rows x 13 columns]

# %% [markdown]
# Se consulta el API de GBIF para obtener las llaves (*keys*) de las especies

# %%
# Se obtienen las llaves de las especies a través del API de GBIF
gbif_species_df = match_species(input_species_df, INPUT_SCINAME_COL)

gbif_species_df[['inputName', 'species', 'genus', 'family', 'matchType', 'status', 'synonym', 'speciesKey', 'usageKey', 'rank', 'alternatives']]
# Out:
#                    inputName                   species           genus  \
# 0   Pleuropetalum pleiogynum  Pleuropetalum pleiogynum   Pleuropetalum
# 1       Amphipterygium molle      Amphipterygium molle  Amphipterygium
# 2          Tapirira lepidota         Tapirira lepidota        Tapirira
# 3      Anaxagorea phaeocarpa     Anaxagorea phaeocarpa      Anaxagorea
# 4          Annona danforthii         Annona danforthii          Annona
# 5     Cymbopetalum torulosum    Cymbopetalum torulosum    Cymbopetalum
# 6    Mosannona costaricensis   Mosannona costaricensis       Mosannona
# ..                       ...                       ...             ...
# 64     Koanophyllon hylonoma     Koanophyllon hylonoma    Koanophyllon
# 65     Koanophyllon pittieri     Koanophyllon pittieri    Koanophyllon
# 66     Koanophyllon wetmorei     Koanophyllon wetmorei    Koanophyllon
# 67      Lepidonia lankesteri      Lepidonia lankesteri       Lepidonia
# 68      Verbesina tapantiana      Verbesina tapantiana       Verbesina
# 69         Avicennia bicolor         Avicennia bicolor       Avicennia
# 70       Avicennia germinans       Avicennia germinans       Avicennia
#
#            family matchType    status  synonym  speciesKey  usageKey     rank  \
# 0   Amaranthaceae     EXACT  ACCEPTED    False     3673624   3673624  SPECIES
# 1   Anacardiaceae     EXACT  ACCEPTED    False     7881320   7881320  SPECIES
# 2   Anacardiaceae     EXACT  ACCEPTED    False     7632788   7632788  SPECIES
# 3      Annonaceae     EXACT  ACCEPTED    False     3156862   3156862  SPECIES
# 4      Annonaceae     EXACT  ACCEPTED    False     5541648   5541648  SPECIES
# 5      Annonaceae     EXACT  ACCEPTED    False     3157865   3157865  SPECIES
# 6      Annonaceae     EXACT  ACCEPTED    False     3158156   3158156  SPECIES
# ..            ...       ...       ...      ...         ...       ...      ...
# 64     Asteraceae     EXACT  ACCEPTED    False     3145047   3145047  SPECIES
# 65     Asteraceae     EXACT  ACCEPTED    False     3144979   3144979  SPECIES
# 66     Asteraceae     EXACT  ACCEPTED    False     3145039   3145039  SPECIES
# 67     Asteraceae     EXACT  ACCEPTED    False     3088906   3088906  SPECIES
# 68     Asteraceae     EXACT  ACCEPTED    False     3147875   3147875  SPECIES
# 69    Acanthaceae     EXACT  ACCEPTED    False     4196610   4196610  SPECIES
# 70    Acanthaceae     EXACT  ACCEPTED    False     2925400   2925400  SPECIES
#
#                                          alternatives
# 0                                                NULL
# 1   [{'usageKey': 3661179, 'acceptedUsageKey': 788...
# 2                                                NULL
# 3                                                NULL
# 4                                                NULL
# 5                                                NULL
# 6                                                NULL
# ..                                                ...
# 64                                               NULL
# 65                                               NULL
# 66                                               NULL
# 67                                               NULL
# 68                                               NULL
# 69                                               NULL
# 70  [{'usageKey': 7782491, 'acceptedUsageKey': 292...
#
# [71 rows x 11 columns]

# %%
# Se separa la lista de llaves

# Se filtran las llaves (en caso de ser necesario)
key_list = gbif_species_df.loc[(gbif_species_df["matchType"]=="EXACT") & (gbif_species_df["status"]=="ACCEPTED")].usageKey.tolist()
# key_list = gbif_taxa_df.usageKey.tolist()

key_list
# Out:
# [3673624,
#  7881320,
#  7632788,
#  3156862,
#  5541648,
#  3157865,
#  3158156,
#  3157812,
#  3157070,
#  3617666,
#  3621126,
#  7425200,
#  7661037,
#  5533815,
#  5534036,
#  5534548,
#  5534472,
#  5534080,
#  3035205,
#  3035162,
#  3035053,
#  3035192,
#  3035040,
#  3036743,
#  3036754,
#  3036602,
#  3036528,
#  6307010,
#  3036755,
#  3036648,
#  3036542,
#  3038090,
#  3038213,
#  3038725,
#  3037796,
#  3038409,
#  3038452,
#  3038458,
#  3038540,
#  3038453,
#  2738670,
#  2738123,
#  2738088,
#  2738130,
#  2733338,
#  2733340,
#  2733382,
#  2732907,
#  2733373,
#  2732932,
#  2734403,
#  2736925,
#  2731948,
#  2731932,
#  2731924,
#  2734229,
#  2734302,
#  2734051,
#  2734052,
#  9444565,
#  5294718,
#  3134409,
#  3139463,
#  3119954,
#  3145047,
#  3144979,
#  3145039,
#  3088906,
#  3147875,
#  4196610,
#  2925400]

# %% [markdown]
# Se construye una consulta para descarga en el portal de GBIF

# %%
# Se construye una consulta para descarga en el portal de GBIF
download_query = {}
download_query["creator"] = GBIF_USER_NAME
download_query["notificationAddresses"] = [GBIF_NOTIFICATION_ADDRESSES]
download_query["sendNotification"] = True
download_query["format"] = GBIF_DOWNLOAD_FORMAT
download_query["predicate"] =   {"type":"and", "predicates": 
                                 [
                                    {"type":"equals", "key":"HAS_COORDINATE",       "value":"true"},
                                    {"type":"equals", "key":"HAS_GEOSPATIAL_ISSUE", "value":"false"}, 
                                    {"type":"in",     "key": "TAXON_KEY",           "values":key_list}
                                 ]
                                }

download_query
# Out:
# {'creator': 'mvargas',
#  'notificationAddresses': ['mvargas@inbio.ac.cr'],
#  'sendNotification': True,
#  'format': 'SIMPLE_CSV',
#  'predicate': {'type': 'and',
#   'predicates': [{'type': 'equals', 'key': 'HAS_COORDINATE', 'value': 'true'},
#    {'type': 'equals', 'key': 'HAS_GEOSPATIAL_ISSUE', 'value': 'false'},
#    {'type': 'in',
#     'key': 'TAXON_KEY',
#     'values': [3673624,
#      7881320,
#      7632788,
#      3156862,
#      5541648,
#      3157865,
#      3158156,
#      3157812,
#      3157070,
#      3617666,
#      3621126,
#      7425200,
#      7661037,
#      5533815,
#      5534036,
#      5534548,
#      5534472,
#      5534080,
#      3035205,
#      3035162,
#      3035053,
#      3035192,
#      3035040,
#      3036743,
#      3036754,
#      3036602,
#      3036528,
#      6307010,
#      3036755,
#      3036648,
#      3036542,
#      3038090,
#      3038213,
#      3038725,
#      3037796,
#      3038409,
#      3038452,
#      3038458,
#      3038540,
#      3038453,
#      2738670,
#      2738123,
#      2738088,
#      2738130,
#      2733338,
#      2733340,
#      2733382,
#      2732907,
#      2733373,
#      2732932,
#      2734403,
#      2736925,
#      2731948,
#      2731932,
#      2731924,
#      2734229,
#      2734302,
#      2734051,
#      2734052,
#      9444565,
#      5294718,
#      3134409,
#      3139463,
#      3119954,
#      3145047,
#      3144979,
#      3145039,
#      3088906,
#      3147875,
#      4196610,
#      2925400]}]}}

# %%
# Submit query to GBIF API
create_download_given_query(GBIF_USER_NAME, GBIF_PASSWORD, download_query)

# Respuesta esperada:
# ok
# <Response [201]>

# %% [markdown]
# **After downloading the file from the GBIF portal if has to be unzipped and renamed with the name defined in OCCURRENCES_CSV**

# %%
occurrences_df = pd.read_csv(OCCURRENCES_CSV, sep='\t')

occurrences_df
# Out:
#            gbifID                            datasetKey  \
# 0      2425451579  4300f8d5-1ae5-49e5-a101-63894b005868
# 1      2425451267  4300f8d5-1ae5-49e5-a101-63894b005868
# 2      2425451067  4300f8d5-1ae5-49e5-a101-63894b005868
# 3      2424845334  9b7d1acf-b22f-4a1f-b6e8-f1ddd744dc07
# 4      2424840472  9b7d1acf-b22f-4a1f-b6e8-f1ddd744dc07
# 5      2424761898  9b7d1acf-b22f-4a1f-b6e8-f1ddd744dc07
# 6      2424761886  9b7d1acf-b22f-4a1f-b6e8-f1ddd744dc07
# ...           ...                                   ...
# 12664     9262125  857bce66-f762-11e1-a439-00145eb45e9a
# 12665     8603895  857bce66-f762-11e1-a439-00145eb45e9a
# 12666     7544855  857bce66-f762-11e1-a439-00145eb45e9a
# 12667     7544854  857bce66-f762-11e1-a439-00145eb45e9a
# 12668     7544853  857bce66-f762-11e1-a439-00145eb45e9a
# 12669     7462088  857bce66-f762-11e1-a439-00145eb45e9a
# 12670     7462087  857bce66-f762-11e1-a439-00145eb45e9a
#
#                                  occurrenceID  kingdom        phylum  \
# 0                 urn:catalog:JBRJ:RB:1419778  Plantae  Tracheophyta
# 1                 urn:catalog:JBRJ:RB:1419941  Plantae  Tracheophyta
# 2                 urn:catalog:JBRJ:RB:1419800  Plantae  Tracheophyta
# 3      {184E56B9-37EB-4112-B04A-72D95EFD7683}  Plantae  Tracheophyta
# 4      {7B37217E-E27F-4C03-B7A4-860BBD2BEFB9}  Plantae  Tracheophyta
# 5      {4F9B79B4-A60E-42F4-841F-2EC49E2C5D06}  Plantae  Tracheophyta
# 6      {964455E3-1C35-4428-88FE-D4545B8A6A2E}  Plantae  Tracheophyta
# ...                                       ...      ...           ...
# 12664                                     NaN  Plantae  Tracheophyta
# 12665                                     NaN  Plantae  Tracheophyta
# 12666                                     NaN  Plantae  Tracheophyta
# 12667                                     NaN  Plantae  Tracheophyta
# 12668                                     NaN  Plantae  Tracheophyta
# 12669                                     NaN  Plantae  Tracheophyta
# 12670                                     NaN  Plantae  Tracheophyta
#
#                class     order       family        genus  \
# 0      Magnoliopsida  Lamiales  Acanthaceae    Avicennia
# 1      Magnoliopsida  Lamiales  Acanthaceae    Avicennia
# 2      Magnoliopsida  Lamiales  Acanthaceae    Avicennia
# 3      Magnoliopsida  Lamiales  Acanthaceae    Avicennia
# 4      Magnoliopsida  Lamiales  Acanthaceae    Avicennia
# 5      Magnoliopsida  Lamiales  Acanthaceae    Avicennia
# 6      Magnoliopsida  Lamiales  Acanthaceae    Avicennia
# ...              ...       ...          ...          ...
# 12664  Magnoliopsida   Apiales   Araliaceae  Dendropanax
# 12665     Liliopsida  Arecales    Arecaceae  Chamaedorea
# 12666     Liliopsida  Arecales    Arecaceae      Bactris
# 12667     Liliopsida  Arecales    Arecaceae      Bactris
# 12668     Liliopsida  Arecales    Arecaceae      Bactris
# 12669  Magnoliopsida  Lamiales  Acanthaceae    Avicennia
# 12670  Magnoliopsida  Lamiales  Acanthaceae    Avicennia
#
#                          species  ...                      identifiedBy  \
# 0            Avicennia germinans  ...                        C.S. Nunes
# 1            Avicennia germinans  ...                        C.S. Nunes
# 2            Avicennia germinans  ...                          R. Moura
# 3            Avicennia germinans  ...                               NaN
# 4            Avicennia germinans  ...                               NaN
# 5            Avicennia germinans  ...                               NaN
# 6            Avicennia germinans  ...                               NaN
# ...                          ...  ...                               ...
# 12664  Dendropanax sessiliflorus  ...  Huber Werner, Weissenhofer Anton
# 12665     Chamaedorea deckeriana  ...  Huber Werner, Weissenhofer Anton
# 12666         Bactris glandulosa  ...                      Huber Werner
# 12667         Bactris glandulosa  ...                      Huber Werner
# 12668         Bactris glandulosa  ...                      Huber Werner
# 12669          Avicennia bicolor  ...  Huber Werner, Weissenhofer Anton
# 12670          Avicennia bicolor  ...  Huber Werner, Weissenhofer Anton
#
#              dateIdentified       license                     rightsHolder  \
# 0      2018-10-23T00:00:00Z     CC_BY_4_0  Rio de Janeiro Botanical Garden
# 1      2018-10-23T00:00:00Z     CC_BY_4_0  Rio de Janeiro Botanical Garden
# 2                       NaN     CC_BY_4_0  Rio de Janeiro Botanical Garden
# 3                       NaN  CC_BY_NC_4_0                              NaN
# 4                       NaN  CC_BY_NC_4_0                              NaN
# 5                       NaN  CC_BY_NC_4_0                              NaN
# 6                       NaN  CC_BY_NC_4_0                              NaN
# ...                     ...           ...                              ...
# 12664                   NaN       CC0_1_0                              NaN
# 12665                   NaN       CC0_1_0                              NaN
# 12666                   NaN       CC0_1_0                              NaN
# 12667                   NaN       CC0_1_0                              NaN
# 12668                   NaN       CC0_1_0                              NaN
# 12669                   NaN       CC0_1_0                              NaN
# 12670                   NaN       CC0_1_0                              NaN
#
#                                          recordedBy typeStatus  \
# 0                                        M.O. Sousa        NaN
# 1                                        M.O. Sousa        NaN
# 2                                  D. Poczwardowski        NaN
# 3                                           W. Hahn        NaN
# 4      Alfonso Medel Narvaez; J. Rebman, P. Breslin        NaN
# 5                      Alfonso Medel Narvaez; cols.        NaN
# 6                                     Peta J. Mudie        NaN
# ...                                             ...        ...
# 12664              Huber Werner, Weissenhofer Anton        NaN
# 12665              Huber Werner, Weissenhofer Anton        NaN
# 12666              Huber Werner, Weissenhofer Anton        NaN
# 12667              Huber Werner, Weissenhofer Anton        NaN
# 12668              Huber Werner, Weissenhofer Anton        NaN
# 12669              Huber Werner, Weissenhofer Anton        NaN
# 12670              Huber Werner, Weissenhofer Anton        NaN
#
#       establishmentMeans           lastInterpreted   mediaType  \
# 0                    NaN  2019-10-17T02:00:00.085Z         NaN
# 1                    NaN  2019-10-17T02:00:01.333Z         NaN
# 2                    NaN  2019-10-17T01:59:58.819Z         NaN
# 3                    NaN  2019-10-07T14:28:25.208Z         NaN
# 4                    NaN  2019-10-07T14:28:19.957Z  STILLIMAGE
# 5                    NaN  2019-10-07T14:26:55.005Z         NaN
# 6                    NaN  2019-10-07T14:26:54.975Z         NaN
# ...                  ...                       ...         ...
# 12664                NaN  2019-09-20T18:24:42.268Z         NaN
# 12665                NaN  2019-09-20T17:01:18.744Z         NaN
# 12666                NaN  2019-09-20T16:28:04.323Z         NaN
# 12667                NaN  2019-09-20T16:28:04.323Z         NaN
# 12668                NaN  2019-09-20T16:28:04.323Z         NaN
# 12669                NaN  2019-09-20T16:23:48.711Z         NaN
# 12670                NaN  2019-09-20T16:23:46.331Z         NaN
#
#                                                    issue
# 0        GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 1        GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 2                           GEODETIC_DATUM_ASSUMED_WGS84
# 3      GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_IN...
# 4      GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_IN...
# 5      GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_IN...
# 6      GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_IN...
# ...                                                  ...
# 12664  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 12665  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 12666  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 12667  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 12668  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 12669  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 12670  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
#
# [12671 rows x 50 columns]

# %%
# Change "eventDate" data type to dateTime
occurrences_df["eventDate"] = pd.to_datetime(occurrences_df["eventDate"])

# %%
# ==================== CREACIÓN DEL DATAFRAME DE ÁREAS PROTEGIDAS ====================
wdpa_gdf = gpd.read_file(PROTECTED_AREAS_LAYER, encoding="latin-1")
wdpa_gdf.index.name = "index_wdpa"


# ==================== CREACIÓN DE LOS ARCHIVOS DE SALIDA ====================

# Archivo CSV
results_csv = open(OUTPUT_CSV, mode='w', newline='', encoding="latin-1")
results_csv_writer = csv.writer(results_csv, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
results_csv_writer.writerow(['Nombre cientifico de entrada', 
                             'Familia (GBIF)', 
                             'Genero (GBIF)', 
                             'Especie (GBIF)', 
                             'EOO (km2)', 
                             'AOO (km2)',
                             'Altitud minima (m)', 
                             'Altitud maxima (m)',
                             'Países', 
                             'Areas protegidas',
                             'Mapa de registros de presencia', 
                             'Mapa agrupado'])

# Archivo HTML
results_html = open(OUTPUT_HTML, mode='w', newline='', encoding="latin-1")
results_html.write("<!DOCTYPE html>")
results_html.write('<html lang="es">')
results_html.write("<head>")
results_html.write("<title>Evaluacion de arboles de Mesoamerica</title>")
results_html.write("<style>table, th, td {border: 1px solid black;}</style>")
results_html.write("</head>")
results_html.write("<body>")
results_html.write("<table>")
results_html.write("<tr><th>Nombre cientifico de entrada</th><th>Familia (GBIF)</th><th>Genero (GBIF)</th><th>Especie (GBIF)</th><th>EOO (km2)</th><th>AOO (km2)</th><th>Altitud minima (m)</th><th>Altitud maxima (m)</th><th>Paises</th><th>Areas protegidas</th><th>Mapa de registros de presencia</th><th>Mapa agrupado</th></tr>")
results_html.write("<tbody>")


# ==================== RECORRIDO DE LA LISTA DE ESPECIES ====================

for index, row in gbif_species_df.iterrows():
    species_input = row["inputName"]
    family_gbif = row["family"]
    genus_gbif = row["genus"]
    species_gbif = row["species"]
    print(species_gbif)

    current_taxon_df = occurrences_df[occurrences_df['species'] == species_gbif]    

    
    # ==================== ESTRUCTURAS PARA EL CÁLCULO DEL EOO Y DEL AOO ====================    

    # Lista de puntos para el cálculo del EOO
    eoo_points = []   
    
    # Lista de valores de (x,y) para el cálculo del AOO
    aoo_x_values = []
    aoo_y_values = []   
    
    
    # ==================== ESTRUCTURAS PARA EL CÁLCULO DE LAS ALTITUDES MÍNIMA Y MÁXIMA ====================    

    altitude_values = []

    
    # ==================== ESTRUCTURAS PARA LA GENERACIÓN DE LA LISTA DE PAÍSES ====================    
    
    # Conjunto de códigos de países en los que hay registros de presencia
    countries = set()
    

    # ==================== ESTRUCTURAS PARA LA GENERACIÓN DE LA LISTA DE ÁREAS PROTEGIDAS ====================    
    
    # Arreglo de códigos de países en los que hay registros de presencia    
    current_taxon_geom = [Point(xy) for xy in zip(current_taxon_df["decimalLongitude"], 
                                                  current_taxon_df["decimalLatitude"])]
    current_taxon_gdf = gpd.GeoDataFrame(current_taxon_df, 
                                         crs={"init": "epsg:4326"}, 
                                         geometry=current_taxon_geom)
    wdpa_ocuppied = gpd.sjoin(wdpa_gdf, current_taxon_gdf, how="inner", op='intersects')
    protected_areas = wdpa_ocuppied.NAME.unique()    
           
        
    # ==================== INICIALIZACIÓN DE MAPAS ====================
    
    # Mapa de registros de presencia
    occurrences_map = folium.Map(location=[9.63, -84], 
                                 tiles='OpenStreetMap', 
                                 attr='OpenStreetMap', 
                                 zoom_start=5, 
                                 control_scale=True)
    folium.TileLayer(tiles='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/MapServer/tile/{z}/{y}/{x}',
                     name='ESRI World Imagery',
                     attr='ESRI World Imagery').add_to(occurrences_map)
    
    # Mapa de registros de presencia agrupados (cluster)
    cluster_map = folium.Map(location=[9.63, -84], 
                             tiles='OpenStreetMap', 
                             attr='OpenStreetMap', 
                             zoom_start=5, 
                             control_scale=True)
    folium.TileLayer(tiles='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/MapServer/tile/{z}/{y}/{x}',
                     name='ESRI World Imagery',
                     attr='ESRI World Imagery').add_to(cluster_map)    
    occurrences_cluster = plugins.MarkerCluster().add_to(cluster_map)
        
    
    # ==================== RECORRIDO DE LOS REGISTROS DE PRESENCIA ====================
    for lat, lng, alt, country, m, label in zip(current_taxon_df.decimalLatitude,
                               current_taxon_df.decimalLongitude,
                               current_taxon_df.elevation,
                               current_taxon_df.countryCode,
                               current_taxon_df.eventDate.dt.month,
                               "<strong>Localidad:</strong> "       + current_taxon_df.locality.astype(str)   + "\n"    +
                               "<strong>Elevación:</strong> "       + current_taxon_df.elevation.astype(str)  + " m \n" +
                               "<strong>Fecha:</strong> "           + current_taxon_df.eventDate.astype(str)  + "\n"    +
                               "<strong>Recolectores:</strong> "    + current_taxon_df.recordedBy.astype(str) + "\n"    +
                               "<strong>Identificadores:</strong> " + current_taxon_df.identifiedBy.astype(str)):

        # Adición de valores para el cálculo de las altitudes mínima y máxima
        altitude_values.append(alt)
        
        # Adición de puntos para el cálculo del EOO
        x,y = transform(INPUT_PROJECTION, OUTPUT_PROJECTION, lng, lat)
        eoo_point = []
        eoo_point.append(x)
        eoo_point.append(y)
        eoo_points.append(eoo_point)        
        
        # Adición de valores x,y para el cálculo del AOO
        x,y = transform(INPUT_PROJECTION, OUTPUT_PROJECTION, lng, lat)
        aoo_x_values.append(x)
        aoo_y_values.append(y)
        
        # Adición de códigos de países
        countries.add(country)      
        
        # Adición de registros de presencia al mapa de registros de presencia
        folium.CircleMarker(location=[lat, lng], 
                            radius=3, 
                            color='red', 
                            fill=True,
                            popup=label,
                            fill_color='darkred',
                            fill_opacity=0.6).add_to(occurrences_map)
        
        # Adición de registros de presencia agrupados al mapa de registros de presencia agrupados (cluster)
        folium.Marker(
            location=[lat, lng],
            icon=None,
            popup=label,
        ).add_to(occurrences_cluster)
        
    
    # Cálculo de las altitudes mínima y máxima
    altitude_min = min(altitude_values)
    if (np.isnan(altitude_min)):
        altitude_min_str = ""
    else:
        altitude_min_str = "{:.2f}".format(altitude_min)
    altitude_max = max(altitude_values)
    if (np.isnan(altitude_max)):
        altitude_max_str = ""
    else:
        altitude_max_str = "{:.2f}".format(altitude_max)
    
    print("Altitud mínima:", altitude_min_str)
    print("Altitud máxima:", altitude_max_str)
    
    # Cálculo del EOO
    a = np.array(eoo_points)
    hull = ConvexHull(a)
    eoo = hull.volume / 1000000
    print("Área de extensión de presencia (EOO):", "{:.2f}".format(eoo), "km2")
    plt.plot(a[:,0], a[:,1], 'o')
    for simplex in hull.simplices:
        plt.plot(a[simplex, 0], a[simplex, 1], 'k-')  
    plt.savefig(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-grafico_eoo.png", bbox_inches='tight')    
  
    # Cálculo del AOO
    x = np.array(aoo_x_values)
    y = np.array(aoo_y_values)
    gridx = np.arange(AOO_GRID_X_MIN, AOO_GRID_X_MAX, AOO_GRID_CELL_X_WIDTH)
    gridy = np.arange(AOO_GRID_Y_MIN, AOO_GRID_Y_MAX, AOO_GRID_CELL_Y_WIDTH)
    grid, _, _ = np.histogram2d(x, y, bins=[gridx, gridy])
    occupied_cells = (grid > 0) 
    aoo = len(grid[occupied_cells]) * (AOO_GRID_CELL_AREA / 1000000)
    print("Área de ocupación (AOO):", "{:.2f}".format(aoo), "km2")
    plt.figure()
    plt.plot(x, y, 'ro')
    plt.grid(True)
    # plt.show()    
    plt.savefig(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-grafico_aoo.png", bbox_inches='tight')     
    
    # Lista de países con registros de presencia
    countries = sorted(countries)
    print("Países con registros de presencia:", countries)
    
    # Lista de áreas protegidas con registros de presencia
    protected_areas = sorted(protected_areas)
    print("Áreas protegidas con registros de presencia:", protected_areas)      
        
    # Adición de controles de capas
    folium.LayerControl().add_to(occurrences_map)
    folium.LayerControl().add_to(cluster_map)
   
    
    # Grabado de archivos HTML con los mapas
    occurrences_map.save(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-mapa_registros_presencia.html")
    cluster_map.save(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-mapa_agrupado.html")  
    
    # Adición de línea en el archivo CSV de salida
    results_csv_writer.writerow([species_input, 
                                 family_gbif, 
                                 genus_gbif, 
                                 species_gbif, 
                                 "{:.2f}".format(eoo), 
                                 "{:.2f}".format(aoo),
                                 altitude_min_str, 
                                 altitude_max_str,                                  
                                 ', '.join(countries),
                                 ', '.join(protected_areas),
                                 '=HYPERLINK("'+OUTPUT_BASE_URL + family_gbif.upper() + "_" + species_input.replace(" ", "_") + '-mapa_registros_presencia.html' + '", "' + 'Enlace al mapa")',
                                 '=HYPERLINK("'+OUTPUT_BASE_URL + family_gbif.upper() + "_" + species_input.replace(" ", "_") + '-mapa_agrupado.html'            + '", "' + 'Enlace al mapa")'])
    
    # Adición de línea en el archivo HTML de salida
    results_html.write("<tr>")
    results_html.write("<td>"+ species_input                 +"</td>")
    results_html.write("<td>"+ family_gbif                   +"</td>")
    results_html.write("<td>"+ genus_gbif                    +"</td>")
    results_html.write("<td>"+ species_gbif                  +"</td>")
    results_html.write("<td>"+ "{:.2f}".format(eoo)          +"</td>")
    results_html.write("<td>"+ "{:.2f}".format(aoo)          +"</td>")
    results_html.write("<td>"+ altitude_min_str              +"</td>")
    results_html.write("<td>"+ altitude_max_str              +"</td>")    
    results_html.write("<td>"+ ', '.join(countries)          +"</td>")
    results_html.write("<td>"+ ', '.join(protected_areas)    +"</td>")
    results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL + family_gbif.upper() + '_' + species_input.replace(' ', '_') + '-mapa_registros_presencia.html' +'">Enlace</a>' + "</td>")
    results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL + family_gbif.upper() + '_' + species_input.replace(' ', '_') + '-mapa_agrupado.html'            +'">Enlace</a>' + "</td>")
    results_html.write("</tr>")
    
    # Archivo de registros de presencia de la especie
    current_taxon_df[['basisOfRecord', 'species', 'catalogNumber', 'recordNumber', 'decimalLatitude', 'decimalLongitude', 'locality', 'year', 'recordedBy']]
    current_taxon_df.to_csv(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-registros_presencia.csv")
    
# ==================== CIERRE DE LOS ARCHIVOS DE SALIDA ====================

# Archivo CSV
results_csv.close()

# Archivo HTML
results_html.write("</tbody></table></body></html>")
results_html.close()
# Out:
# Pleuropetalum pleiogynum
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 4145957.54 km2
# Área de ocupación (AOO): 528.00 km2
# Países con registros de presencia: ['BO', 'CO', 'CR', 'MX', 'NI', 'PA', 'PE', 'SV', 'VE']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'CanglÃ³n', 'Carara', 'Cerro Datanli El Diablo', 'Cerro Kilambe', 'Cerro Nara', 'Cerro Tisey Estanzuela', 'Cerros de Amotape', 'Cerros de Turrubares', 'Chagres', 'Corcovado', 'Cordillera Volcanica Central', 'Darien', 'Darien National Park', 'DariÃ©n', 'Golfito', 'Golfo Dulce', 'Grecia', 'Hitoy Cerere', 'Internacional La Amistad', 'La Cangreja', 'Los Katios', 'Los KatÃ\xados National Park', 'Los Santos', 'Madidi', 'Miraflor/Moropotente', 'Rio Banano', 'Rio Pacuare', 'Rios Barroso y San Juan', 'San Rafael de Guasare', 'SerranÃ\xada Filo del Tallo', 'Sierra Amerrisque', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tayrona', 'Tepesomoto/Pataste']
# Amphipterygium molle
# Altitud mínima: 0.00
# Altitud máxima: 2110.00
# Área de extensión de presencia (EOO): 245493.75 km2
# Área de ocupación (AOO): 60.00 km2
# Países con registros de presencia: ['CR', 'MX']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Cuenca Alimentadora del Distrito Nacional de Riego 043 Estado de Nayarit', 'Guanacaste', 'Santa Rosa']
# Tapirira lepidota
# Altitud mínima: 49.00
# Altitud máxima: 330.00
# Área de extensión de presencia (EOO): 5602.90 km2
# Área de ocupación (AOO): 56.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Golfito', 'Golfo Dulce', 'Osa', 'Pejeperro', 'Piedras Blancas']
# Anaxagorea phaeocarpa
# Altitud mínima: 0.00
# Altitud máxima: 3064.00
# Área de extensión de presencia (EOO): 8721212.41 km2
# Área de ocupación (AOO): 756.00 km2
# Países con registros de presencia: ['BR', 'CO', 'CR', 'EC', 'GF', 'NI', 'PA', 'PE']
# Áreas protegidas con registros de presencia: ['Airo Pai', 'Allpahuayo  Mishana', 'Amacayacu', 'Amazon Estuary and its Mangroves', 'Area de ConservaciÃ³n Guanacaste', 'Barbilla', 'Barra del Colorado', 'Braulio Carrillo', 'Complejo de humedales Lagos de Tarapoto', 'Corcovado', 'Cordillera Volcanica Central', 'Cuyabeno', 'Darien National Park', 'DariÃ©n', 'EstaÃ§Ã£o EcolÃ³gica Do GrÃ£o ParÃ¡', 'Floresta Estadual De Faro', 'Floresta Estadual Do AmapÃ¡', 'Floresta Estadual Do Trombetas', 'Floresta Nacional De CaxiuanÃ£', 'Floresta Nacional De TapajÃ³s', 'Golfo de Tribuga Cabo Corrientes', 'Guanacaste', 'Hitoy Cerere', 'Humedal Caribe Noreste', 'Indio Maiz', 'Internacional La Amistad', 'KararaÃ´', 'La Selva', 'La Sierpe', 'Maquenque', 'Marais De Kaw', 'MaraÃ£ Urubaxi', 'Montagne de Kaw', 'NarganÃ¡', 'Pacaas Novas', 'Parque Ecologico Urbano de Cobija', 'Parque Nacional Da Serra Do Divisor', 'Parque Nacional De PacaÃ¡s Novos', 'Parque Nacional Mapinguari', 'Parque Nacional Montanhas Do Tumucumaque', 'Parque do Xingu', 'Reserva BiolÃ³gica Do Rio Trombetas', 'Reserva De Desenvolvimento SustentÃ¡vel Do Rio Iratapuru', 'Reserva Extrativista MapuÃ¡', 'Reserva de la BiÃ³sfera de Yasuni', 'Rio Negro', 'Rio Pacuare', 'Sureste de Nicaragua', 'SÃ£o Gabriel/SÃ£o Salvador', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero', 'Trombetas/Mapuera', 'Uru-Eu-Wau-Wau', 'Waimiri-Atroari', 'Yaigoje Apaporis', 'Yanomami', 'YasunÃ\xad', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Do ArquipÃ©lago Do MarajÃ³', 'Ã\x89vare I']
# Annona danforthii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 853488.10 km2
# Área de ocupación (AOO): 108.00 km2
# Países con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Amacayacu', 'Area de ConservaciÃ³n Guanacaste', 'Cerro Nara', 'Complejo de humedales Lagos de Tarapoto', 'Golfo Dulce', 'Guanacaste', 'Las Orquideas', 'Los Santos', 'Rio Banano']
# Cymbopetalum torulosum
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 217882.45 km2
# Área de ocupación (AOO): 212.00 km2
# Países con registros de presencia: ['CR', 'HN', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Carara', 'Cerro Silva', 'Corcovado', 'Golfo Dulce', 'La Cangreja', 'La Selva', 'Los Santos', 'Piedras Blancas', 'Punta Gorda', 'Sureste de Nicaragua']
# Mosannona costaricensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 19511.70 km2
# Área de ocupación (AOO): 56.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce']
# Unonopsis panamensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 106681.05 km2
# Área de ocupación (AOO): 204.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Cerro Gaital', 'Cerro Nara', 'Cerros de Turrubares', 'Chagres', 'DariÃ©n', 'Fernando Castro Cervantes', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Golfo Dulce', 'Osa', 'Soberania']
# Xylopia macrantha
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1336786.69 km2
# Área de ocupación (AOO): 212.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA', 'PE']
# Áreas protegidas con registros de presencia: ['Barro Colorado', 'Corcovado', 'Darien', 'Golfo Dulce', 'La Sierpe', 'Manuel Antonio', 'ManÃº National Park', 'Osa', 'Soberania', 'del Manu']
# Lacmellea zamorae
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1995.74 km2
# Área de ocupación (AOO): 152.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Cerro Nara', 'Chirripo', 'Los Santos', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Macoubea mesoamericana
# Altitud mínima: 20.00
# Altitud máxima: 700.00
# Área de extensión de presencia (EOO): 8475.00 km2
# Área de ocupación (AOO): 44.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Tabernaemontana hannae
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 12367.75 km2
# Área de ocupación (AOO): 32.00 km2
# Países con registros de presencia: ['CR', 'MX']
# Áreas protegidas con registros de presencia: ['CaÃ±Ã³n del Sumidero', 'Monte Alto', 'Parque Nacional CaÃ±Ã³n del Sumidero']
# Tabernaemontana pauli
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 13584.33 km2
# Área de ocupación (AOO): 184.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Golfito', 'Golfo Dulce', 'La Cangreja', 'Piedras Blancas', 'Punta Rio Claro']
# Ilex pallida
# Altitud mínima: 700.00
# Altitud máxima: 3350.00
# Área de extensión de presencia (EOO): 82337.03 km2
# Área de ocupación (AOO): 348.00 km2
# Países con registros de presencia: ['CR', 'HN', 'NI', 'PA', 'SV']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Cacique Lempira, SenÌ\x83or de las MontanÌ\x83as', 'Cerro Cumaica Cerro Alegre', 'Cerro de Escazu', 'Chirripo', 'Cordillera Volcanica Central', 'Curi cancha', 'Guanacaste', 'Internacional La Amistad', 'La Amistad', 'Las Tablas', 'Los Quetzales', 'Los Santos', 'MontaÃ±a de Celaque', 'Reserva de la BiÃ³sfera de La Amistad', 'Rincon de la Vieja', 'Rio Macho', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº', 'Volcan Irazu', 'Volcan Poas', 'VolcÃ¡n Mombacho']
# Ilex costaricensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 322845.78 km2
# Área de ocupación (AOO): 228.00 km2
# Países con registros de presencia: ['CR', 'MX', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Cerro El Arenal', 'Cerro Kilambe', 'Cerro de Escazu', 'Fortuna', 'Grecia', 'Guanacaste', 'Internacional La Amistad', 'La Selva', 'Las Tablas', 'Los Quetzales', 'Los Santos', 'Los Tuxtlas', 'Manglares y humedales de la Laguna de Sontecomapan', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ilex haberi
# Altitud mínima: 566.00
# Altitud máxima: 2150.00
# Área de extensión de presencia (EOO): 155041.11 km2
# Área de ocupación (AOO): 64.00 km2
# Países con registros de presencia: ['CR', 'NI', 'VE']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'El Caura', 'Guanacaste', 'Volcan Tenorio', 'VolcÃ¡n Maderas']
# Ilex hemiepiphytica
# Altitud mínima: 50.00
# Altitud máxima: 2625.00
# Área de extensión de presencia (EOO): 13977.93 km2
# Área de ocupación (AOO): 88.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Guanacaste', 'Internacional La Amistad', 'Maquenque', 'Miravalles', 'Rio Banano', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ilex vulcanicola
# Altitud mínima: 1000.00
# Altitud máxima: 3056.00
# Área de extensión de presencia (EOO): 41925.70 km2
# Área de ocupación (AOO): 104.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Cerro Gaital', 'Chirripo', 'Internacional La Amistad', 'Santa Fe', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Dendropanax alberti-smithii
# Altitud mínima: 0.00
# Altitud máxima: 2225.04
# Área de extensión de presencia (EOO): 775121.08 km2
# Área de ocupación (AOO): 80.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA', 'PE']
# Áreas protegidas con registros de presencia: ['Chagres', 'Darien National Park', 'DariÃ©n', 'Donoso', 'Encanto de los manglares del Bajo Baudo', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Yanachaga - ChemillÃ©n']
# Dendropanax latilobus
# Altitud mínima: 700.00
# Altitud máxima: 2465.00
# Área de extensión de presencia (EOO): 34768.39 km2
# Área de ocupación (AOO): 84.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Curi cancha', 'Guanacaste', 'La Amistad', 'Las Tablas', 'Reserva de la BiÃ³sfera de La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº']
# C:\Users\mfvargas\Anaconda3\lib\site-packages\ipykernel_launcher.py:188: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Dendropanax praestans
# Altitud mínima: 850.00
# Altitud máxima: 2700.00
# Área de extensión de presencia (EOO): 32630.78 km2
# Área de ocupación (AOO): 52.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Cerro Gaital', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Santa Fe']
# Dendropanax ravenii
# Altitud mínima: 20.00
# Altitud máxima: 725.00
# Área de extensión de presencia (EOO): 12034.24 km2
# Área de ocupación (AOO): 108.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Golfo Dulce', 'Piedras Blancas']
# Dendropanax sessiliflorus
# Altitud mínima: 0.00
# Altitud máxima: 2810.00
# Área de extensión de presencia (EOO): 69792.82 km2
# Área de ocupación (AOO): 280.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Carara', 'Chirripo', 'Corcovado', 'Darien National Park', 'DariÃ©n', 'Fortuna', 'Golfito', 'Golfo Dulce', 'Internacional La Amistad', 'Las Tablas', 'Los Quetzales', 'Piedras Blancas', 'Santa Fe', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Terraba-Sierpe']
# Oreopanax anomalus
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 16081.86 km2
# Área de ocupación (AOO): 128.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal', 'Arenal Monteverde', 'Guanacaste', 'Internacional La Amistad', 'Miravalles', 'Rincon de la Vieja', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tenorio']
# Oreopanax compactus
# Altitud mínima: 800.00
# Altitud máxima: 2000.00
# Área de extensión de presencia (EOO): 2354.40 km2
# Área de ocupación (AOO): 20.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: []
# Oreopanax donnell-smithii
# Altitud mínima: 450.00
# Altitud máxima: 3350.00
# Área de extensión de presencia (EOO): 16549.77 km2
# Área de ocupación (AOO): 132.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Cerro Nara', 'Los Quetzales', 'Los Santos', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Oreopanax nubigenus
# Altitud mínima: 0.00
# Altitud máxima: 2775.00
# Área de extensión de presencia (EOO): 9135.03 km2
# Área de ocupación (AOO): 104.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Caraigres', 'Cordillera Volcanica Central', 'Juan Castro Blanco', 'Miravalles', 'Volcan Poas']
# Oreopanax paramicola
# Altitud mínima: 500.00
# Altitud máxima: 3400.00
# Área de extensión de presencia (EOO): 3950.61 km2
# Área de ocupación (AOO): 80.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Cerro Las Vueltas', 'Chirripo', 'Internacional La Amistad', 'La Amistad', 'Los Quetzales', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Macho', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº']
# Oreopanax pycnocarpus
# Altitud mínima: 550.00
# Altitud máxima: 3200.00
# Área de extensión de presencia (EOO): 36368.47 km2
# Área de ocupación (AOO): 176.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Braulio Carrillo', 'Cerro Las Vueltas', 'Cerro de Escazu', 'Chirripo', 'Internacional La Amistad', 'La Amistad', 'Las Tablas', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Banano', 'Rio Macho', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº']
# Oreopanax standleyi
# Altitud mínima: 60.00
# Altitud máxima: 2700.00
# Área de extensión de presencia (EOO): 44434.72 km2
# Área de ocupación (AOO): 128.00 km2
# Países con registros de presencia: ['CR', 'SV']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Internacional La Amistad', 'Los Santos', 'Piedras Blancas', 'Rio Banano', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan Turrialba']
# Oreopanax striatus
# Altitud mínima: 650.00
# Altitud máxima: 2975.00
# Área de extensión de presencia (EOO): 12116.71 km2
# Área de ocupación (AOO): 104.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Internacional La Amistad', 'Las Tablas', 'Los Quetzales', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Schefflera albocapitata
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 123.70 km2
# Área de ocupación (AOO): 12.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: []
# Schefflera brenesii
# Altitud mínima: 60.00
# Altitud máxima: 2400.00
# Área de extensión de presencia (EOO): 20870.50 km2
# Área de ocupación (AOO): 220.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal', 'Arenal Monteverde', 'Cerro Nara', 'Chirripo', 'Cordillera Volcanica Central', 'Guanacaste', 'La Amistad', 'Los Santos', 'Piedras Blancas', 'Reserva de la BiÃ³sfera de La Amistad', 'Rincon de la Vieja', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan Tenorio', 'Zona de Emergencia Volcan Arenal']
# Schefflera cartagoensis
# Altitud mínima: 1400.00
# Altitud máxima: 1550.00
# Área de extensión de presencia (EOO): 1342.47 km2
# Área de ocupación (AOO): 16.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Schefflera epiphytica
# Altitud mínima: 243.84
# Altitud máxima: 1341.12
# Área de extensión de presencia (EOO): 224904.47 km2
# Área de ocupación (AOO): 172.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Cerro Gaital', 'Fortuna', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Palo Seco', 'Santa Fe', 'Ã\x81rea de Manejo Especial Municipal de Chame (Manglares)']
# Schefflera instita
# Altitud mínima: 1200.00
# Altitud máxima: 1950.00
# Área de extensión de presencia (EOO): 5205.79 km2
# Área de ocupación (AOO): 40.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Braulio Carrillo', 'Internacional La Amistad', 'Rincon de la Vieja', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Schefflera minutiflora
# Altitud mínima: 600.00
# Altitud máxima: 2630.00
# Área de extensión de presencia (EOO): 851443.41 km2
# Área de ocupación (AOO): 248.00 km2
# Países con registros de presencia: ['CO', 'EC', 'PE']
# Áreas protegidas con registros de presencia: ['Alto de San Miguel', 'Antisana', 'Camelias', 'Canones de los rios Melcocho y Santo Domingo', 'Cayambe Coca', 'CofÃ¡n Bermejo', 'Divisoria Valle de Aburra Rio Cauca', 'El Quimi', 'El Sira', 'Embalse el Penol y Cuenca Alta del Rio Guatape', 'La Planada', 'Las Orquideas', 'Podocarpus', 'Podocarpus-El Condor', 'Rio Anchicaya', 'Serrania de Chiribiquete', 'Sumaco', 'Sumaco Napo-Galeras']
# Schefflera nicaraguensis
# Altitud mínima: 2.00
# Altitud máxima: 1700.00
# Área de extensión de presencia (EOO): 27918.51 km2
# Área de ocupación (AOO): 88.00 km2
# Países con registros de presencia: ['CR', 'NI']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal', 'Barbilla', 'Barra del Colorado', 'Cahuita', 'Guanacaste', 'Humedal Caribe Noreste', 'Indio Maiz', 'Los Santos', 'RÃ\xado San Juan', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero', 'Volcan Tenorio']
# Schefflera pubens
# Altitud mínima: 114.30
# Altitud máxima: 1000.00
# Área de extensión de presencia (EOO): 5659.09 km2
# Área de ocupación (AOO): 24.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cordillera Volcanica Central', 'General de DivisiÃ³n Omar Torrijos Herrera']
# Schefflera seibertii
# Altitud mínima: 50.00
# Altitud máxima: 1690.00
# Área de extensión de presencia (EOO): 32109.06 km2
# Área de ocupación (AOO): 56.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Barbilla', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Fortaleza la Inmaculada  ConcepciÃ³n de MarÃ\xada.', 'Guanacaste', 'Internacional La Amistad', 'Rio Banano', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Terraba-Sierpe']
# Aiphanes hirsuta
# Altitud mínima: 125.00
# Altitud máxima: 2300.00
# Área de extensión de presencia (EOO): 558283.91 km2
# Área de ocupación (AOO): 372.00 km2
# Países con registros de presencia: ['CO', 'CR', 'EC', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Camelias', 'Canones de los rios Melcocho y Santo Domingo', 'Carauta', 'Cerro Gaital', 'Chagres', 'Cotacachi Cayapas', 'Darien', 'Darien National Park', 'DariÃ©n', 'De Urrao', 'Embalse el Penol y Cuenca Alta del Rio Guatape', 'Fortuna', 'General de DivisiÃ³n Omar Torrijos Herrera', 'La Tebaida', 'Las Orquideas', 'Paramillo', 'Punchina', 'Rio Anchicaya', 'Santa Fe']
# Astrocaryum alatum
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 246601.63 km2
# Área de ocupación (AOO): 260.00 km2
# Países con registros de presencia: ['CR', 'HN', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Barra del Colorado', 'Braulio Carrillo', 'Carara', 'Cerro Bana Cruz', 'Chagres', 'Donoso', 'Estero Puntarenas y Manglares Asociados', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Guanacaste', 'Humedal Caribe Noreste', 'Indio Maiz', 'Santa Fe', 'Soberania', 'Sureste de Nicaragua', 'Zona de Amortiguamiento (Bosawas)']
# Astrocaryum confertum
# Altitud mínima: 50.00
# Altitud máxima: 350.00
# Área de extensión de presencia (EOO): 44098.46 km2
# Área de ocupación (AOO): 40.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Donoso', 'Humedal Caribe Noreste', 'La Selva', 'NarganÃ¡', 'Tortuguero']
# Astrocaryum standleyanum
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1177688.75 km2
# Área de ocupación (AOO): 312.00 km2
# Países con registros de presencia: ['CO', 'CR', 'EC', 'PA']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Barro Colorado', 'Darien', 'Darien National Park', 'DariÃ©n', 'De Los Humedales Entre Los RÃ\xados Leon Y SuriquÃ\xad', 'En el Territorio Colectivo del Consejo Comunitario de la Comunidad Negra de la Plata', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Humedales entre los Rios Leon y Suriqui', 'La Sierpe', 'Los Katios', 'Los KatÃ\xados National Park', 'Machalilla', 'Manglares Churute', 'Manuel Antonio', 'NarganÃ¡', 'Soberania', 'Zona Marina Parque Nacional Machalilla']
# Bactris caudata
# Altitud mínima: 5.00
# Altitud máxima: 1250.00
# Área de extensión de presencia (EOO): 111721.05 km2
# Área de ocupación (AOO): 80.00 km2
# Países con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Cerro Silva', 'Chagres', 'Indio Maiz', 'Sureste de Nicaragua']
# Bactris glandulosa
# Altitud mínima: 0.00
# Altitud máxima: 1200.00
# Área de extensión de presencia (EOO): 257958.62 km2
# Área de ocupación (AOO): 320.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Carara', 'Carauta', 'Cerro Gaital', 'Cerro Nara', 'Corcovado', 'Darien', 'El Montuoso', 'El Rodeo', 'Finca Baru del Pacifico', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfito', 'Golfo Dulce', 'La Cangreja', 'NarganÃ¡', 'Piedras Blancas', 'Rancho La Merced']
# Bactris herrerana
# Altitud mínima: 50.00
# Altitud máxima: 700.00
# Área de extensión de presencia (EOO): 4133.82 km2
# Área de ocupación (AOO): 44.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Golfo Dulce', 'La Cangreja', 'Piedras Blancas']
# Bactris longiseta
# Altitud mínima: 50.00
# Altitud máxima: 1000.00
# Área de extensión de presencia (EOO): 1936.26 km2
# Área de ocupación (AOO): 24.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo']
# Bactris militaris
# Altitud mínima: 0.00
# Altitud máxima: 350.00
# Área de extensión de presencia (EOO): 847412.51 km2
# Área de ocupación (AOO): 64.00 km2
# Países con registros de presencia: ['CR', 'PA', 'US']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Braulio Carrillo', 'Donoso', 'Gandoca Manzanillo', 'Gandoca-Manzanillo']
# Bactris polystachya
# Altitud mínima: 10.00
# Altitud máxima: 700.00
# Área de extensión de presencia (EOO): 6126.00 km2
# Área de ocupación (AOO): 40.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Maquenque']
# Chamaedorea deckeriana
# Altitud mínima: 1.00
# Altitud máxima: 1250.00
# Área de extensión de presencia (EOO): 250791.60 km2
# Área de ocupación (AOO): 436.00 km2
# Países con registros de presencia: ['CO', 'CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Arenal', 'Arenal Monteverde', 'Barra del Colorado', 'Braulio Carrillo', 'Carauta', 'Chagres', 'Cordillera Volcanica Central', 'Fortuna', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Humedal Caribe Noreste', 'Indio Maiz', 'Internacional La Amistad', 'La Cangreja', 'La Selva', 'Maquenque', 'NarganÃ¡', 'Palo Seco', 'Piedras Blancas', 'Punta Gorda', 'Rio Banano', 'Rio Pacuare', 'RÃ\xado San Juan', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tenorio', 'Tortuguero']
# Colpothrinax aphanopetala
# Altitud mínima: 365.00
# Altitud máxima: 1400.00
# Área de extensión de presencia (EOO): 60520.80 km2
# Área de ocupación (AOO): 32.00 km2
# Países con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Chagres', 'Fortuna', 'Indio Maiz', 'Internacional La Amistad', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Cryosophila cookii
# Altitud mínima: 20.00
# Altitud máxima: 100.00
# Área de extensión de presencia (EOO): 531.77 km2
# Área de ocupación (AOO): 20.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: []
# Cryosophila grayumii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1190802.90 km2
# Área de ocupación (AOO): 68.00 km2
# Países con registros de presencia: ['CR', 'PA', 'US']
# Áreas protegidas con registros de presencia: ['Carara']
# Cryosophila guagara
# Altitud mínima: 10.00
# Altitud máxima: 350.00
# Área de extensión de presencia (EOO): 9903.92 km2
# Área de ocupación (AOO): 100.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Carara', 'Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Golfo Dulce', 'Piedras Blancas']
# Geonoma ferruginea
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 457077.32 km2
# Área de ocupación (AOO): 524.00 km2
# Países con registros de presencia: ['CO', 'CR', 'GT', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal', 'Arenal Monteverde', 'Barbilla', 'Braulio Carrillo', 'Cerro Cumaica Cerro Alegre', 'Cerro Kilambe', 'Cerro Mombachito La Vieja', 'Cerro Musun', 'Cerro San Gil', 'Cerro Saslaya', 'Cordillera Volcanica Central', 'Curi cancha', 'Golfo Dulce', 'Guanacaste', 'Hitoy Cerere', 'Internacional La Amistad', 'Macizo de PeÃ±as Blancas', 'Palo Seco', 'Rincon de la Vieja', 'Rio Banano', 'San San Pond Sak', 'Sierra Amerrisque', 'Sierra Quirragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan Tenorio']
# Geonoma congesta
# Altitud mínima: 0.00
# Altitud máxima: 1270.00
# Área de extensión de presencia (EOO): 7119461.24 km2
# Área de ocupación (AOO): 872.00 km2
# Países con registros de presencia: ['CO', 'CR', 'EC', 'HN', 'NI', 'PA', 'US']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Barra del Colorado', 'Bosawas', 'Braulio Carrillo', 'CaÃ±o Negro', 'Cerro Bana Cruz', 'Cerro Cola Blanca', 'Cerro Musun', 'Cerro Saslaya', 'Cerro Silva', 'Chagres', 'Corcovado', 'Cotacachi Cayapas', 'Donoso', 'En el Territorio Colectivo del Consejo Comunitario de la Comunidad Negra de la Plata', 'Fortuna', 'Gandoca Manzanillo', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Golfo Dulce', 'Guanacaste', 'Humedal Caribe Noreste', 'Indio Maiz', 'La Cangreja', 'La Selva', 'La Sierpe', 'Maquenque', 'Piedras Blancas', 'Punta Gorda', 'Rincon de la Vieja', 'RÃ\xado PlÃ¡tano', 'RÃ\xado San Juan', 'Santa Fe', 'Sierra Amerrisque', 'Sureste de Nicaragua', 'Tortuguero', 'Utria', 'Zona de Amortiguamiento (Bosawas)']
# Geonoma longivaginata
# Altitud mínima: 4.00
# Altitud máxima: 1000.00
# Área de extensión de presencia (EOO): 207194.40 km2
# Área de ocupación (AOO): 132.00 km2
# Países con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Archie Carr', 'Area de ConservaciÃ³n Guanacaste', 'Barra del Colorado', 'Cerro Saslaya', 'Fortuna', 'Golfito', 'Golfo Dulce', 'Guanacaste', 'Hitoy Cerere', 'Humedal Caribe Noreste', 'La Selva', 'La Tirimbina', 'Los Santos', 'NarganÃ¡', 'Piedras Blancas', 'Rio Banano', 'Rio Pacuare', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero']
# Geonoma orbignyana
# Altitud mínima: 122.00
# Altitud máxima: 5000.00
# Área de extensión de presencia (EOO): 4603026.12 km2
# Área de ocupación (AOO): 1720.00 km2
# Países con registros de presencia: ['BO', 'CO', 'CR', 'EC', 'NI', 'PA', 'PE', 'VE']
# Áreas protegidas con registros de presencia: ['Alto Fragua Indi Wasi', 'Alto Mayo', 'Alto de San Miguel', 'Alto del Insor', 'AmborÃ³', 'Antisana', 'Apolobamba', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Bahuaja - Sonene', 'Barbas Bremen', 'Bosque de Palmeras de la Comunidad Campesina Taulia Molinopampa', 'Braulio Carrillo', 'Cacica Noria', 'Camelias', 'Campoalegre', 'Canones de los rios Melcocho y Santo Domingo', 'Carauta', 'Carrasco', 'Cavernas del RepechÃ³n', 'Cerro El Arenal', 'Cerro Pintao - Serrania del Perija', 'Complejo de Humedales Cuyabeno Lagartococha YasunÃ\xad', 'CopallÃ\xadn', 'Cordillera Volcanica Central', 'Cordillera de los Picachos', 'Corredor Biologico Guacharos PuracE', 'Cuchilla Jardin Tamesis', 'Cuchillas Negra y Guanaque', 'Cueva de los Guacharos', 'Curi cancha', 'Cuyabeno', 'De Urrao', 'Divisoria Valle de Aburra Rio Cauca', 'El Cerro Dapa Carisucio', 'El Chayote', 'El Sira', 'Embalse el Penol y Cuenca Alta del Rio Guatape', 'Farallones del Citara', 'Guanacaste', 'Guanenta Alto Rio Fonce', 'Guaramacal', 'Ichigkat Muja - Cordillera del CÃ³ndor', 'Internacional La Amistad', 'La Amistad', 'Las Aves El Dorado', 'Las Orquideas', 'Las Tablas', 'Los Nevados', 'Los Quetzales', 'Los Santos', 'Madidi', 'ManÃº National Park', 'Pacaya - Samiria', 'Pacaya Samiria', 'Paramillo', 'Paramos de Guantiva y la Rusia', 'Parque Nacional PilÃ³n-Lajas', 'PilÃ³n Lajas', 'Podocarpus', 'Podocarpus-El Condor', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Anchicaya', 'Rio Macho', 'Rio Nare', 'Rubio', 'RÃ\xados Guanare, BoconÃ³, Tucupido, La Yuca y Masparro', 'Sangay', 'Sangay National Park', 'Selva de Florencia', 'Sierra de Aroa', 'Siete Iglesias', 'Sisavita', 'Sureste del Lago de Maracaibo Sto. Domingo-MotatÃ¡n', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Tatama', 'Ucumari', 'Volcan BarÃº', 'Yanachaga - ChemillÃ©n', 'de San MatÃ\xadas - San Carlos', 'del Manu']
# Pholidostachys pulchra
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 238348.76 km2
# Área de ocupación (AOO): 52.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Braulio Carrillo', 'Corcovado', 'Humedal Caribe Noreste', 'NarganÃ¡', 'Tortuguero']
# Reinhardtia koschnyana
# Altitud mínima: 10.00
# Altitud máxima: 1468.00
# Área de extensión de presencia (EOO): 293513.13 km2
# Área de ocupación (AOO): 196.00 km2
# Países con registros de presencia: ['CO', 'CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Bosawas', 'Darien National Park', 'DariÃ©n', 'NarganÃ¡', 'Rio Leon', 'Sureste de Nicaragua', 'Zona de Amortiguamiento (Bosawas)']
# Bartlettina prionophylla
# Altitud mínima: 1350.00
# Altitud máxima: 2804.16
# Área de extensión de presencia (EOO): 14354.87 km2
# Área de ocupación (AOO): 56.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Las Tablas', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº']
# Hebeclinium costaricense
# Altitud mínima: 548.64
# Altitud máxima: 1200.00
# Área de extensión de presencia (EOO): 55559.57 km2
# Área de ocupación (AOO): 56.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Cerro Gaital', 'Cerro Nara', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Zona de Emergencia Volcan Arenal']
# Jessea multivenia
# Altitud mínima: 900.00
# Altitud máxima: 3819.00
# Área de extensión de presencia (EOO): 36927.05 km2
# Área de ocupación (AOO): 296.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Caraigres', 'Cerro Las Vueltas', 'Cerro de Escazu', 'Chirripo', 'Cordillera Volcanica Central', 'Internacional La Amistad', 'La Amistad', 'Los Quetzales', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Banano', 'Rio Macho', 'Rio Navarro-Rio Sombrero', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan Irazu', 'Volcan Tenorio']
# Koanophyllon hylonoma
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 78029.19 km2
# Área de ocupación (AOO): 284.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal', 'Arenal Monteverde', 'Braulio Carrillo', 'Curi cancha', 'Diria', 'Fortuna', 'Golfo Dulce', 'Guanacaste', 'Hitoy Cerere', 'Internacional La Amistad', 'La Selva', 'Miravalles', 'Rincon de la Vieja', 'Rio Navarro-Rio Sombrero', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan Tenorio', 'Ã\x81rea de Manejo Especial Municipal de Chame (Manglares)']
# Koanophyllon pittieri
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 893770.28 km2
# Área de ocupación (AOO): 700.00 km2
# Países con registros de presencia: ['BZ', 'CR', 'GT', 'MX', 'NI']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Bladen', 'Braulio Carrillo', 'CaÃ±Ã³n del Usumacinta', 'Cerro de Escazu', 'Chiquibul', 'Curi cancha', 'El Chayote', 'El CordÃ³n del RetÃ©n', 'El Pilar', 'El Triunfo', 'Guanacaste', 'Hitoy Cerere', 'Internacional La Amistad', 'Juan Castro Blanco', 'La Sepultura', 'La SerranÃ\xada', 'Los Tuxtlas', 'Manglares y humedales de la Laguna de Sontecomapan', 'Maya', 'Miravalles', 'Montes Azules', 'Mountain Pine Ridge', 'Rincon de la Vieja', 'Rio Navarro-Rio Sombrero', 'Rio Toro', 'San RomÃ¡n', 'Selva El Ocote', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan TacanÃ¡', 'Volcan Tenorio', 'VolcÃ¡n TacanÃ¡', 'YaxchilÃ¡n', 'Zona de ProtecciÃ³n Forestal en los terrenos que se encuentran en los municipios de La Concordia, Angel Albino Corzo, Villa Flores y Jiquipilas']
# Koanophyllon wetmorei
# Altitud mínima: 5.00
# Altitud máxima: 1350.00
# Área de extensión de presencia (EOO): 39239.79 km2
# Área de ocupación (AOO): 60.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Barro Colorado', 'Darien National Park', 'DariÃ©n', 'Fortuna', 'La Amistad', 'Reserva de la BiÃ³sfera de La Amistad', 'Soberania', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Lepidonia lankesteri
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1316.97 km2
# Área de ocupación (AOO): 80.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Chirripo', 'Rio Navarro-Rio Sombrero', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Verbesina tapantiana
# Altitud mínima: 600.00
# Altitud máxima: 2208.00
# Área de extensión de presencia (EOO): 1795.90 km2
# Área de ocupación (AOO): 40.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Avicennia bicolor
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 455710.75 km2
# Área de ocupación (AOO): 288.00 km2
# Países con registros de presencia: ['CO', 'CR', 'HN', 'NI', 'PA', 'SV']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'BahÃ\xada de Chismuyo', 'BahÃ\xada de Jiquilisco', 'CenegÃ³n del Mangle', 'Cipanci', 'Estero Puntarenas y Manglares Asociados', 'Estero Real', 'Gorgona', 'Isla Juan Venado', 'Isla San lucas', 'Manglar BahÃ\xada de Jiquilisco', 'Marino las Baulas de Guanacaste', 'Palo Verde', 'Piedras Blancas', 'Santa Rosa', 'Tivives', 'VolcÃ¡n Cosiguina', 'Xiriualtique-Jiquilisco', 'Zona de Amortiguamiento (juan venado)', 'Ã\x81rea de Manejo Especial Municipal de Chame (Manglares)']
# Avicennia germinans
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 112664622.30 km2
# Área de ocupación (AOO): 6588.00 km2
# Países con registros de presencia: ['AG', 'AO', 'AW', 'BJ', 'BL', 'BR', 'BS', 'BZ', 'CD', 'CG', 'CI', 'CM', 'CO', 'CR', 'CU', 'CW', 'DE', 'DO', 'EC', 'GA', 'GD', 'GF', 'GH', 'GM', 'GN', 'GP', 'GQ', 'GT', 'GW', 'GY', 'HN', 'HT', 'IR', 'JM', 'KN', 'KY', 'LR', 'MQ', 'MR', 'MX', 'NG', 'NI', 'PA', 'PE', 'PR', 'SL', 'SN', 'SR', 'ST', 'SV', 'TG', 'TT', 'US', 'VC', 'VE', 'VI']
# Áreas protegidas con registros de presencia: ['Agoa', 'Alligator Harbor', 'Amazon Estuary and its Mangroves', 'Anastasia', 'Apalachicola Bay', 'Apalachicola National Estuarine Research Reserve Outstanding Florida Water', 'Aransas', 'ArchipielÃ¡go de ColÃ³n (GalÃ¡pagos)', 'Area de ConservaciÃ³n Guanacaste', 'Arrecife de Puerto Morelos', 'Arrecifes de Cozumel', 'Arrecifes de Xcalak', 'Arrecifes de la Cordillera', 'Bacalar Chico', 'Bahia Honda', 'Bahia Junquillal', 'Bahia Portete Kaurrele', 'BahÃ\xada de Jiquilisco', 'BahÃ\xada de Loreto', 'Banco Chinchorro', 'Belize Barrier Reef Reserve System', 'Biscayne', 'Black Point Park and', 'Blanca Jeannette Kawas (Punta Sal)', 'Bogue Islands Lagoon', 'Bogue Lagoon Creek', 'Booby Pond Nature Reserve', 'Booby Pond and Rookery Animal Sanctuary/RAMSAR Site', 'Bosque Estatal de GuÃ¡nica', 'Bower Tract', 'Breton', 'Buenavista', 'Cabezas de San Juan', 'Cades Bay', 'Caladesi Island', 'Canal del Infiernillo y esteros del territorio Comcaac', 'Canaveral', 'Cape St. George', 'Caribe Mexicano Profundo', 'Cas Cay', 'Cayo Levisa- Corona de San Carlos', 'Cayos Miskitos y Franja Costera Inmediata', 'Cedar Keys', 'Cerro Silva', 'Chagres', 'Chamela-Cuixmala', 'Cipanci', 'CiÃ©naga de Zapata', 'CiÃ©nagas y Manglares de la Costa Norte de YucatÃ¡n', 'CiÃ©nega del Fuerte', 'Coconut Point', 'Complejo Jaltepeque', 'Complejo Lagunar BahÃ\xada GuÃ¡simas - Estero Lobos', 'Corcovado', 'Costa Occidental de Isla Mujeres, Punta CancÃºn y Punta Nizuc', 'CotubanamÃ¡ (Del Este)', 'Crandon', 'Crane Point', 'Crocodile Lake', 'Cuencas y corales de la zona costera de Huatulco', 'Curry Hammock', 'Darien National Park', 'DariÃ©n', 'De la Cuenca Alta del Rio Quindio de Salento', 'Delta del Orinoco', 'Dr. Julian G. Bruce St. George Island', 'Dzilam', 'El Palmar', 'El VizcaÃ\xadno', 'Emerson Point', 'Ensenada de Pabellones', 'Estero Bay', 'Estero El Salado', 'Estero El Soldado', 'Estero La Manzanilla', 'Estero Padre Ramos', 'Estero Puntarenas y Manglares Asociados', 'Estero Real', 'Etang des Salines', 'Etangs des Salines', 'Everglades', 'Everglades National Park', 'Farallones de Cali', 'Florida Keys', 'Galeras', 'Galveston Island', 'GalÃ¡pagos', 'GalÃ¡pagos Islands', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'General Use Zone', 'Golfito', 'Gran Humedal del Norte de Ciego de Ã\x81vila', 'Grand Isle', 'Great White Heron', 'Greynolds', 'Guadeloupe', "Guadeloupe [aire d'adhÃ©sion]", 'Guana River Marsh', 'Guana Tolomato Matanzas', 'Guarapiche', 'Gulf Islands', 'Healthshire', 'Honeymoon Island', 'Hugh Taylor Birch', 'Humedal Los ComondÃº', 'Humedal de Importancia para la ConservaciÃ³n de Aves AcuÃ¡ticas Reserva RÃ\xado Lagartos', 'Humedales Mogote - Ensenada de La Paz', 'Humedales de Yavaros - Moroncarit', 'Humedales de la Laguna la Cruz', 'Humedales del norte de Ciego de Avila', 'Imataca', 'Indian River - Malabar to Vero Beach', 'Isla Contoy', 'Isla Juan Venado', 'Isla MartÃ\xadn PÃ©rez', 'Isla San lucas', 'Isla de Salamanca', 'Islands and Protected Areas of the Gulf of California', 'Islas MarÃ\xadas', 'Islas del Golfo de California', 'Islas del PacÃ\xadfico de la PenÃ\xadnsula de Baja California', 'Isles Dernieres Barrier Islands', 'J.N. Ding Darling', 'Jeff Lewis', 'Jobos Bay', 'John Pennekamp Coral Reef', 'La Encrucijada', 'La Mancha y El Llano', 'La Tovara', 'La porciÃ³n norte y la franja costera oriental, terrestres y marinas de la Isla de Cozumel', 'Laguna Atascosa', 'Laguna Huizache Caimanero', 'Laguna Madre', 'Laguna Madre y Delta del RÃ\xado Bravo', 'Laguna Playa Colorada-Santa Marea La Reforma', 'Laguna de TÃ©rminos', 'Lagunas Costeras y Serranias AledaÃ±as de la Costa de Michoacan', 'Lagunas de Chacahua', 'Lagunas de Santa MarÃ\xada-Topolobampo-Ohuira', 'Las Dunas de las Calderas', 'Leon Levy Native Plant Preserve', 'Lignumvitae Key', 'Limestone Creek', 'Litoral Central', 'Long Key', 'Los Corales del Rosario y San Bernardo', 'Los Delgaditos', 'Los Flamencos', 'Los Petenes', 'Los Tuxtlas', 'Lovers Key', 'Lower Rio Grande Va ...
