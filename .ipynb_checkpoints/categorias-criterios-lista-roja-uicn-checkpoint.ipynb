# %% [markdown]
# # Categorías y criterios de la Lista Roja de la UICN

# %% [markdown]
# Este [Jupyter Notebook](https://jupyter.org/), desarrollado en el lenguaje de programación [Python](https://www.python.org/), aplica las categorías y criterios de la [Lista Roja de la Unión Internacional para la Conservación de la Naturaleza (UICN)](https://www.iucnredlist.org/es/).

# %% [markdown]
# **Entradas**
# - Un archivo CSV con nombres científicos de especies.
#
# **Procesamiento**
# - Se obtienen las llaves (*keys*) de las especies en el [API de GBIF](https://www.gbif.org/developer/summary).
# - En caso de ser necesario, se filtran las llaves (ej. se conservan solo las de nombres que tengan coincidencia exacta o solo las de nombres aceptados).
# - Con base en la lista de llaves, se construye una consulta para el [portal de GBIF](https://www.gbif.org/).
# - El resultado de la consulta al portal se descarga y se renombra como "occurrences.csv".
# - Se recorre el archivo "occurrences.csv" para generar las salidas que se describen seguidamente.
#
# **Salidas**
#
# Para cada especie en el archivo de entrada, se genera:
# - Un registro en un archivo CSV con las siguientes columnas:
#   - Extensión de presencia (EOO).
#   - Área de ocupación (AOO).
#   - Lista de países con registros de presencia.
# - Un mapa de registros de presencia.
# - Un mapa de registros de presencia agrupados (en *clusters*).
# - Un mapa de calor.

# %% [markdown]
# **Bibliotecas de Python**

# %%
import requests
import json
import io

import csv

import pandas as pd
import geopandas as gpd
import numpy as np
from scipy.spatial import ConvexHull

import folium
from folium import plugins

import fiona
from shapely.geometry import shape, Point

from pyproj import Proj, transform

import matplotlib.pyplot as plt
# %matplotlib inline

import calendar

# El siguiente archivo debe estar en el mismo directorio que este notebook
from functions_query_from_species_list import *

# %% [markdown]
# **Constantes**

# %%
# Credenciales para el API de GBIF
GBIF_USER_NAME = "usuario"
GBIF_PASSWORD = "clave"
GBIF_NOTIFICATION_ADDRESSES = "direccion_correo"
GBIF_DOWNLOAD_FORMAT = "SIMPLE_CSV"

# Proyecciones cartográficas para los cálculos de EOO y AOO
INPUT_PROJECTION = Proj(init='epsg:4326')
OUTPUT_PROJECTION = Proj(init='epsg:3857')

# Límites y dimensiones de la cuadrícula para el cálculo del AOO.
# Deben especificarse en las unidades del sistema espacial de referencia (SRS) que se utiliza.
# Por ejemplo, para el caso de Web Mercator (EPSG:3857), deben especificarse en metros.
# Límites de la cuadrícula
AOO_GRID_X_MIN = -15000000
AOO_GRID_X_MAX = -4000000
AOO_GRID_Y_MIN = -7000000
AOO_GRID_Y_MAX = 7000000
# Dimensiones de la cuadrícula
AOO_GRID_CELL_X_WIDTH = 2000
AOO_GRID_CELL_Y_WIDTH = 2000
AOO_GRID_CELL_AREA = AOO_GRID_CELL_X_WIDTH * AOO_GRID_CELL_Y_WIDTH

# Directorio de entrada
INPUT_DIR = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/"

# Archivo CSV de entrada con lista de especies a procesar
INPUT_CHECKLIST = INPUT_DIR + "Abarema_racemiflora-Axinaea_costaricensis-lista-especies.csv"
# Columna con el nombre científico de la especie
INPUT_SCINAME_COL = "Taxon Name"

# Archivo CSV con registros de presencia
OCCURRENCES_CSV = INPUT_DIR + "Abarema_racemiflora-Axinaea_costaricensis-registros-presencia.csv"

# Archivo CSV con especies del archivo de entrada que no se procesan
INPUT_CHECKLIST_NON_PROCESSED = INPUT_DIR + "Abarema_racemiflora-Axinaea_costaricensis-lista-especies-no-procesadas.csv"

# Directorio de salida
OUTPUT_DIR = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abarema_racemiflora-Axinaea_costaricensis/"
# Archivo CSV de salida
OUTPUT_CSV = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abarema_racemiflora-Axinaea_costaricensis-evaluacion.csv"
# Archivo HTML de salida
OUTPUT_HTML = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abarema_racemiflora-Axinaea_costaricensis-evaluacion.html"
# URL de salida
OUTPUT_BASE_URL_MAP = "https://evaluacion-arboles-mesoamerica.github.io/Abarema_racemiflora-Axinaea_costaricensis/"
OUTPUT_BASE_URL_CSV = "https://github.com/evaluacion-arboles-mesoamerica/Abarema_racemiflora-Axinaea_costaricensis/blob/master/"

# Capa geoespacial de áreas protegidas
PROTECTED_AREAS_LAYER = "C:/Users/mfvargas/geodatos/wdpa/WDPA_Mesoamerica.shp"

# Número máximo de registros a desplegar en los dataframes de Pandas
pd.options.display.max_rows = 15

# %% [markdown]
# ## Carga de datos

# %%
# Carga del archivo CSV de entrada en un dataframe de Pandas
input_species_df = pd.read_csv(INPUT_CHECKLIST, encoding='utf_8')

input_species_df
# Out:
#              Family        Genus          Species                Taxon Name  \
# 0          FABACEAE      Abarema      racemiflora       Abarema racemiflora
# 1         MALVACEAE     Abutilon         purpusii         Abutilon purpusii
# 2     EUPHORBIACEAE     Acalypha       ferdinandi       Acalypha ferdinandi
# 3         LAMIACEAE    Aegiphila       panamensis      Aegiphila panamensis
# 4        OPILIACEAE    Agonandra       macrocarpa      Agonandra macrocarpa
# 5         LAURACEAE       Aiouea         brenesii           Aiouea brenesii
# 6         LAURACEAE       Aiouea     chavarrianum       Aiouea chavarrianum
# ..              ...          ...              ...                       ...
# 59        ARECACEAE  Astrocaryum     standleyanum  Astrocaryum standleyanum
# 60   PHYLLANTHACEAE   Astrocasia          peltata        Astrocasia peltata
# 61         FABACEAE      Ateleia  herbert-smithii   Ateleia herbert-smithii
# 62         FABACEAE      Ateleia       pterocarpa        Ateleia pterocarpa
# 63    AVICENNIACEAE    Avicennia          bicolor         Avicennia bicolor
# 64    AVICENNIACEAE    Avicennia        germinans       Avicennia germinans
# 65  MELASTOMATACEAE      Axinaea    costaricensis     Axinaea costaricensis
#
#    Category Criteria IUCN Assessment completed  \
# 0        LC      NaN                       NaN
# 1       NaN      NaN                       NaN
# 2       NaN      NaN                       NaN
# 3       NaN      NaN                       NaN
# 4       NaN      NaN                       NaN
# 5       NaN      NaN                       NaN
# 6       NaN      NaN                       NaN
# ..      ...      ...                       ...
# 59      NaN      NaN                       NaN
# 60      NaN      NaN                       NaN
# 61      NaN      NaN                       NaN
# 62       LC      NaN                       NaN
# 63       VU     A2cd                       NaN
# 64       LC      NaN                       NaN
# 65      NaN      NaN      Kew to compile draft
#
#                                 Notes Endemic? Information inputted into SIS  \
# 0   To send to David Neill for review       no                           yes
# 1                                 NaN      NaN                           NaN
# 2                                 NaN      NaN                           NaN
# 3                     1998 assessment      NaN                           NaN
# 4                     1998 assessment      NaN                           NaN
# 5                                 NaN      NaN                           NaN
# 6                                 NaN      NaN                           NaN
# ..                                ...      ...                           ...
# 59                                NaN      NaN                           NaN
# 60                                NaN      NaN                           NaN
# 61                                NaN      NaN                           NaN
# 62                                NaN      NaN                           NaN
# 63                    2008 assessment      NaN                           NaN
# 64                    2007 assessment      NaN                           NaN
# 65                                NaN      NaN                           NaN
#
#     Assessment reviewed Map completed  Submitted to IUCN
# 0                   NaN           yes                NaN
# 1                   NaN           NaN                NaN
# 2                   NaN           NaN                NaN
# 3                   NaN           NaN                NaN
# 4                   NaN           NaN                NaN
# 5                   NaN           NaN                NaN
# 6                   NaN           NaN                NaN
# ..                  ...           ...                ...
# 59                  NaN           NaN                NaN
# 60                  NaN           NaN                NaN
# 61                  NaN           NaN                NaN
# 62                  NaN           NaN                NaN
# 63                  NaN           NaN                NaN
# 64                  NaN           NaN                NaN
# 65                  NaN           NaN                NaN
#
# [66 rows x 13 columns]

# %% [markdown]
# Se consulta el API de GBIF para obtener las llaves (*keys*) de las especies

# %%
# Se obtienen las llaves de las especies a través del API de GBIF
gbif_species_df = match_species(input_species_df, INPUT_SCINAME_COL)

gbif_species_df[['inputName', 'species', 'genus', 'family', 'matchType', 'status', 'synonym', 'speciesKey', 'usageKey', 'rank', 'alternatives']]
# Out:
#                    inputName                   species        genus  \
# 0        Abarema racemiflora       Abarema racemiflora      Abarema
# 1          Abutilon purpusii       Callianthe purpusii   Callianthe
# 2        Acalypha ferdinandi       Acalypha ferdinandi     Acalypha
# 3       Aegiphila panamensis      Aegiphila panamensis    Aegiphila
# 4       Agonandra macrocarpa      Agonandra macrocarpa    Agonandra
# 5            Aiouea brenesii           Aiouea brenesii       Aiouea
# 6        Aiouea chavarrianum        Aiouea chavarriana       Aiouea
# ..                       ...                       ...          ...
# 59  Astrocaryum standleyanum  Astrocaryum standleyanum  Astrocaryum
# 60        Astrocasia peltata        Astrocasia peltata   Astrocasia
# 61   Ateleia herbert-smithii   Ateleia herbert-smithii      Ateleia
# 62        Ateleia pterocarpa        Ateleia pterocarpa      Ateleia
# 63         Avicennia bicolor         Avicennia bicolor    Avicennia
# 64       Avicennia germinans       Avicennia germinans    Avicennia
# 65     Axinaea costaricensis     Axinaea costaricensis      Axinaea
#
#              family matchType    status  synonym  speciesKey  usageKey  \
# 0          Fabaceae     EXACT  ACCEPTED    False     2977909   2977909
# 1         Malvaceae     EXACT   SYNONYM     True     8418086   3936341
# 2     Euphorbiaceae     EXACT  ACCEPTED    False     7276169   7276169
# 3         Lamiaceae     EXACT  ACCEPTED    False     3891222   3891222
# 4        Opiliaceae     EXACT  ACCEPTED    False     3658839   3658839
# 5         Lauraceae     EXACT  ACCEPTED    False     9665460   9665460
# 6         Lauraceae     FUZZY  ACCEPTED    False     9695833   9695833
# ..              ...       ...       ...      ...         ...       ...
# 59        Arecaceae     EXACT  ACCEPTED    False     2738130   2738130
# 60   Phyllanthaceae     EXACT  ACCEPTED    False     3076391   3076391
# 61         Fabaceae     EXACT  ACCEPTED    False     5361723   5361723
# 62         Fabaceae     EXACT  ACCEPTED    False     5361724   5361724
# 63      Acanthaceae     EXACT  ACCEPTED    False     4196610   4196610
# 64      Acanthaceae     EXACT  ACCEPTED    False     2925400   2925400
# 65  Melastomataceae     EXACT  ACCEPTED    False     5601145   5601145
#
#        rank                                       alternatives
# 0   SPECIES                                               NULL
# 1   SPECIES                                               NULL
# 2   SPECIES                                               NULL
# 3   SPECIES  [{'usageKey': 3891182, 'scientificName': 'Aegi...
# 4   SPECIES  [{'usageKey': 7924587, 'scientificName': 'Adin...
# 5   SPECIES                                               NULL
# 6   SPECIES                                               NULL
# ..      ...                                                ...
# 59  SPECIES                                               NULL
# 60  SPECIES                                               NULL
# 61  SPECIES                                               NULL
# 62  SPECIES  [{'usageKey': 7388007, 'acceptedUsageKey': 536...
# 63  SPECIES                                               NULL
# 64  SPECIES  [{'usageKey': 7782491, 'acceptedUsageKey': 292...
# 65  SPECIES  [{'usageKey': 5601148, 'scientificName': 'Axin...
#
# [66 rows x 11 columns]

# %%
# Se construye una lista de nombres excluídos por no ser aceptados o con coincidencia no exacta
gbif_species_df = gbif_species_df[['inputName', 'species', 'genus', 'family', 'matchType', 'status', 'synonym', 'speciesKey', 'usageKey', 'rank', 'alternatives']]
gbif_species_non_processed_df = gbif_species_df.loc[~((gbif_species_df["matchType"]=="EXACT") & (gbif_species_df["status"]=="ACCEPTED"))]

gbif_species_non_processed_df.to_csv(INPUT_CHECKLIST_NON_PROCESSED)

# %%
# Se separa la lista de llaves

# Se filtran las llaves (en caso de ser necesario)
gbif_species_df = gbif_species_df.loc[(gbif_species_df["matchType"]=="EXACT") & (gbif_species_df["status"]=="ACCEPTED")]
key_list = gbif_species_df.usageKey.tolist()

key_list
# Out:
# [2977909,
#  7276169,
#  3891222,
#  3658839,
#  9665460,
#  9810051,
#  4183412,
#  9700381,
#  9744148,
#  2738670,
#  3796445,
#  4205554,
#  5335637,
#  5334877,
#  2901143,
#  7881320,
#  4094049,
#  4094040,
#  5593053,
#  5594889,
#  3156862,
#  4180153,
#  5541648,
#  5592412,
#  2897338,
#  2897216,
#  2897443,
#  2897213,
#  2897678,
#  2897223,
#  2897261,
#  2897503,
#  5558134,
#  5558011,
#  5557693,
#  5557608,
#  5557440,
#  5557397,
#  5558831,
#  5558457,
#  5558632,
#  5558476,
#  7331075,
#  5558442,
#  5557750,
#  5557482,
#  5558709,
#  5558656,
#  7331093,
#  5557619,
#  5557514,
#  5557395,
#  5558834,
#  2738123,
#  2738088,
#  2738130,
#  3076391,
#  5361723,
#  5361724,
#  4196610,
#  2925400,
#  5601145]

# %% [markdown]
# Se construye una consulta para descarga en el portal de GBIF

# %%
# Se construye una consulta para descarga en el portal de GBIF
download_query = {}
download_query["creator"] = GBIF_USER_NAME
download_query["notificationAddresses"] = [GBIF_NOTIFICATION_ADDRESSES]
download_query["sendNotification"] = True
download_query["format"] = GBIF_DOWNLOAD_FORMAT
download_query["predicate"] =   {"type":"and", "predicates": 
                                 [
                                    {"type":"equals", "key":"HAS_COORDINATE",       "value":"true"},
                                    {"type":"equals", "key":"HAS_GEOSPATIAL_ISSUE", "value":"false"}, 
                                    {"type":"in",     "key": "TAXON_KEY",           "values":key_list}
                                 ]
                                }

download_query
# Out:
# {'creator': 'mvargas',
#  'notificationAddresses': ['mvargas@inbio.ac.cr'],
#  'sendNotification': True,
#  'format': 'SIMPLE_CSV',
#  'predicate': {'type': 'and',
#   'predicates': [{'type': 'equals', 'key': 'HAS_COORDINATE', 'value': 'true'},
#    {'type': 'equals', 'key': 'HAS_GEOSPATIAL_ISSUE', 'value': 'false'},
#    {'type': 'in',
#     'key': 'TAXON_KEY',
#     'values': [2977909,
#      7276169,
#      3891222,
#      3658839,
#      9665460,
#      9810051,
#      4183412,
#      9700381,
#      9744148,
#      2738670,
#      3796445,
#      4205554,
#      5335637,
#      5334877,
#      2901143,
#      7881320,
#      4094049,
#      4094040,
#      5593053,
#      5594889,
#      3156862,
#      4180153,
#      5541648,
#      5592412,
#      2897338,
#      2897216,
#      2897443,
#      2897213,
#      2897678,
#      2897223,
#      2897261,
#      2897503,
#      5558134,
#      5558011,
#      5557693,
#      5557608,
#      5557440,
#      5557397,
#      5558831,
#      5558457,
#      5558632,
#      5558476,
#      7331075,
#      5558442,
#      5557750,
#      5557482,
#      5558709,
#      5558656,
#      7331093,
#      5557619,
#      5557514,
#      5557395,
#      5558834,
#      2738123,
#      2738088,
#      2738130,
#      3076391,
#      5361723,
#      5361724,
#      4196610,
#      2925400,
#      5601145]}]}}

# %%
# Submit query to GBIF API
create_download_given_query(GBIF_USER_NAME, GBIF_PASSWORD, download_query)

# Respuesta esperada:
# ok
# <Response [201]>

# %% [markdown]
# **After downloading the file from the GBIF portal if has to be unzipped and renamed with the name defined in OCCURRENCES_CSV**

# %%
occurrences_df = pd.read_csv(OCCURRENCES_CSV, sep='\t')

occurrences_df
# Out:
#            gbifID                            datasetKey  \
# 0      2425451579  4300f8d5-1ae5-49e5-a101-63894b005868
# 1      2425451267  4300f8d5-1ae5-49e5-a101-63894b005868
# 2      2425451067  4300f8d5-1ae5-49e5-a101-63894b005868
# 3      2424848855  9b7d1acf-b22f-4a1f-b6e8-f1ddd744dc07
# 4      2424845334  9b7d1acf-b22f-4a1f-b6e8-f1ddd744dc07
# 5      2424840472  9b7d1acf-b22f-4a1f-b6e8-f1ddd744dc07
# 6      2424761898  9b7d1acf-b22f-4a1f-b6e8-f1ddd744dc07
# ...           ...                                   ...
# 10112     7388177  857bce66-f762-11e1-a439-00145eb45e9a
# 10113     7388175  857bce66-f762-11e1-a439-00145eb45e9a
# 10114     7388173  857bce66-f762-11e1-a439-00145eb45e9a
# 10115     7388171  857bce66-f762-11e1-a439-00145eb45e9a
# 10116     7388169  857bce66-f762-11e1-a439-00145eb45e9a
# 10117     7388167  857bce66-f762-11e1-a439-00145eb45e9a
# 10118     7388165  857bce66-f762-11e1-a439-00145eb45e9a
#
#                                  occurrenceID  kingdom        phylum  \
# 0                 urn:catalog:JBRJ:RB:1419778  Plantae  Tracheophyta
# 1                 urn:catalog:JBRJ:RB:1419941  Plantae  Tracheophyta
# 2                 urn:catalog:JBRJ:RB:1419800  Plantae  Tracheophyta
# 3      {36903AD0-AE51-4D34-B3C7-BF32A5F6612D}  Plantae  Tracheophyta
# 4      {184E56B9-37EB-4112-B04A-72D95EFD7683}  Plantae  Tracheophyta
# 5      {7B37217E-E27F-4C03-B7A4-860BBD2BEFB9}  Plantae  Tracheophyta
# 6      {4F9B79B4-A60E-42F4-841F-2EC49E2C5D06}  Plantae  Tracheophyta
# ...                                       ...      ...           ...
# 10112                                     NaN  Plantae  Tracheophyta
# 10113                                     NaN  Plantae  Tracheophyta
# 10114                                     NaN  Plantae  Tracheophyta
# 10115                                     NaN  Plantae  Tracheophyta
# 10116                                     NaN  Plantae  Tracheophyta
# 10117                                     NaN  Plantae  Tracheophyta
# 10118                                     NaN  Plantae  Tracheophyta
#
#                class        order       family         genus  \
# 0      Magnoliopsida     Lamiales  Acanthaceae     Avicennia
# 1      Magnoliopsida     Lamiales  Acanthaceae     Avicennia
# 2      Magnoliopsida     Lamiales  Acanthaceae     Avicennia
# 3      Magnoliopsida  Gentianales    Rubiaceae  Arachnothryx
# 4      Magnoliopsida     Lamiales  Acanthaceae     Avicennia
# 5      Magnoliopsida     Lamiales  Acanthaceae     Avicennia
# 6      Magnoliopsida     Lamiales  Acanthaceae     Avicennia
# ...              ...          ...          ...           ...
# 10112  Magnoliopsida     Ericales  Primulaceae       Ardisia
# 10113  Magnoliopsida     Ericales  Primulaceae       Ardisia
# 10114  Magnoliopsida     Ericales  Primulaceae       Ardisia
# 10115  Magnoliopsida     Ericales  Primulaceae       Ardisia
# 10116  Magnoliopsida     Ericales  Primulaceae       Ardisia
# 10117  Magnoliopsida     Ericales  Primulaceae       Ardisia
# 10118  Magnoliopsida     Ericales  Primulaceae       Ardisia
#
#                           species  ...                      identifiedBy  \
# 0             Avicennia germinans  ...                        C.S. Nunes
# 1             Avicennia germinans  ...                        C.S. Nunes
# 2             Avicennia germinans  ...                          R. Moura
# 3      Arachnothryx costaricensis  ...                               NaN
# 4             Avicennia germinans  ...                               NaN
# 5             Avicennia germinans  ...                               NaN
# 6             Avicennia germinans  ...                               NaN
# ...                           ...  ...                               ...
# 10112          Ardisia dunlapiana  ...  Huber Werner, Weissenhofer Anton
# 10113          Ardisia dunlapiana  ...  Huber Werner, Weissenhofer Anton
# 10114          Ardisia dunlapiana  ...                      Huber Werner
# 10115              Ardisia dodgei  ...  Huber Werner, Weissenhofer Anton
# 10116              Ardisia dodgei  ...  Huber Werner, Weissenhofer Anton
# 10117              Ardisia dodgei  ...  Huber Werner, Weissenhofer Anton
# 10118              Ardisia dodgei  ...  Huber Werner, Weissenhofer Anton
#
#              dateIdentified       license                     rightsHolder  \
# 0      2018-10-23T00:00:00Z     CC_BY_4_0  Rio de Janeiro Botanical Garden
# 1      2018-10-23T00:00:00Z     CC_BY_4_0  Rio de Janeiro Botanical Garden
# 2                       NaN     CC_BY_4_0  Rio de Janeiro Botanical Garden
# 3                       NaN  CC_BY_NC_4_0                              NaN
# 4                       NaN  CC_BY_NC_4_0                              NaN
# 5                       NaN  CC_BY_NC_4_0                              NaN
# 6                       NaN  CC_BY_NC_4_0                              NaN
# ...                     ...           ...                              ...
# 10112                   NaN       CC0_1_0                              NaN
# 10113                   NaN       CC0_1_0                              NaN
# 10114                   NaN       CC0_1_0                              NaN
# 10115                   NaN       CC0_1_0                              NaN
# 10116                   NaN       CC0_1_0                              NaN
# 10117                   NaN       CC0_1_0                              NaN
# 10118                   NaN       CC0_1_0                              NaN
#
#                                          recordedBy typeStatus  \
# 0                                        M.O. Sousa        NaN
# 1                                        M.O. Sousa        NaN
# 2                                  D. Poczwardowski        NaN
# 3                      Gayle C. Jones; Lynden Facey        NaN
# 4                                           W. Hahn        NaN
# 5      Alfonso Medel Narvaez; J. Rebman, P. Breslin        NaN
# 6                      Alfonso Medel Narvaez; cols.        NaN
# ...                                             ...        ...
# 10112              Huber Werner, Weissenhofer Anton        NaN
# 10113              Huber Werner, Weissenhofer Anton        NaN
# 10114                  Arauz Suarez Eduardo Gerrado        NaN
# 10115              Huber Werner, Weissenhofer Anton        NaN
# 10116              Huber Werner, Weissenhofer Anton        NaN
# 10117              Huber Werner, Weissenhofer Anton        NaN
# 10118              Huber Werner, Weissenhofer Anton        NaN
#
#       establishmentMeans           lastInterpreted   mediaType  \
# 0                    NaN  2019-10-17T02:00:00.085Z         NaN
# 1                    NaN  2019-10-17T02:00:01.333Z         NaN
# 2                    NaN  2019-10-17T01:59:58.819Z         NaN
# 3                    NaN  2019-10-07T14:28:28.855Z         NaN
# 4                    NaN  2019-10-07T14:28:25.208Z         NaN
# 5                    NaN  2019-10-07T14:28:19.957Z  STILLIMAGE
# 6                    NaN  2019-10-07T14:26:55.005Z         NaN
# ...                  ...                       ...         ...
# 10112                NaN  2019-09-20T16:19:32.179Z         NaN
# 10113                NaN  2019-09-20T16:19:32.178Z         NaN
# 10114                NaN  2019-09-20T16:19:32.179Z         NaN
# 10115                NaN  2019-09-20T16:19:36.315Z         NaN
# 10116                NaN  2019-09-20T16:19:32.437Z         NaN
# 10117                NaN  2019-09-20T16:19:33.096Z         NaN
# 10118                NaN  2019-09-20T16:19:32.256Z         NaN
#
#                                                    issue
# 0        GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 1        GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 2                           GEODETIC_DATUM_ASSUMED_WGS84
# 3      GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_IN...
# 4      GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_IN...
# 5      GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_IN...
# 6      GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_IN...
# ...                                                  ...
# 10112  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 10113  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 10114  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 10115  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 10116  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 10117  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
# 10118  BASIS_OF_RECORD_INVALID;GEODETIC_DATUM_ASSUMED...
#
# [10119 rows x 50 columns]

# %%
# Change "eventDate" data type to dateTime
occurrences_df["eventDate"] = pd.to_datetime(occurrences_df["eventDate"])

# %%
# ==================== CREACIÓN DEL DATAFRAME DE ÁREAS PROTEGIDAS ====================
wdpa_gdf = gpd.read_file(PROTECTED_AREAS_LAYER, encoding="latin-1")
wdpa_gdf.index.name = "index_wdpa"


# ==================== CREACIÓN DE LOS ARCHIVOS DE SALIDA ====================

# Archivo CSV
results_csv = open(OUTPUT_CSV, mode='w', newline='', encoding="latin-1")
results_csv_writer = csv.writer(results_csv, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
results_csv_writer.writerow(['Nombre cientifico de entrada', 
                             'Familia (GBIF)', 
                             'Genero (GBIF)', 
                             'Especie (GBIF)', 
                             'EOO (km2)', 
                             'AOO (km2)',
                             'Altitud minima (m)', 
                             'Altitud maxima (m)',
                             'Países', 
                             'Areas protegidas',
                             'Mapa de registros de presencia', 
                             'Mapa agrupado',
                             'Archivo CSV con registros de presencia'])

# Archivo HTML
results_html = open(OUTPUT_HTML, mode='w', newline='', encoding="latin-1")
results_html.write("<!DOCTYPE html>")
results_html.write('<html lang="es">')
results_html.write("<head>")
results_html.write("<title>Evaluacion de arboles de Mesoamerica</title>")
results_html.write("<style>table, th, td {border: 1px solid black;}</style>")
results_html.write("</head>")
results_html.write("<body>")
results_html.write("<table>")
results_html.write("<tr><th>Nombre cientifico de entrada</th><th>Familia (GBIF)</th><th>Genero (GBIF)</th><th>Especie (GBIF)</th><th>EOO (km2)</th><th>AOO (km2)</th><th>Altitud minima (m)</th><th>Altitud maxima (m)</th><th>Paises</th><th>Areas protegidas</th><th>Mapa de registros de presencia</th><th>Mapa agrupado</th><th>Archivo CSV con registros de presencia</th></tr>")
results_html.write("<tbody>")


# ==================== RECORRIDO DE LA LISTA DE ESPECIES ====================

for index, row in gbif_species_df.iterrows():
    species_input = row["inputName"]
    family_gbif = row["family"]
    genus_gbif = row["genus"]
    species_gbif = row["species"]
    print(species_gbif)

    current_taxon_df = occurrences_df[occurrences_df['species'] == species_gbif]    

    
    # ==================== ESTRUCTURAS PARA EL CÁLCULO DEL EOO Y DEL AOO ====================    

    # Lista de puntos para el cálculo del EOO
    eoo_points = []   
    
    # Lista de valores de (x,y) para el cálculo del AOO
    aoo_x_values = []
    aoo_y_values = []   
    
    
    # ==================== ESTRUCTURAS PARA EL CÁLCULO DE LAS ALTITUDES MÍNIMA Y MÁXIMA ====================    

    altitude_values = []

    
    # ==================== ESTRUCTURAS PARA LA GENERACIÓN DE LA LISTA DE PAÍSES ====================    
    
    # Conjunto de códigos de países en los que hay registros de presencia
    countries = set()
    

    # ==================== ESTRUCTURAS PARA LA GENERACIÓN DE LA LISTA DE ÁREAS PROTEGIDAS ====================    
    
    # Arreglo de códigos de países en los que hay registros de presencia    
    current_taxon_geom = [Point(xy) for xy in zip(current_taxon_df["decimalLongitude"], 
                                                  current_taxon_df["decimalLatitude"])]
    current_taxon_gdf = gpd.GeoDataFrame(current_taxon_df, 
                                         crs={"init": "epsg:4326"}, 
                                         geometry=current_taxon_geom)
    
    wdpa_ocuppied = gpd.sjoin(wdpa_gdf, current_taxon_gdf, how="inner", op='intersects')
    protected_areas = wdpa_ocuppied.NAME.unique()    
           
        
    # ==================== INICIALIZACIÓN DE MAPAS ====================
    
    # Mapa de registros de presencia
    occurrences_map = folium.Map(location=[9.63, -84], 
                                 tiles='OpenStreetMap', 
                                 attr='OpenStreetMap', 
                                 zoom_start=5, 
                                 control_scale=True)
    folium.TileLayer(tiles='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/MapServer/tile/{z}/{y}/{x}',
                     name='ESRI World Imagery',
                     attr='ESRI World Imagery').add_to(occurrences_map)
    
    # Mapa de registros de presencia agrupados (cluster)
    cluster_map = folium.Map(location=[9.63, -84], 
                             tiles='OpenStreetMap', 
                             attr='OpenStreetMap', 
                             zoom_start=5, 
                             control_scale=True)
    folium.TileLayer(tiles='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/MapServer/tile/{z}/{y}/{x}',
                     name='ESRI World Imagery',
                     attr='ESRI World Imagery').add_to(cluster_map)    
    occurrences_cluster = plugins.MarkerCluster().add_to(cluster_map)
        
    
    # ==================== RECORRIDO DE LOS REGISTROS DE PRESENCIA ====================
    for lat, lng, alt, country, m, label in zip(current_taxon_df.decimalLatitude,
                               current_taxon_df.decimalLongitude,
                               current_taxon_df.elevation,
                               current_taxon_df.countryCode,
                               current_taxon_df.eventDate.dt.month,
                               "<strong>Localidad:</strong> "       + current_taxon_df.locality.astype(str)   + "\n"    +
                               "<strong>Elevación:</strong> "       + current_taxon_df.elevation.astype(str)  + " m \n" +
                               "<strong>Fecha:</strong> "           + current_taxon_df.eventDate.astype(str)  + "\n"    +
                               "<strong>Recolectores:</strong> "    + current_taxon_df.recordedBy.astype(str) + "\n"    +
                               "<strong>Identificadores:</strong> " + current_taxon_df.identifiedBy.astype(str)):

        # Adición de valores para el cálculo de las altitudes mínima y máxima
        altitude_values.append(alt)
        
        # Adición de puntos para el cálculo del EOO
        x,y = transform(INPUT_PROJECTION, OUTPUT_PROJECTION, lng, lat)
        eoo_point = []
        eoo_point.append(x)
        eoo_point.append(y)
        eoo_points.append(eoo_point)        
        
        # Adición de valores x,y para el cálculo del AOO
        x,y = transform(INPUT_PROJECTION, OUTPUT_PROJECTION, lng, lat)
        aoo_x_values.append(x)
        aoo_y_values.append(y)
        
        # Adición de códigos de países
        countries.add(country)      
        
        # Adición de registros de presencia al mapa de registros de presencia
        folium.CircleMarker(location=[lat, lng], 
                            radius=3, 
                            color='red', 
                            fill=True,
                            popup=label,
                            fill_color='darkred',
                            fill_opacity=0.6).add_to(occurrences_map)
        
        # Adición de registros de presencia agrupados al mapa de registros de presencia agrupados (cluster)
        folium.Marker(
            location=[lat, lng],
            icon=None,
            popup=label,
        ).add_to(occurrences_cluster)
        
    
    # Cálculo de las altitudes mínima y máxima
    altitude_min = min(altitude_values)
    if (np.isnan(altitude_min)):
        altitude_min_str = ""
    else:
        altitude_min_str = "{:.2f}".format(altitude_min)
    altitude_max = max(altitude_values)
    if (np.isnan(altitude_max)):
        altitude_max_str = ""
    else:
        altitude_max_str = "{:.2f}".format(altitude_max)
    
    print("Altitud mínima:", altitude_min_str)
    print("Altitud máxima:", altitude_max_str)
    
    # Cálculo del EOO
    if (len(eoo_points) > 2):
        a = np.array(eoo_points)
        hull = ConvexHull(a)
        eoo = hull.volume / 1000000
    else:
        eoo = 0
    print("Área de extensión de presencia (EOO):", "{:.2f}".format(eoo), "km2")
  
    # Cálculo del AOO
    x = np.array(aoo_x_values)
    y = np.array(aoo_y_values)
    gridx = np.arange(AOO_GRID_X_MIN, AOO_GRID_X_MAX, AOO_GRID_CELL_X_WIDTH)
    gridy = np.arange(AOO_GRID_Y_MIN, AOO_GRID_Y_MAX, AOO_GRID_CELL_Y_WIDTH)
    grid, _, _ = np.histogram2d(x, y, bins=[gridx, gridy])
    occupied_cells = (grid > 0) 
    aoo = len(grid[occupied_cells]) * (AOO_GRID_CELL_AREA / 1000000)
    print("Área de ocupación (AOO):", "{:.2f}".format(aoo), "km2")
    
    # Lista de países con registros de presencia
    countries = sorted(countries)
    print("Países con registros de presencia:", countries)
    
    # Lista de áreas protegidas con registros de presencia
    protected_areas = sorted(protected_areas)
    print("Áreas protegidas con registros de presencia:", protected_areas)      
        
    # Adición de controles de capas
    folium.LayerControl().add_to(occurrences_map)
    folium.LayerControl().add_to(cluster_map)
   
    
    # Grabado de archivos HTML con los mapas
    occurrences_map.save(OUTPUT_DIR + species_input.replace(" ", "_") + "-mapa_registros_presencia.html")
    cluster_map.save(OUTPUT_DIR + species_input.replace(" ", "_") + "-mapa_agrupado.html")  
    
    # Adición de línea en el archivo CSV de salida
    results_csv_writer.writerow([species_input, 
                                 family_gbif, 
                                 genus_gbif, 
                                 species_gbif, 
                                 "{:.2f}".format(eoo), 
                                 "{:.2f}".format(aoo),
                                 altitude_min_str, 
                                 altitude_max_str,                                  
                                 ', '.join(countries),
                                 ', '.join(protected_areas),
                                 '=HYPERLINK("'+OUTPUT_BASE_URL_MAP + species_input.replace(" ", "_") + '-mapa_registros_presencia.html' + '", "' + 'Enlace al mapa")',
                                 '=HYPERLINK("'+OUTPUT_BASE_URL_MAP + species_input.replace(" ", "_") + '-mapa_agrupado.html'            + '", "' + 'Enlace al mapa")',
                                 '=HYPERLINK("'+OUTPUT_BASE_URL_CSV + species_input.replace(" ", "_") + '-registros_presencia.csv'       + '", "' + 'Enlace al archivo")'])
    
    # Adición de línea en el archivo HTML de salida
    results_html.write("<tr>")
    results_html.write("<td>"+ species_input                 +"</td>")
    results_html.write("<td>"+ family_gbif                   +"</td>")
    results_html.write("<td>"+ genus_gbif                    +"</td>")
    results_html.write("<td>"+ species_gbif                  +"</td>")
    results_html.write("<td>"+ "{:.2f}".format(eoo)          +"</td>")
    results_html.write("<td>"+ "{:.2f}".format(aoo)          +"</td>")
    results_html.write("<td>"+ altitude_min_str              +"</td>")
    results_html.write("<td>"+ altitude_max_str              +"</td>")    
    results_html.write("<td>"+ ', '.join(countries)          +"</td>")
    results_html.write("<td>"+ ', '.join(protected_areas)    +"</td>")
    results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL_MAP + species_input.replace(' ', '_') + '-mapa_registros_presencia.html' +'">Enlace</a>' + "</td>")
    results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL_MAP + species_input.replace(' ', '_') + '-mapa_agrupado.html'            +'">Enlace</a>' + "</td>")
    results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL_CSV + species_input.replace(' ', '_') + '-registros_presencia.csv'       +'">Enlace</a>' + "</td>")    
    results_html.write("</tr>")
    
    # Creación de archivo de registros de presencia de la especie en archivo CSV
    current_taxon_df = current_taxon_df[['basisOfRecord', 'species', 'catalogNumber', 'recordNumber', 'decimalLatitude', 'decimalLongitude', 'locality', 'year', 'recordedBy']]
    current_taxon_df.columns = ['BasisOfRec', 'Binomial', 'CatalogNo', 'CollectID', 'Dec_Lat', 'Dec_Long', 'Dist_comm', 'Event_Year', 'recordedBy']
    current_taxon_df.insert(3,  "Citation",  "GBIF")
    current_taxon_df.insert(5,  "Compiler",  "Manuel Vargas")
    current_taxon_df.insert(6,  "Data_sens", "")    
    current_taxon_df.insert(11, "Origin", 1)    
    current_taxon_df.insert(12, "Presence", 1)
    current_taxon_df.insert(13, "Seasonal", 1)        
    current_taxon_df.insert(14, "Sens_comm", "")
    current_taxon_df.insert(15, "SpatialRef", "WGS84")
    current_taxon_df.insert(16, "YrCompiled", 2019)    
    current_taxon_df.to_csv(OUTPUT_DIR + species_input.replace(" ", "_") + "-registros_presencia.csv")
    
# ==================== CIERRE DE LOS ARCHIVOS DE SALIDA ====================

# Archivo CSV
results_csv.close()

# Archivo HTML
results_html.write("</tbody></table></body></html>")
results_html.close()
# Out:
# Abarema racemiflora
# Altitud mínima: 205.00
# Altitud máxima: 2000.00
# Área de extensión de presencia (EOO): 3369446.21 km2
# Área de ocupación (AOO): 124.00 km2
# Países con registros de presencia: ['BO', 'BR', 'CO', 'CR', 'EC', 'PA']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cordillera Volcanica Central', 'Cotapata', 'Donoso', 'La Selva', 'Las Orquideas', 'Llanganates']
# Acalypha ferdinandi
# Altitud mínima: 0.00
# Altitud máxima: 1550.00
# Área de extensión de presencia (EOO): 803644.48 km2
# Área de ocupación (AOO): 288.00 km2
# Países con registros de presencia: ['CR', 'GT', 'HN', 'MX', 'PE']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Carara', 'Cerro San Gil', 'Cerro de Escazu', 'Cerros de Turrubares', 'El Rodeo', 'La Cangreja', 'Lancetilla', 'Palenque', 'Santa Rosa', 'Volcan Tenorio']
# Aegiphila panamensis
# Altitud mínima: 0.00
# Altitud máxima: 2590.80
# Área de extensión de presencia (EOO): 8450100.76 km2
# Área de ocupación (AOO): 1660.00 km2
# Países con registros de presencia: ['BO', 'BR', 'CO', 'CR', 'EC', 'GF', 'GT', 'HN', 'MX', 'NI', 'PA', 'PE', 'SV', 'VE']
# Áreas protegidas con registros de presencia: ['Alto Orinoco-Casiquiare', 'Amacayacu', 'Antisana', 'Apaneca-Llamatepec', 'ArchipiÃ©lago  de Zapatera', 'Area Natural Protegida Laguna del Jocotal', 'Area de ConservaciÃ³n Guanacaste', 'Barra Honda', 'Barra del Colorado', 'Barro Colorado', 'Bosawas', 'Cahuita', 'Camino de Cruces', 'Cano Negro', 'Carara', 'CaÃ±o Negro', 'Cerro Cumaica Cerro Alegre', 'Cerro El Arenal', 'Cerro Gaital', 'Cerro Mombachito La Vieja', 'Cerro Nara', 'Cerro Silva', 'Cerro Tomabu', 'Cerros de Turrubares', 'Chagres', 'Chirripo', 'Coiba', 'Coiba National Park and its Special Zone of Marine Protection', 'Complejo Laguna GÃ¼ija', 'Complejo VolcÃ¡nico San Cristobal Casitas', 'Complejo de Humedales Cuyabeno Lagartococha YasunÃ\xad', 'Corcovado', 'Cueva de los Guacharos', 'Cuyabeno', 'Darien National Park', 'DariÃ©n', 'Diria', 'Donoso', 'El CajÃ³n', 'El Caura', 'El Montuoso', 'El Rodeo', 'El TamÃ¡', 'Embalse CerrÃ³n Grande', 'Encanto de los manglares del Bajo Baudo', 'Formaciones de Tepuyes', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Guanacaste', 'Humedal Caribe Noreste', 'Indio Maiz', 'Internacional La Amistad', 'La Cangreja', 'La Joya', 'La Paragua', 'Laguna El Jocotal', 'Laguna de Apoyo', 'Las Tablas', 'Los Corales del Rosario y San Bernardo', 'Los Guatuzos', 'Los Santos', 'Manuel Antonio', 'Metropolitano', 'Miraflor/Moropotente', 'Miravalles', 'Nancuchiname (Mata de PiÃ±a, La Maroma, PorciÃ³n 5 y 6)', 'NarganÃ¡', 'Nukak', 'Parque Nacional Montecristo', 'Parque do Xingu', 'Piedras Blancas', 'Plan de Amayo', 'Punchina', 'Punta Gorda', 'Reserva de la BiÃ³sfera de Yasuni', 'Rincon de la Vieja', 'Rio Negro', 'RÃ\xado San Juan', 'San Diego La Barra, laguna, cerro, San felipe (12)', 'Santa Rosa', 'Serrania de los Yariguies', 'SerranÃ\xada de la Neblina', 'Sierra Amerrisque', 'Soberania', 'Sur del Estado BolÃ\xadvar', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero', 'Volcan BarÃº', 'VolcÃ¡n  Masaya', 'VolcÃ¡n Cosiguina', 'Xiriualtique-Jiquilisco', 'Yanesha', 'YasunÃ\xad', 'Zona de Amortiguamiento (Bosawas)', 'Zona de Amortiguamiento (Tisey Estanzuela)', 'Ã\x81rea De ProteÃ§Ã£o Ambiental  Tapuruquara', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Do Lago De Tucurui']
# Agonandra macrocarpa
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 370348.21 km2
# Área de ocupación (AOO): 236.00 km2
# Países con registros de presencia: ['CR', 'HN', 'MX', 'NI']
# Áreas protegidas con registros de presencia: ['Ancient Maya City and Protected Tropical Forests of Calakmul, Campeche', 'Area de ConservaciÃ³n Guanacaste', 'Balam-Ku', 'Calakmul', 'CiÃ©nagas y Manglares de la Costa Norte de YucatÃ¡n', 'Diria', 'Dzilam', 'Guanacaste', 'Humedal de Importancia para la ConservaciÃ³n de Aves AcuÃ¡ticas Reserva RÃ\xado Lagartos', 'Palo Verde', 'RegiÃ³n de Calakmul', 'Reserva Estatal de Dzilam', 'RÃ\xada Lagartos', 'Santa Rosa', 'Tivives']
# Aiouea brenesii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 701285.15 km2
# Área de ocupación (AOO): 168.00 km2
# Países con registros de presencia: ['CO', 'CR', 'HN', 'MX', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Coiba', 'Coiba National Park and its Special Zone of Marine Protection', 'El Rodeo', 'Guanacaste', 'Internacional La Amistad', 'Las Tablas', 'Penas Blancas', 'Rincon de la Vieja', 'Santa Fe', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº', 'YaxchilÃ¡n']
# Aiouea neurophylla
# Altitud mínima: 0.00
# Altitud máxima: 1550.00
# Área de extensión de presencia (EOO): 603005.04 km2
# Área de ocupación (AOO): 156.00 km2
# Países con registros de presencia: ['CR', 'HN', 'MX', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Bosawas', 'Cerro Guabule', 'Cerros de Turrubares', 'Corcovado', 'Golfito', 'Golfo Dulce', 'Humedal Caribe Noreste', 'Lancetilla', 'Las Tablas', 'Piedras Blancas', 'Punta Rio Claro', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero']
# Aiouea obscura
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 111491.53 km2
# Área de ocupación (AOO): 76.00 km2
# Países con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Golfo Dulce']
# Aiouea pittieri
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 98080.68 km2
# Área de ocupación (AOO): 284.00 km2
# Países con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Cerro El Arenal', 'Cerro Hoya', 'Cerro Tisey Estanzuela', 'Cerros de Turrubares', 'Corcovado', 'Fortuna', 'Guanacaste', 'Internacional La Amistad', 'La Cangreja', 'Las Tablas', 'Miraflor/Moropotente', 'Rincon de la Vieja', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Aiouea tonduzii
# Altitud mínima: 0.50
# Altitud máxima: 1850.00
# Área de extensión de presencia (EOO): 102675.80 km2
# Área de ocupación (AOO): 188.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Cerro de Escazu', 'Chirripo', 'Darien National Park', 'DariÃ©n', 'Fortuna', 'Guanacaste', 'La Amistad', 'Las Tablas', 'Los Santos', 'NarganÃ¡', 'Rincon de la Vieja', 'Rio Banano', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Ã\x81rea de Manejo Especial Municipal de Chame (Manglares)']
# Aiphanes hirsuta
# Altitud mínima: 125.00
# Altitud máxima: 2300.00
# Área de extensión de presencia (EOO): 558283.91 km2
# Área de ocupación (AOO): 372.00 km2
# Países con registros de presencia: ['CO', 'CR', 'EC', 'PA']
# Áreas protegidas con registros de presencia: ['Altos de Campana', 'Camelias', 'Canones de los rios Melcocho y Santo Domingo', 'Carauta', 'Cerro Gaital', 'Chagres', 'Cotacachi Cayapas', 'Darien', 'Darien National Park', 'DariÃ©n', 'De Urrao', 'Embalse el Penol y Cuenca Alta del Rio Guatape', 'Fortuna', 'General de DivisiÃ³n Omar Torrijos Herrera', 'La Tebaida', 'Las Orquideas', 'Paramillo', 'Punchina', 'Rio Anchicaya', 'Santa Fe']
# Albizia duckeana
# Altitud mínima: 42.50
# Altitud máxima: 145.00
# Área de extensión de presencia (EOO): 3966291.11 km2
# Área de ocupación (AOO): 40.00 km2
# Países con registros de presencia: ['BR', 'GY', 'HN']
# Áreas protegidas con registros de presencia: ['Parque Estadual Cristalino', 'Tawahka Asangni']
# Alfaroa manningii
# Altitud mínima: 0.00
# Altitud máxima: 2150.00
# Área de extensión de presencia (EOO): 73899.22 km2
# Área de ocupación (AOO): 184.00 km2
# Países con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Barbilla', 'Guanacaste', 'Miravalles', 'Monumento Nacional Guayabo', 'Rincon de la Vieja', 'Rio Pacuare', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan Tenorio']
# Alibertia utleyorum
# Altitud mínima: 0.00
# Altitud máxima: 300.00
# Área de extensión de presencia (EOO): 27313.63 km2
# Área de ocupación (AOO): 80.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Cordillera Volcanica Central', 'Estero Puntarenas y Manglares Asociados', 'Golfo Dulce', 'Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Alseis costaricensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 42715.66 km2
# Área de ocupación (AOO): 116.00 km2
# Países con registros de presencia: ['CR', 'NI']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Carara', 'Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Guanacaste', 'Sureste de Nicaragua']
# Amaioua pedicellata
# Altitud mínima: 118.00
# Altitud máxima: 1600.00
# Área de extensión de presencia (EOO): 73590.07 km2
# Área de ocupación (AOO): 176.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Barbilla', 'Braulio Carrillo', 'Cerro Nara', 'Donoso', 'Fortuna', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Hitoy Cerere', 'Internacional La Amistad', 'La Amistad', 'NarganÃ¡', 'Palo Seco', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Macho', 'Santa Fe', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Amphipterygium molle
# Altitud mínima: 0.00
# Altitud máxima: 2110.00
# Área de extensión de presencia (EOO): 245493.75 km2
# Área de ocupación (AOO): 60.00 km2
# Países con registros de presencia: ['CR', 'MX']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Cuenca Alimentadora del Distrito Nacional de Riego 043 Estado de Nayarit', 'Guanacaste', 'Santa Rosa']
# Amphitecna gentryi
# Altitud mínima: 300.00
# Altitud máxima: 1840.00
# Área de extensión de presencia (EOO): 6421.35 km2
# Área de ocupación (AOO): 108.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Guanacaste', 'Tenorio', 'Volcan Tenorio']
# Amphitecna isthmica
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 124145.84 km2
# Área de ocupación (AOO): 196.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Carara', 'Cerro Gaital', 'Corcovado', 'Darien National Park', 'DariÃ©n', 'Donoso', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'General de DivisiÃ³n Omar Torrijos Herrera', 'Golfito', 'Golfo Dulce', 'La Cangreja', 'Las Tablas', 'Los Santos', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Amyris brenesii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 94880.49 km2
# Área de ocupación (AOO): 132.00 km2
# Países con registros de presencia: ['CR', 'SV']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Arenal', 'Carara', 'Cerro de Escazu', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Hitoy Cerere', 'Humedal Caribe Noreste', 'Internacional La Amistad', 'San Benito I y II', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero']
# Amyris magnifolia
# Altitud mínima: 200.00
# Altitud máxima: 1100.00
# Área de extensión de presencia (EOO): 4898.78 km2
# Área de ocupación (AOO): 28.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Carara', 'Golfo Dulce', 'Piedras Blancas']
# Anaxagorea phaeocarpa
# Altitud mínima: 0.00
# Altitud máxima: 3064.00
# Área de extensión de presencia (EOO): 8721212.41 km2
# Área de ocupación (AOO): 756.00 km2
# Países con registros de presencia: ['BR', 'CO', 'CR', 'EC', 'GF', 'NI', 'PA', 'PE']
# Áreas protegidas con registros de presencia: ['Airo Pai', 'Allpahuayo  Mishana', 'Amacayacu', 'Amazon Estuary and its Mangroves', 'Area de ConservaciÃ³n Guanacaste', 'Barbilla', 'Barra del Colorado', 'Braulio Carrillo', 'Complejo de humedales Lagos de Tarapoto', 'Corcovado', 'Cordillera Volcanica Central', 'Cuyabeno', 'Darien National Park', 'DariÃ©n', 'EstaÃ§Ã£o EcolÃ³gica Do GrÃ£o ParÃ¡', 'Floresta Estadual De Faro', 'Floresta Estadual Do AmapÃ¡', 'Floresta Estadual Do Trombetas', 'Floresta Nacional De CaxiuanÃ£', 'Floresta Nacional De TapajÃ³s', 'Golfo de Tribuga Cabo Corrientes', 'Guanacaste', 'Hitoy Cerere', 'Humedal Caribe Noreste', 'Indio Maiz', 'Internacional La Amistad', 'KararaÃ´', 'La Selva', 'La Sierpe', 'Maquenque', 'Marais De Kaw', 'MaraÃ£ Urubaxi', 'Montagne de Kaw', 'NarganÃ¡', 'Pacaas Novas', 'Parque Ecologico Urbano de Cobija', 'Parque Nacional Da Serra Do Divisor', 'Parque Nacional De PacaÃ¡s Novos', 'Parque Nacional Mapinguari', 'Parque Nacional Montanhas Do Tumucumaque', 'Parque do Xingu', 'Reserva BiolÃ³gica Do Rio Trombetas', 'Reserva De Desenvolvimento SustentÃ¡vel Do Rio Iratapuru', 'Reserva Extrativista MapuÃ¡', 'Reserva de la BiÃ³sfera de Yasuni', 'Rio Negro', 'Rio Pacuare', 'Sureste de Nicaragua', 'SÃ£o Gabriel/SÃ£o Salvador', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero', 'Trombetas/Mapuera', 'Uru-Eu-Wau-Wau', 'Waimiri-Atroari', 'Yaigoje Apaporis', 'Yanomami', 'YasunÃ\xad', 'Ã\x81rea De ProteÃ§Ã£o Ambiental Do ArquipÃ©lago Do MarajÃ³', 'Ã\x89vare I']
# Aniba venezuelana
# Altitud mínima: 4.00
# Altitud máxima: 1900.00
# Área de extensión de presencia (EOO): 811242.68 km2
# Área de ocupación (AOO): 184.00 km2
# Países con registros de presencia: ['CO', 'CR', 'NI', 'VE']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Archie Carr', 'Arenal Monteverde', 'Barbilla', 'Barra del Colorado', 'Corcovado', 'Cordillera Volcanica Central', 'Cuenca Alta del RÃ\xado Cojedes', 'Golfo Dulce', 'Humedal Caribe Noreste', 'Indio Maiz', 'Lapa Verde', 'Los Santos', 'Maquenque', 'Sierra de Nirgua', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tortuguero']
# Annona danforthii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 853488.10 km2
# Área de ocupación (AOO): 108.00 km2
# Países con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Amacayacu', 'Area de ConservaciÃ³n Guanacaste', 'Cerro Nara', 'Complejo de humedales Lagos de Tarapoto', 'Golfo Dulce', 'Guanacaste', 'Las Orquideas', 'Los Santos', 'Rio Banano']
# Anthodiscus chocoensis
# Altitud mínima: 1.00
# Altitud máxima: 1204.00
# Área de extensión de presencia (EOO): 268372.14 km2
# Área de ocupación (AOO): 140.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Donoso', 'Golfito', 'Golfo Dulce', 'La Sierpe', 'Los Santos']
# Arachnothryx aspera
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 2328.39 km2
# Área de ocupación (AOO): 124.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Caraigres', 'Cuenca del Rio Abangares', 'El Rodeo']
# Arachnothryx brenesii
# Altitud mínima: 0.00
# Altitud máxima: 1350.00
# Área de extensión de presencia (EOO): 41688.57 km2
# Área de ocupación (AOO): 136.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Arenal', 'Arenal Monteverde', 'Braulio Carrillo', 'Volcan Tenorio']
# Arachnothryx calycosa
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 24484.27 km2
# Área de ocupación (AOO): 84.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Golfo Dulce', 'La Amistad', 'Reserva de la BiÃ³sfera de La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Arachnothryx chaconii
# Altitud mínima: 620.00
# Altitud máxima: 950.00
# Área de extensión de presencia (EOO): 1624.05 km2
# Área de ocupación (AOO): 36.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Braulio Carrillo', 'La Selva', 'Tenorio']
# Arachnothryx costaricensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 156524.53 km2
# Área de ocupación (AOO): 164.00 km2
# Países con registros de presencia: ['CR', 'GT', 'HN']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Area de ConservaciÃ³n Guanacaste', 'Carara', 'La Amistad', 'La Cangreja', 'Pico Bonito', 'Reserva de la BiÃ³sfera de La Amistad', 'Rincon de la Vieja', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Texiguat', 'Volcan Tenorio']
# Arachnothryx monteverdensis
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 15877.62 km2
# Área de ocupación (AOO): 156.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Cano Negro', 'CaÃ±o Negro', 'Estero Puntarenas y Manglares Asociados', 'Guanacaste', 'Rincon de la Vieja', 'Tenorio', 'Volcan Tenorio']
# Arachnothryx povedae
# Altitud mínima: 150.00
# Altitud máxima: 950.00
# Área de extensión de presencia (EOO): 287.37 km2
# Área de ocupación (AOO): 28.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Carara', 'La Cangreja']
# Arachnothryx tayloriae
# Altitud mínima: 850.00
# Altitud máxima: 1400.00
# Área de extensión de presencia (EOO): 4075.85 km2
# Área de ocupación (AOO): 28.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Arenal Monteverde', 'Cordillera Volcanica Central', 'Internacional La Amistad', 'Rio Banano', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia alajuelae
# Altitud mínima: 1200.00
# Altitud máxima: 1200.00
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 4.00 km2
# Países con registros de presencia: ['NI']
# Áreas protegidas con registros de presencia: []
# Ardisia angucianensis
# Altitud mínima: 1500.00
# Altitud máxima: 1500.00
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 4.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: []
# Ardisia blepharodes
# Altitud mínima: 300.00
# Altitud máxima: 1500.00
# Área de extensión de presencia (EOO): 12104.87 km2
# Área de ocupación (AOO): 40.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Barbilla', 'Golfo Dulce', 'Palo Seco', 'Rio Banano', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia brenesii
# Altitud mínima: 0.00
# Altitud máxima: 1500.00
# Área de extensión de presencia (EOO): 40557.87 km2
# Área de ocupación (AOO): 172.00 km2
# Países con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Alberto Manuel Brenes', 'Arenal Monteverde', 'Barra del Colorado', 'Cordillera Volcanica Central', 'Corredor Fronterizo', 'Humedal Caribe Noreste', 'Indio Maiz', 'Maquenque', 'NarganÃ¡', 'RÃ\xado San Juan', 'Sureste de Nicaragua']
# Ardisia capitellata
# Altitud mínima: 1160.00
# Altitud máxima: 2050.00
# Área de extensión de presencia (EOO): 10309.71 km2
# Área de ocupación (AOO): 72.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Estero Puntarenas y Manglares Asociados', 'Internacional La Amistad', 'Las Tablas', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia cartagoana
# Altitud mínima: 612.50
# Altitud máxima: 1250.00
# Área de extensión de presencia (EOO): 14315.67 km2
# Área de ocupación (AOO): 44.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Terraba-Sierpe']
# Ardisia crassiramea
# Altitud mínima: 650.00
# Altitud máxima: 1720.00
# Área de extensión de presencia (EOO): 3346.75 km2
# Área de ocupación (AOO): 88.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Guanacaste', 'Rincon de la Vieja', 'Volcan Tenorio']
# Ardisia dodgei
# Altitud mínima: 27.50
# Altitud máxima: 2550.00
# Área de extensión de presencia (EOO): 472335.61 km2
# Área de ocupación (AOO): 128.00 km2
# Países con registros de presencia: ['CO', 'CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Cueva de los Guacharos', 'Golfito', 'Golfo Dulce', 'Paramos de Guantiva y la Rusia', 'Piedras Blancas']
# Ardisia dunlapiana
# Altitud mínima: 0.00
# Altitud máxima: 900.00
# Área de extensión de presencia (EOO): 13171.14 km2
# Área de ocupación (AOO): 100.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Estero Puntarenas y Manglares Asociados', 'Golfito', 'Golfo Dulce', 'Piedras Blancas']
# Ardisia furfuracea
# Altitud mínima: 850.00
# Altitud máxima: 2200.00
# Área de extensión de presencia (EOO): 7560.76 km2
# Área de ocupación (AOO): 60.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cordillera Volcanica Central', 'Golfo Dulce', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte']
# Ardisia furfuracella
# Altitud mínima: 10.00
# Altitud máxima: 2115.50
# Área de extensión de presencia (EOO): 80892.02 km2
# Área de ocupación (AOO): 128.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Corcovado', 'El Montuoso', 'Golfo Dulce', 'Las Tablas', 'Los Santos', 'Osa', 'Palo Seco', 'Rincon de la Vieja', 'Rio Navarro-Rio Sombrero', 'Santa Fe', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia generalensis
# Altitud mínima: 300.00
# Altitud máxima: 300.00
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 4.00 km2
# Países con registros de presencia: ['PA']
# Áreas protegidas con registros de presencia: []
# Ardisia liesneri
# Altitud mínima: 5.50
# Altitud máxima: 495.00
# Área de extensión de presencia (EOO): 1386.71 km2
# Área de ocupación (AOO): 100.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Corcovado', 'Golfo Dulce']
# Ardisia maxonii
# Altitud mínima: 1150.00
# Altitud máxima: 2850.00
# Área de extensión de presencia (EOO): 17690.61 km2
# Área de ocupación (AOO): 60.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Chirripo', 'Internacional La Amistad', 'Las Tablas', 'Los Santos', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Volcan BarÃº']
# Ardisia opaca
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 236360.73 km2
# Área de ocupación (AOO): 20.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA']
# Áreas protegidas con registros de presencia: ['Darien National Park', 'DariÃ©n', 'Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia palmana
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1230596.26 km2
# Área de ocupación (AOO): 336.00 km2
# Países con registros de presencia: ['CO', 'CR', 'GY', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Braulio Carrillo', 'Carauta', 'Cerro de Escazu', 'Cerros de Turrubares', 'Cordillera Volcanica Central', 'Curi cancha', 'Estero Puntarenas y Manglares Asociados', 'Fortuna', 'Guanacaste', 'Indio Maiz', 'Internacional La Amistad', 'La Amistad', 'La Selva', 'Las Tablas', 'Los Santos', 'Macizo de PeÃ±as Blancas', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Banano', 'Sureste de Nicaragua', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tenorio', 'Utria', 'Volcan BarÃº', 'Volcan Tenorio', 'VolcÃ¡n Maderas']
# Ardisia pleurobotrya
# Altitud mínima: 0.00
# Altitud máxima: 3100.00
# Área de extensión de presencia (EOO): 19182.55 km2
# Área de ocupación (AOO): 192.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Braulio Carrillo', 'Cordillera Volcanica Central', 'Estero Puntarenas y Manglares Asociados', 'Internacional La Amistad', 'La Amistad', 'Las Tablas', 'Reserva de la BiÃ³sfera de La Amistad', 'Rincon de la Vieja', 'Rio Macho', 'Rio Toro', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan Poas']
# Ardisia storkii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 4.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: []
# Ardisia tarariae
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 144.75 km2
# Área de ocupación (AOO): 40.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Internacional La Amistad', 'Talamanca Range-La Amistad Reserves / La Amistad National Park']
# Ardisia tortuguerensis
# Altitud mínima: 100.00
# Altitud máxima: 100.00
# Área de extensión de presencia (EOO): 0.00 km2
# Área de ocupación (AOO): 8.00 km2
# Países con registros de presencia: ['CR']
# Áreas protegidas con registros de presencia: ['Humedal Caribe Noreste', 'Tortuguero']
# Ardisia wedelii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 190324.92 km2
# Área de ocupación (AOO): 248.00 km2
# Países con registros de presencia: ['CR', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Bosawas', 'Braulio Carrillo', 'Carara', 'Cerro Kilambe', 'Cerro Silva', 'Fortuna', 'Humedal Caribe Noreste', 'Indio Maiz', 'La Selva', 'Palo Seco', 'RÃ\xado San Juan', 'Santa Fe', 'Sureste de Nicaragua', 'Tortuguero', 'Zona de Amortiguamiento (Bosawas)', 'Zona de Emergencia Volcan Arenal']
# Astrocaryum alatum
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 246601.63 km2
# Área de ocupación (AOO): 260.00 km2
# Países con registros de presencia: ['CR', 'HN', 'NI', 'PA']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Arenal Monteverde', 'Barra del Colorado', 'Braulio Carrillo', 'Carara', 'Cerro Bana Cruz', 'Chagres', 'Donoso', 'Estero Puntarenas y Manglares Asociados', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Guanacaste', 'Humedal Caribe Noreste', 'Indio Maiz', 'Santa Fe', 'Soberania', 'Sureste de Nicaragua', 'Zona de Amortiguamiento (Bosawas)']
# Astrocaryum confertum
# Altitud mínima: 50.00
# Altitud máxima: 350.00
# Área de extensión de presencia (EOO): 44098.46 km2
# Área de ocupación (AOO): 40.00 km2
# Países con registros de presencia: ['CR', 'PA']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Donoso', 'Humedal Caribe Noreste', 'La Selva', 'NarganÃ¡', 'Tortuguero']
# Astrocaryum standleyanum
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 1177688.75 km2
# Área de ocupación (AOO): 312.00 km2
# Países con registros de presencia: ['CO', 'CR', 'EC', 'PA']
# Áreas protegidas con registros de presencia: ['Barra del Colorado', 'Barro Colorado', 'Darien', 'Darien National Park', 'DariÃ©n', 'De Los Humedales Entre Los RÃ\xados Leon Y SuriquÃ\xad', 'En el Territorio Colectivo del Consejo Comunitario de la Comunidad Negra de la Plata', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'Golfo Dulce', 'Humedales entre los Rios Leon y Suriqui', 'La Sierpe', 'Los Katios', 'Los KatÃ\xados National Park', 'Machalilla', 'Manglares Churute', 'Manuel Antonio', 'NarganÃ¡', 'Soberania', 'Zona Marina Parque Nacional Machalilla']
# Astrocasia peltata
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 243567.32 km2
# Área de ocupación (AOO): 76.00 km2
# Países con registros de presencia: ['MX']
# Áreas protegidas con registros de presencia: ['Chamela-Cuixmala', 'Islands and Protected Areas of the Gulf of California', 'Islas MarÃ\xadas', 'Islas del Golfo de California', 'Reserva de la Biosfera Chamela-Cuixmala']
# Ateleia herbert-smithii
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 710708.30 km2
# Área de ocupación (AOO): 80.00 km2
# Países con registros de presencia: ['CO', 'CR', 'NI']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'RÃ\xado Escalante Chacocente', 'Santa Rosa', 'Tayrona']
# Ateleia pterocarpa
# Altitud mínima: 0.00
# Altitud máxima: 1250.00
# Área de extensión de presencia (EOO): 1342254.33 km2
# Área de ocupación (AOO): 428.00 km2
# Países con registros de presencia: ['BZ', 'CR', 'GT', 'HN', 'MX', 'NI']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'Cockscomb Basin', 'El Triunfo', 'La Concordia Zaragoza', 'La Sepultura', 'Laguna de TÃ©rminos', 'Los Santos', 'Los Tuxtlas', 'Manglares y humedales de la Laguna de Sontecomapan', 'MontaÃ±as Mayas Chiquibul', 'Montes Azules', 'Parque Nacional YaxhÃ¡-Nakum-Naranjo', 'Santa Rosa', 'Zona de ProtecciÃ³n Forestal en los terrenos que se encuentran en los municipios de La Concordia, Angel Albino Corzo, Villa Flores y Jiquipilas', 'Ã\x81rea de ProtecciÃ³n de Flora y Fauna Laguna de TÃ©rminos']
# Avicennia bicolor
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 455710.75 km2
# Área de ocupación (AOO): 288.00 km2
# Países con registros de presencia: ['CO', 'CR', 'HN', 'NI', 'PA', 'SV']
# Áreas protegidas con registros de presencia: ['Area de ConservaciÃ³n Guanacaste', 'BahÃ\xada de Chismuyo', 'BahÃ\xada de Jiquilisco', 'CenegÃ³n del Mangle', 'Cipanci', 'Estero Puntarenas y Manglares Asociados', 'Estero Real', 'Gorgona', 'Isla Juan Venado', 'Isla San lucas', 'Manglar BahÃ\xada de Jiquilisco', 'Marino las Baulas de Guanacaste', 'Palo Verde', 'Piedras Blancas', 'Santa Rosa', 'Tivives', 'VolcÃ¡n Cosiguina', 'Xiriualtique-Jiquilisco', 'Zona de Amortiguamiento (juan venado)', 'Ã\x81rea de Manejo Especial Municipal de Chame (Manglares)']
# Avicennia germinans
# Altitud mínima:
# Altitud máxima:
# Área de extensión de presencia (EOO): 112664622.30 km2
# Área de ocupación (AOO): 6588.00 km2
# Países con registros de presencia: ['AG', 'AO', 'AW', 'BJ', 'BL', 'BR', 'BS', 'BZ', 'CD', 'CG', 'CI', 'CM', 'CO', 'CR', 'CU', 'CW', 'DE', 'DO', 'EC', 'GA', 'GD', 'GF', 'GH', 'GM', 'GN', 'GP', 'GQ', 'GT', 'GW', 'GY', 'HN', 'HT', 'IR', 'JM', 'KN', 'KY', 'LR', 'MQ', 'MR', 'MX', 'NG', 'NI', 'PA', 'PE', 'PR', 'SL', 'SN', 'SR', 'ST', 'SV', 'TG', 'TT', 'US', 'VC', 'VE', 'VI']
# Áreas protegidas con registros de presencia: ['Agoa', 'Alligator Harbor', 'Amazon Estuary and its Mangroves', 'Anastasia', 'Apalachicola Bay', 'Apalachicola National Estuarine Research Reserve Outstanding Florida Water', 'Aransas', 'ArchipielÃ¡go de ColÃ³n (GalÃ¡pagos)', 'Area de ConservaciÃ³n Guanacaste', 'Arrecife de Puerto Morelos', 'Arrecifes de Cozumel', 'Arrecifes de Xcalak', 'Arrecifes de la Cordillera', 'Bacalar Chico', 'Bahia Honda', 'Bahia Junquillal', 'Bahia Portete Kaurrele', 'BahÃ\xada de Jiquilisco', 'BahÃ\xada de Loreto', 'Banco Chinchorro', 'Belize Barrier Reef Reserve System', 'Biscayne', 'Black Point Park and', 'Blanca Jeannette Kawas (Punta Sal)', 'Bogue Islands Lagoon', 'Bogue Lagoon Creek', 'Booby Pond Nature Reserve', 'Booby Pond and Rookery Animal Sanctuary/RAMSAR Site', 'Bosque Estatal de GuÃ¡nica', 'Bower Tract', 'Breton', 'Buenavista', 'Cabezas de San Juan', 'Cades Bay', 'Caladesi Island', 'Canal del Infiernillo y esteros del territorio Comcaac', 'Canaveral', 'Cape St. George', 'Caribe Mexicano Profundo', 'Cas Cay', 'Cayo Levisa- Corona de San Carlos', 'Cayos Miskitos y Franja Costera Inmediata', 'Cedar Keys', 'Cerro Silva', 'Chagres', 'Chamela-Cuixmala', 'Cipanci', 'CiÃ©naga de Zapata', 'CiÃ©nagas y Manglares de la Costa Norte de YucatÃ¡n', 'CiÃ©nega del Fuerte', 'Coconut Point', 'Complejo Jaltepeque', 'Complejo Lagunar BahÃ\xada GuÃ¡simas - Estero Lobos', 'Corcovado', 'Costa Occidental de Isla Mujeres, Punta CancÃºn y Punta Nizuc', 'CotubanamÃ¡ (Del Este)', 'Crandon', 'Crane Point', 'Crocodile Lake', 'Cuencas y corales de la zona costera de Huatulco', 'Curry Hammock', 'Darien National Park', 'DariÃ©n', 'De la Cuenca Alta del Rio Quindio de Salento', 'Delta del Orinoco', 'Dr. Julian G. Bruce St. George Island', 'Dzilam', 'El Palmar', 'El VizcaÃ\xadno', 'Emerson Point', 'Ensenada de Pabellones', 'Estero Bay', 'Estero El Salado', 'Estero El Soldado', 'Estero La Manzanilla', 'Estero Padre Ramos', 'Estero Puntarenas y Manglares Asociados', 'Estero Real', 'Etang des Salines', 'Etangs des Salines', 'Everglades', 'Everglades National Park', 'Farallones de Cali', 'Florida Keys', 'Galeras', 'Galveston Island', 'GalÃ¡pagos', 'GalÃ¡pagos Islands', 'Gandoca Manzanillo', 'Gandoca-Manzanillo', 'General Use Zone', 'Golfito', 'Gran Humedal del Norte de Ciego de Ã\x81vila', 'Grand Isle', 'Great White Heron', 'Greynolds', 'Guadeloupe', "Guadeloupe [aire d'adhÃ©sion]", 'Guana River Marsh', 'Guana Tolomato Matanzas', 'Guarapiche', 'Gulf Islands', 'Healthshire', 'Honeymoon Island', 'Hugh Taylor Birch', 'Humedal Los ComondÃº', 'Humedal de Importancia para la ConservaciÃ³n de Aves AcuÃ¡ticas Reserva RÃ\xado Lagartos', 'Humedales Mogote - Ensenada de La Paz', 'Humedales de Yavaros - Moroncarit', 'Humedales de la Laguna la Cruz', 'Humedales del norte de Ciego de Avila', 'Imataca', 'Indian River - Malabar to Vero Beach', 'Isla Contoy', 'Isla Juan Venado', 'Isla MartÃ\xadn PÃ©rez', 'Isla San lucas', 'Isla de Salamanca', 'Islands and Protected Areas of the Gulf of California', 'Islas MarÃ\xadas', 'Islas del Golfo de California', 'Islas del PacÃ\xadfico de la PenÃ\xadnsula de Baja California', 'Isles Dernieres Barrier Islands', 'J.N. Ding Darling', 'Jeff Lewis', 'Jobos Bay', 'John Pennekamp Coral Reef', 'La Encrucijada', 'La Mancha y El Llano', 'La Tovara', 'La porciÃ³n norte y la franja costera oriental, terrestres y marinas de la Isla de Cozumel', 'Laguna Atascosa', 'Laguna Huizache Caimanero', 'Laguna Madre', 'Laguna Madre y Delta del RÃ\xado Bravo', 'Laguna Playa Colorada-Santa Marea La Reforma', 'Laguna de TÃ©rminos', 'Lagunas Costeras y Serranias AledaÃ±as de la Costa de Michoacan', 'Lagunas de Chacahua', 'Lagunas de Santa MarÃ\xada-Topolobampo-Ohuira', 'Las Dunas de las Calderas', 'Leon Levy Native Plant Preserve', 'Lignumvitae Key', 'Limestone Creek', 'Litoral Central', 'Long Key', 'Los Corales del Rosario y San Bernardo', 'Los Delgaditos', 'Los Flamencos', 'Los Petenes', 'Los Tuxtlas', 'Lovers Key', 'Lower Rio Grande Va ...
# Axinaea costaricensis
# Altitud mínima: 216.00
# Altitud máxima: 3230.00
# Área de extensión de presencia (EOO): 502241.54 km2
# Área de ocupación (AOO): 224.00 km2
# Países con registros de presencia: ['CO', 'CR', 'PA', 'VE']
# Áreas protegidas con registros de presencia: ['Braulio Carrillo', 'Cerro de Escazu', 'Chirripo', 'Cordillera Volcanica Central', 'Guaramacal', 'Internacional La Amistad', 'Juan Castro Blanco', 'La Amistad', 'Los Quetzales', 'Los Santos', 'Reserva de la BiÃ³sfera de La Amistad', 'Rio Toro', 'Sisavita', 'Sureste del Lago de Maracaibo Sto. Domingo-MotatÃ¡n', 'Talamanca Range-La Amistad Reserves / La Amistad National Park', 'Tapanti-Macizo de la Muerte', 'Volcan BarÃº', 'Volcan Poas']
