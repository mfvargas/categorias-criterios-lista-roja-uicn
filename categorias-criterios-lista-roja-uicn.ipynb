# %% [markdown]
# # Categorías y criterios de la Lista Roja de la UICN

# %% [markdown]
# Este [Jupyter Notebook](https://jupyter.org/), desarrollado en el lenguaje de programación [Python](https://www.python.org/), aplica las categorías y criterios de la [Lista Roja de la Unión Internacional para la Conservación de la Naturaleza (UICN)](https://www.iucnredlist.org/es/).

# %% [markdown]
# **Entradas**
# - Un archivo CSV con nombres científicos de especies.
#
# **Procesamiento**
# - Se obtienen las llaves (*keys*) de las especies en el [API de GBIF](https://www.gbif.org/developer/summary).
# - En caso de ser necesario, se filtran las llaves (ej. se conservan solo las de nombres que tengan coincidencia exacta o solo las de nombres aceptados).
# - Con base en la lista de llaves, se construye una consulta para el [portal de GBIF](https://www.gbif.org/).
# - El resultado de la consulta al portal se descarga y se renombra como "occurrences.csv".
# - Se recorre el archivo "occurrences.csv" para generar las salidas que se describen seguidamente.
#
# **Salidas**
#
# Para cada especie en el archivo de entrada, se genera:
# - Un registro en un archivo CSV con las siguientes columnas:
#   - Extensión de presencia (EOO).
#   - Área de ocupación (AOO).
#   - Lista de países con registros de presencia.
# - Un mapa de registros de presencia.
# - Un mapa de registros de presencia agrupados (en *clusters*).
# - Un mapa de calor.

# %% [markdown]
# **Bibliotecas de Python**

# %%
import requests
import json
import io

import csv

import pandas as pd
import geopandas as gpd
import numpy as np
from scipy.spatial import ConvexHull

import folium
from folium import plugins

import fiona
from shapely.geometry import shape, Point

from pyproj import Proj, transform

import matplotlib.pyplot as plt
# %matplotlib inline

import calendar

# El siguiente archivo debe estar en el mismo directorio que este notebook
from functions_query_from_species_list import *

# %% [markdown]
# **Constantes**

# %%
# Credenciales para el API de GBIF
GBIF_USER_NAME = "mvargas"
GBIF_PASSWORD = "grizabella"
GBIF_NOTIFICATION_ADDRESSES = "mvargas@inbio.ac.cr"
GBIF_DOWNLOAD_FORMAT = "SIMPLE_CSV"

# Proyecciones cartográficas para los cálculos de EOO y AOO
INPUT_PROJECTION = Proj(init='epsg:4326')
OUTPUT_PROJECTION = Proj(init='epsg:3857')

# Límites y dimensiones de la cuadrícula para el cálculo del AOO.
# Deben especificarse en las unidades del sistema espacial de referencia (SRS) que se utiliza.
# Por ejemplo, para el caso de Web Mercator (EPSG:3857), deben especificarse en metros.
# Límites de la cuadrícula
AOO_GRID_X_MIN = -15000000
AOO_GRID_X_MAX = -4000000
AOO_GRID_Y_MIN = -7000000
AOO_GRID_Y_MAX = 7000000
# Dimensiones de la cuadrícula
AOO_GRID_CELL_X_WIDTH = 2000
AOO_GRID_CELL_Y_WIDTH = 2000
AOO_GRID_CELL_AREA = AOO_GRID_CELL_X_WIDTH * AOO_GRID_CELL_Y_WIDTH

# Directorio de entrada
INPUT_DIR = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/"

# Archivo CSV de entrada con lista de especies a procesar
INPUT_CHECKLIST = INPUT_DIR + "Abarema_racemiflora-Axinaea_costaricensis-lista-especies.csv"
# Columna con el nombre científico de la especie
INPUT_SCINAME_COL = "Taxon Name"

# Archivo CSV con registros de presencia
OCCURRENCES_CSV = INPUT_DIR + "Abarema_racemiflora-Axinaea_costaricensis-registros-presencia.csv"

# Archivo CSV con especies del archivo de entrada que no se procesan
INPUT_CHECKLIST_NON_PROCESSED = INPUT_DIR + "Abarema_racemiflora-Axinaea_costaricensis-lista-especies-no-procesadas.csv"

# Directorio de salida
OUTPUT_DIR = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abarema_racemiflora-Axinaea_costaricensis/"
# Archivo CSV de salida
OUTPUT_CSV = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abarema_racemiflora-Axinaea_costaricensis-evaluacion.csv"
# Archivo HTML de salida
OUTPUT_HTML = "C:/Users/mfvargas/evaluacion-arboles-mesoamerica/Abarema_racemiflora-Axinaea_costaricensis-evaluacion.html"
# URL de salida
OUTPUT_BASE_URL = "https://evaluacion-arboles-mesoamerica.github.io/Abarema_racemiflora-Axinaea_costaricensis/"

# Capa geoespacial de áreas protegidas
PROTECTED_AREAS_LAYER = "C:/Users/mfvargas/geodatos/wdpa/WDPA_Mesoamerica.shp"

# Número máximo de registros a desplegar en los dataframes de Pandas
pd.options.display.max_rows = 70

# %% [markdown]
# ## Carga de datos

# %%
# Carga del archivo CSV de entrada en un dataframe de Pandas
input_species_df = pd.read_csv(INPUT_CHECKLIST, encoding='utf_8')

input_species_df
# Out:
#              Family           Genus          Species  \
# 0          FABACEAE         Abarema      racemiflora
# 1         MALVACEAE        Abutilon         purpusii
# 2     EUPHORBIACEAE        Acalypha       ferdinandi
# 3         LAMIACEAE       Aegiphila       panamensis
# 4        OPILIACEAE       Agonandra       macrocarpa
# 5         LAURACEAE          Aiouea         brenesii
# 6         LAURACEAE          Aiouea     chavarrianum
# 7         LAURACEAE          Aiouea      neurophylla
# 8         LAURACEAE          Aiouea          obscura
# 9         LAURACEAE          Aiouea         pittieri
# 10        LAURACEAE          Aiouea         tonduzii
# 11        ARECACEAE        Aiphanes          hirsuta
# 12         FABACEAE         Albizia         duckeana
# 13     JUGLANDACEAE         Alfaroa        manningii
# 14        RUBIACEAE       Alibertia        utleyorum
# 15        RUBIACEAE          Alseis    costaricensis
# 16        RUBIACEAE         Amaioua      pedicellata
# 17    ANACARDIACEAE  Amphipterygium            molle
# 18     BIGNONIACEAE      Amphitecna          gentryi
# 19     BIGNONIACEAE      Amphitecna           haberi
# 20     BIGNONIACEAE      Amphitecna         isthmica
# 21         RUTACEAE          Amyris         brenesii
# 22         RUTACEAE          Amyris       magnifolia
# 23       ANNONACEAE      Anaxagorea       phaeocarpa
# 24        LAURACEAE           Aniba      venezuelana
# 25       ANNONACEAE          Annona       danforthii
# 26    CARYOCARACEAE     Anthodiscus       chocoensis
# 27        RUBIACEAE    Arachnothryx           aspera
# 28        RUBIACEAE    Arachnothryx         brenesii
# 29        RUBIACEAE    Arachnothryx         calycosa
# 30        RUBIACEAE    Arachnothryx         chaconii
# 31        RUBIACEAE    Arachnothryx    costaricensis
# 32        RUBIACEAE    Arachnothryx   monteverdensis
# 33        RUBIACEAE    Arachnothryx          povedae
# 34        RUBIACEAE    Arachnothryx        tayloriae
# 35      MYRSINACEAE         Ardisia        alajuelae
# 36      MYRSINACEAE         Ardisia    angucianensis
# 37      MYRSINACEAE         Ardisia      blepharodes
# 38      MYRSINACEAE         Ardisia         brenesii
# 39      MYRSINACEAE         Ardisia      capitellata
# 40      MYRSINACEAE         Ardisia       cartagoana
# 41      MYRSINACEAE         Ardisia      crassiramea
# 42      MYRSINACEAE         Ardisia           dodgei
# 43      MYRSINACEAE         Ardisia       dunlapiana
# 44      MYRSINACEAE         Ardisia       furfuracea
# 45      MYRSINACEAE         Ardisia     furfuracella
# 46      MYRSINACEAE         Ardisia     generalensis
# 47      MYRSINACEAE         Ardisia         liesneri
# 48      MYRSINACEAE         Ardisia          maxonii
# 49      MYRSINACEAE         Ardisia            opaca
# 50      MYRSINACEAE         Ardisia          palmana
# 51      MYRSINACEAE         Ardisia     pleurobotrya
# 52      MYRSINACEAE         Ardisia      standleyana
# 53      MYRSINACEAE         Ardisia          storkii
# 54      MYRSINACEAE         Ardisia         tarariae
# 55      MYRSINACEAE         Ardisia   tortuguerensis
# 56      MYRSINACEAE         Ardisia          wedelii
# 57        ARECACEAE     Astrocaryum           alatum
# 58        ARECACEAE     Astrocaryum        confertum
# 59        ARECACEAE     Astrocaryum     standleyanum
# 60   PHYLLANTHACEAE      Astrocasia          peltata
# 61         FABACEAE         Ateleia  herbert-smithii
# 62         FABACEAE         Ateleia       pterocarpa
# 63    AVICENNIACEAE       Avicennia          bicolor
# 64    AVICENNIACEAE       Avicennia        germinans
# 65  MELASTOMATACEAE         Axinaea    costaricensis
#
#                      Taxon Name Category Criteria IUCN Assessment completed  \
# 0           Abarema racemiflora       LC      NaN                       NaN
# 1             Abutilon purpusii      NaN      NaN                       NaN
# 2           Acalypha ferdinandi      NaN      NaN                       NaN
# 3          Aegiphila panamensis      NaN      NaN                       NaN
# 4          Agonandra macrocarpa      NaN      NaN                       NaN
# 5               Aiouea brenesii      NaN      NaN                       NaN
# 6           Aiouea chavarrianum      NaN      NaN                       NaN
# 7            Aiouea neurophylla      NaN      NaN                       NaN
# 8                Aiouea obscura      NaN      NaN                       NaN
# 9               Aiouea pittieri      NaN      NaN                       NaN
# 10              Aiouea tonduzii      NaN      NaN                       NaN
# 11             Aiphanes hirsuta      NaN      NaN                       NaN
# 12             Albizia duckeana      NaN      NaN                       NaN
# 13            Alfaroa manningii      NaN      NaN                       NaN
# 14          Alibertia utleyorum      NaN      NaN                       NaN
# 15         Alseis costaricensis      NaN      NaN                       NaN
# 16          Amaioua pedicellata      NaN      NaN                       NaN
# 17         Amphipterygium molle        x      NaN                       NaN
# 18           Amphitecna gentryi      NaN      NaN                       NaN
# 19            Amphitecna haberi      NaN      NaN                       NaN
# 20          Amphitecna isthmica      NaN      NaN                       NaN
# 21              Amyris brenesii      NaN      NaN                       NaN
# 22            Amyris magnifolia      NaN      NaN                       NaN
# 23        Anaxagorea phaeocarpa       LC      NaN                       NaN
# 24            Aniba venezuelana       LC      NaN                       NaN
# 25            Annona danforthii       LC      NaN                       NaN
# 26       Anthodiscus chocoensis      NaN      NaN                       NaN
# 27          Arachnothryx aspera      NaN      NaN                       NaN
# 28        Arachnothryx brenesii      NaN      NaN                       NaN
# 29        Arachnothryx calycosa      NaN      NaN                       NaN
# 30        Arachnothryx chaconii      NaN      NaN                       NaN
# 31   Arachnothryx costaricensis      NaN      NaN                       NaN
# 32  Arachnothryx monteverdensis      NaN      NaN                       NaN
# 33         Arachnothryx povedae      NaN      NaN                       NaN
# 34       Arachnothryx tayloriae      NaN      NaN                       NaN
# 35            Ardisia alajuelae      NaN      NaN                       NaN
# 36        Ardisia angucianensis      NaN      NaN                       NaN
# 37          Ardisia blepharodes      NaN      NaN                       NaN
# 38             Ardisia brenesii      NaN      NaN                       NaN
# 39          Ardisia capitellata      NaN      NaN      Kew to compile draft
# 40           Ardisia cartagoana      NaN      NaN                       NaN
# 41          Ardisia crassiramea      NaN      NaN                       NaN
# 42               Ardisia dodgei      NaN      NaN                       NaN
# 43           Ardisia dunlapiana      NaN      NaN                       NaN
# 44           Ardisia furfuracea      NaN      NaN                       NaN
# 45         Ardisia furfuracella      NaN      NaN                       NaN
# 46         Ardisia generalensis      NaN      NaN                       NaN
# 47             Ardisia liesneri      NaN      NaN                       NaN
# 48              Ardisia maxonii      NaN      NaN                       NaN
# 49                Ardisia opaca      NaN      NaN                       NaN
# 50              Ardisia palmana      NaN      NaN                       NaN
# 51         Ardisia pleurobotrya      NaN      NaN                       NaN
# 52          Ardisia standleyana      NaN      NaN                       NaN
# 53              Ardisia storkii      NaN      NaN                       NaN
# 54             Ardisia tarariae      NaN      NaN                       NaN
# 55       Ardisia tortuguerensis      NaN      NaN                       NaN
# 56              Ardisia wedelii      NaN      NaN                       NaN
# 57           Astrocaryum alatum      NaN      NaN                       NaN
# 58        Astrocaryum confertum      NaN      NaN                       NaN
# 59     Astrocaryum standleyanum      NaN      NaN                       NaN
# 60           Astrocasia peltata      NaN      NaN                       NaN
# 61      Ateleia herbert-smithii      NaN      NaN                       NaN
# 62           Ateleia pterocarpa       LC      NaN                       NaN
# 63            Avicennia bicolor       VU     A2cd                       NaN
# 64          Avicennia germinans       LC      NaN                       NaN
# 65        Axinaea costaricensis      NaN      NaN      Kew to compile draft
#
#                                                 Notes Endemic?  \
# 0                   To send to David Neill for review       no
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3                                     1998 assessment      NaN
# 4                                     1998 assessment      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8                                     1998 assessment      NaN
# 9                                                 NaN      NaN
# 10                                                NaN      NaN
# 11                                    1998 assessment      NaN
# 12                                                NaN      NaN
# 13                                    1998 assessment      NaN
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16                                                NaN      NaN
# 17  Taxonomic Issue - not found in Costa Rica. Rem...      NaN
# 18                                                NaN      NaN
# 19                                                NaN      NaN
# 20                                    1998 assessment      NaN
# 21                                                NaN      NaN
# 22                                                NaN      NaN
# 23                                    1998 assessment      NaN
# 24                                    1998 assessment      NaN
# 25                      1998 assessment not published      NaN
# 26                                    1998 assessment      NaN
# 27                                                NaN      NaN
# 28                                                NaN      NaN
# 29                                                NaN      NaN
# 30                                                NaN      NaN
# 31                                                NaN      NaN
# 32                                                NaN      NaN
# 33                                                NaN      NaN
# 34                                                NaN      NaN
# 35                                                NaN      NaN
# 36                                                NaN      NaN
# 37                                                NaN      NaN
# 38                                                NaN      NaN
# 39                                                NaN      NaN
# 40                                                NaN      NaN
# 41                                                NaN      NaN
# 42                                                NaN      NaN
# 43                                                NaN      NaN
# 44                                                NaN      NaN
# 45                                    1998 assessment      NaN
# 46                                                NaN      NaN
# 47                                                NaN      NaN
# 48                                    1998 assessment      NaN
# 49                                    1998 assessment      NaN
# 50                                                NaN      NaN
# 51                                                NaN      NaN
# 52                                    1998 assessment      NaN
# 53                                                NaN      NaN
# 54                                                NaN      NaN
# 55                                                NaN      NaN
# 56                                                NaN      NaN
# 57                                    1998 assessment      NaN
# 58                                                NaN      NaN
# 59                                                NaN      NaN
# 60                                                NaN      NaN
# 61                                                NaN      NaN
# 62                                                NaN      NaN
# 63                                    2008 assessment      NaN
# 64                                    2007 assessment      NaN
# 65                                                NaN      NaN
#
#    Information inputted into SIS  Assessment reviewed Map completed  \
# 0                            yes                  NaN           yes
# 1                            NaN                  NaN           NaN
# 2                            NaN                  NaN           NaN
# 3                            NaN                  NaN           NaN
# 4                            NaN                  NaN           NaN
# 5                            NaN                  NaN           NaN
# 6                            NaN                  NaN           NaN
# 7                            NaN                  NaN           NaN
# 8                            NaN                  NaN           NaN
# 9                            NaN                  NaN           NaN
# 10                           NaN                  NaN           NaN
# 11                           NaN                  NaN           NaN
# 12                           NaN                  NaN           NaN
# 13                           NaN                  NaN           NaN
# 14                           NaN                  NaN           NaN
# 15                           NaN                  NaN           NaN
# 16                           NaN                  NaN           NaN
# 17                           NaN                  NaN           NaN
# 18                           NaN                  NaN           NaN
# 19                           NaN                  NaN           NaN
# 20                           NaN                  NaN           NaN
# 21                           NaN                  NaN           NaN
# 22                           NaN                  NaN           NaN
# 23                           NaN                  NaN           NaN
# 24                           NaN                  NaN           NaN
# 25                           NaN                  NaN           NaN
# 26                           NaN                  NaN           NaN
# 27                           NaN                  NaN           NaN
# 28                           NaN                  NaN           NaN
# 29                           NaN                  NaN           NaN
# 30                           NaN                  NaN           NaN
# 31                           NaN                  NaN           NaN
# 32                           NaN                  NaN           NaN
# 33                           NaN                  NaN           NaN
# 34                           NaN                  NaN           NaN
# 35                           NaN                  NaN           NaN
# 36                           NaN                  NaN           NaN
# 37                           NaN                  NaN           NaN
# 38                           NaN                  NaN           NaN
# 39                           NaN                  NaN           NaN
# 40                           NaN                  NaN           NaN
# 41                           NaN                  NaN           NaN
# 42                           NaN                  NaN           NaN
# 43                           NaN                  NaN           NaN
# 44                           NaN                  NaN           NaN
# 45                           NaN                  NaN           NaN
# 46                           NaN                  NaN           NaN
# 47                           NaN                  NaN           NaN
# 48                           NaN                  NaN           NaN
# 49                           NaN                  NaN           NaN
# 50                           NaN                  NaN           NaN
# 51                           NaN                  NaN           NaN
# 52                           NaN                  NaN           NaN
# 53                           NaN                  NaN           NaN
# 54                           NaN                  NaN           NaN
# 55                           NaN                  NaN           NaN
# 56                           NaN                  NaN           NaN
# 57                           NaN                  NaN           NaN
# 58                           NaN                  NaN           NaN
# 59                           NaN                  NaN           NaN
# 60                           NaN                  NaN           NaN
# 61                           NaN                  NaN           NaN
# 62                           NaN                  NaN           NaN
# 63                           NaN                  NaN           NaN
# 64                           NaN                  NaN           NaN
# 65                           NaN                  NaN           NaN
#
#     Submitted to IUCN
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49                NaN
# 50                NaN
# 51                NaN
# 52                NaN
# 53                NaN
# 54                NaN
# 55                NaN
# 56                NaN
# 57                NaN
# 58                NaN
# 59                NaN
# 60                NaN
# 61                NaN
# 62                NaN
# 63                NaN
# 64                NaN
# 65                NaN

# %% [markdown]
# Se consulta el API de GBIF para obtener las llaves (*keys*) de las especies

# %%
# Se obtienen las llaves de las especies a través del API de GBIF
gbif_species_df = match_species(input_species_df, INPUT_SCINAME_COL)

gbif_species_df[['inputName', 'species', 'genus', 'family', 'matchType', 'status', 'synonym', 'speciesKey', 'usageKey', 'rank', 'alternatives']]
# Out:
#                       inputName                      species           genus  \
# 0           Abarema racemiflora          Abarema racemiflora         Abarema
# 1             Abutilon purpusii          Callianthe purpusii      Callianthe
# 2           Acalypha ferdinandi          Acalypha ferdinandi        Acalypha
# 3          Aegiphila panamensis         Aegiphila panamensis       Aegiphila
# 4          Agonandra macrocarpa         Agonandra macrocarpa       Agonandra
# 5               Aiouea brenesii              Aiouea brenesii          Aiouea
# 6           Aiouea chavarrianum           Aiouea chavarriana          Aiouea
# 7            Aiouea neurophylla           Aiouea neurophylla          Aiouea
# 8                Aiouea obscura               Aiouea obscura          Aiouea
# 9               Aiouea pittieri              Aiouea pittieri          Aiouea
# 10              Aiouea tonduzii              Aiouea tonduzii          Aiouea
# 11             Aiphanes hirsuta             Aiphanes hirsuta        Aiphanes
# 12             Albizia duckeana             Albizia duckeana         Albizia
# 13            Alfaroa manningii            Alfaroa manningii         Alfaroa
# 14          Alibertia utleyorum          Alibertia utleyorum       Alibertia
# 15         Alseis costaricensis         Alseis costaricensis          Alseis
# 16          Amaioua pedicellata          Amaioua pedicellata         Amaioua
# 17         Amphipterygium molle         Amphipterygium molle  Amphipterygium
# 18           Amphitecna gentryi           Amphitecna gentryi      Amphitecna
# 19            Amphitecna haberi            Amphitecna haberi      Amphitecna
# 20          Amphitecna isthmica          Amphitecna isthmica      Amphitecna
# 21              Amyris brenesii              Amyris brenesii          Amyris
# 22            Amyris magnifolia            Amyris magnifolia          Amyris
# 23        Anaxagorea phaeocarpa        Anaxagorea phaeocarpa      Anaxagorea
# 24            Aniba venezuelana            Aniba venezuelana           Aniba
# 25            Annona danforthii            Annona danforthii          Annona
# 26       Anthodiscus chocoensis       Anthodiscus chocoensis     Anthodiscus
# 27          Arachnothryx aspera          Arachnothryx aspera    Arachnothryx
# 28        Arachnothryx brenesii        Arachnothryx brenesii    Arachnothryx
# 29        Arachnothryx calycosa        Arachnothryx calycosa    Arachnothryx
# 30        Arachnothryx chaconii        Arachnothryx chaconii    Arachnothryx
# 31   Arachnothryx costaricensis   Arachnothryx costaricensis    Arachnothryx
# 32  Arachnothryx monteverdensis  Arachnothryx monteverdensis    Arachnothryx
# 33         Arachnothryx povedae         Arachnothryx povedae    Arachnothryx
# 34       Arachnothryx tayloriae       Arachnothryx tayloriae    Arachnothryx
# 35            Ardisia alajuelae            Ardisia alajuelae         Ardisia
# 36        Ardisia angucianensis        Ardisia angucianensis         Ardisia
# 37          Ardisia blepharodes          Ardisia blepharodes         Ardisia
# 38             Ardisia brenesii             Ardisia brenesii         Ardisia
# 39          Ardisia capitellata          Ardisia capitellata         Ardisia
# 40           Ardisia cartagoana           Ardisia cartagoana         Ardisia
# 41          Ardisia crassiramea          Ardisia crassiramea         Ardisia
# 42               Ardisia dodgei               Ardisia dodgei         Ardisia
# 43           Ardisia dunlapiana           Ardisia dunlapiana         Ardisia
# 44           Ardisia furfuracea           Ardisia furfuracea         Ardisia
# 45         Ardisia furfuracella         Ardisia furfuracella         Ardisia
# 46         Ardisia generalensis         Ardisia generalensis         Ardisia
# 47             Ardisia liesneri             Ardisia liesneri         Ardisia
# 48              Ardisia maxonii              Ardisia maxonii         Ardisia
# 49                Ardisia opaca                Ardisia opaca         Ardisia
# 50              Ardisia palmana              Ardisia palmana         Ardisia
# 51         Ardisia pleurobotrya         Ardisia pleurobotrya         Ardisia
# 52          Ardisia standleyana             Ardisia copeyana         Ardisia
# 53              Ardisia storkii              Ardisia storkii         Ardisia
# 54             Ardisia tarariae             Ardisia tarariae         Ardisia
# 55       Ardisia tortuguerensis       Ardisia tortuguerensis         Ardisia
# 56              Ardisia wedelii              Ardisia wedelii         Ardisia
# 57           Astrocaryum alatum           Astrocaryum alatum     Astrocaryum
# 58        Astrocaryum confertum        Astrocaryum confertum     Astrocaryum
# 59     Astrocaryum standleyanum     Astrocaryum standleyanum     Astrocaryum
# 60           Astrocasia peltata           Astrocasia peltata      Astrocasia
# 61      Ateleia herbert-smithii      Ateleia herbert-smithii         Ateleia
# 62           Ateleia pterocarpa           Ateleia pterocarpa         Ateleia
# 63            Avicennia bicolor            Avicennia bicolor       Avicennia
# 64          Avicennia germinans          Avicennia germinans       Avicennia
# 65        Axinaea costaricensis        Axinaea costaricensis         Axinaea
#
#              family matchType    status  synonym  speciesKey  usageKey  \
# 0          Fabaceae     EXACT  ACCEPTED    False     2977909   2977909
# 1         Malvaceae     EXACT   SYNONYM     True     8418086   3936341
# 2     Euphorbiaceae     EXACT  ACCEPTED    False     7276169   7276169
# 3         Lamiaceae     EXACT  ACCEPTED    False     3891222   3891222
# 4        Opiliaceae     EXACT  ACCEPTED    False     3658839   3658839
# 5         Lauraceae     EXACT  ACCEPTED    False     9665460   9665460
# 6         Lauraceae     FUZZY  ACCEPTED    False     9695833   9695833
# 7         Lauraceae     EXACT  ACCEPTED    False     9810051   9810051
# 8         Lauraceae     EXACT  ACCEPTED    False     4183412   4183412
# 9         Lauraceae     EXACT  ACCEPTED    False     9700381   9700381
# 10        Lauraceae     EXACT  ACCEPTED    False     9744148   9744148
# 11        Arecaceae     EXACT  ACCEPTED    False     2738670   2738670
# 12         Fabaceae     EXACT  ACCEPTED    False     3796445   3796445
# 13     Juglandaceae     EXACT  ACCEPTED    False     4205554   4205554
# 14        Rubiaceae     EXACT  ACCEPTED    False     5335637   5335637
# 15        Rubiaceae     EXACT  ACCEPTED    False     5334877   5334877
# 16        Rubiaceae     EXACT  ACCEPTED    False     2901143   2901143
# 17    Anacardiaceae     EXACT  ACCEPTED    False     7881320   7881320
# 18     Bignoniaceae     EXACT  ACCEPTED    False     4094049   4094049
# 19     Bignoniaceae     EXACT  DOUBTFUL    False     7597158   7597158
# 20     Bignoniaceae     EXACT  ACCEPTED    False     4094040   4094040
# 21         Rutaceae     EXACT  ACCEPTED    False     5593053   5593053
# 22         Rutaceae     EXACT  ACCEPTED    False     5594889   5594889
# 23       Annonaceae     EXACT  ACCEPTED    False     3156862   3156862
# 24        Lauraceae     EXACT  ACCEPTED    False     4180153   4180153
# 25       Annonaceae     EXACT  ACCEPTED    False     5541648   5541648
# 26    Caryocaraceae     EXACT  ACCEPTED    False     5592412   5592412
# 27        Rubiaceae     EXACT  ACCEPTED    False     2897338   2897338
# 28        Rubiaceae     EXACT  ACCEPTED    False     2897216   2897216
# 29        Rubiaceae     EXACT  ACCEPTED    False     2897443   2897443
# 30        Rubiaceae     EXACT  ACCEPTED    False     2897213   2897213
# 31        Rubiaceae     EXACT  ACCEPTED    False     2897678   2897678
# 32        Rubiaceae     EXACT  ACCEPTED    False     2897223   2897223
# 33        Rubiaceae     EXACT  ACCEPTED    False     2897261   2897261
# 34        Rubiaceae     EXACT  ACCEPTED    False     2897503   2897503
# 35      Primulaceae     EXACT  ACCEPTED    False     5558134   5558134
# 36      Primulaceae     EXACT  ACCEPTED    False     5558011   5558011
# 37      Primulaceae     EXACT  ACCEPTED    False     5557693   5557693
# 38      Primulaceae     EXACT  ACCEPTED    False     5557608   5557608
# 39      Primulaceae     EXACT  ACCEPTED    False     5557440   5557440
# 40      Primulaceae     EXACT  ACCEPTED    False     5557397   5557397
# 41      Primulaceae     EXACT  ACCEPTED    False     5558831   5558831
# 42      Primulaceae     EXACT  ACCEPTED    False     5558457   5558457
# 43      Primulaceae     EXACT  ACCEPTED    False     5558632   5558632
# 44      Primulaceae     EXACT  ACCEPTED    False     5558476   5558476
# 45      Primulaceae     EXACT  ACCEPTED    False     7331075   7331075
# 46      Primulaceae     EXACT  ACCEPTED    False     5558442   5558442
# 47      Primulaceae     EXACT  ACCEPTED    False     5557750   5557750
# 48      Primulaceae     EXACT  ACCEPTED    False     5557482   5557482
# 49      Primulaceae     EXACT  ACCEPTED    False     5558709   5558709
# 50      Primulaceae     EXACT  ACCEPTED    False     5558656   5558656
# 51      Primulaceae     EXACT  ACCEPTED    False     7331093   7331093
# 52      Primulaceae     EXACT   SYNONYM     True     5558881   5557690
# 53      Primulaceae     EXACT  ACCEPTED    False     5557619   5557619
# 54      Primulaceae     EXACT  ACCEPTED    False     5557514   5557514
# 55      Primulaceae     EXACT  ACCEPTED    False     5557395   5557395
# 56      Primulaceae     EXACT  ACCEPTED    False     5558834   5558834
# 57        Arecaceae     EXACT  ACCEPTED    False     2738123   2738123
# 58        Arecaceae     EXACT  ACCEPTED    False     2738088   2738088
# 59        Arecaceae     EXACT  ACCEPTED    False     2738130   2738130
# 60   Phyllanthaceae     EXACT  ACCEPTED    False     3076391   3076391
# 61         Fabaceae     EXACT  ACCEPTED    False     5361723   5361723
# 62         Fabaceae     EXACT  ACCEPTED    False     5361724   5361724
# 63      Acanthaceae     EXACT  ACCEPTED    False     4196610   4196610
# 64      Acanthaceae     EXACT  ACCEPTED    False     2925400   2925400
# 65  Melastomataceae     EXACT  ACCEPTED    False     5601145   5601145
#
#        rank                                       alternatives
# 0   SPECIES                                               NULL
# 1   SPECIES                                               NULL
# 2   SPECIES                                               NULL
# 3   SPECIES  [{'usageKey': 3891182, 'scientificName': 'Aegi...
# 4   SPECIES  [{'usageKey': 7924587, 'scientificName': 'Adin...
# 5   SPECIES                                               NULL
# 6   SPECIES                                               NULL
# 7   SPECIES                                               NULL
# 8   SPECIES  [{'usageKey': 2358012, 'acceptedUsageKey': 520...
# 9   SPECIES                                               NULL
# 10  SPECIES                                               NULL
# 11  SPECIES                                               NULL
# 12  SPECIES                                               NULL
# 13  SPECIES                                               NULL
# 14  SPECIES  [{'usageKey': 8309742, 'scientificName': 'Alib...
# 15  SPECIES                                               NULL
# 16  SPECIES                                               NULL
# 17  SPECIES  [{'usageKey': 3661179, 'acceptedUsageKey': 788...
# 18  SPECIES                                               NULL
# 19  SPECIES                                               NULL
# 20  SPECIES                                               NULL
# 21  SPECIES                                               NULL
# 22  SPECIES                                               NULL
# 23  SPECIES                                               NULL
# 24  SPECIES  [{'usageKey': 1907180, 'scientificName': 'Anae...
# 25  SPECIES                                               NULL
# 26  SPECIES                                               NULL
# 27  SPECIES                                               NULL
# 28  SPECIES                                               NULL
# 29  SPECIES                                               NULL
# 30  SPECIES  [{'usageKey': 3848195, 'scientificName': 'Arac...
# 31  SPECIES                                               NULL
# 32  SPECIES                                               NULL
# 33  SPECIES                                               NULL
# 34  SPECIES                                               NULL
# 35  SPECIES  [{'usageKey': 7448928, 'acceptedUsageKey': 555...
# 36  SPECIES                                               NULL
# 37  SPECIES                                               NULL
# 38  SPECIES  [{'usageKey': 5557801, 'scientificName': 'Ardi...
# 39  SPECIES  [{'usageKey': 5557447, 'acceptedUsageKey': 372...
# 40  SPECIES                                               NULL
# 41  SPECIES                                               NULL
# 42  SPECIES                                               NULL
# 43  SPECIES                                               NULL
# 44  SPECIES  [{'usageKey': 7331075, 'scientificName': 'Ardi...
# 45  SPECIES  [{'usageKey': 5558476, 'scientificName': 'Ardi...
# 46  SPECIES                                               NULL
# 47  SPECIES  [{'usageKey': 8462966, 'acceptedUsageKey': 372...
# 48  SPECIES  [{'usageKey': 7330849, 'scientificName': 'Ardi...
# 49  SPECIES  [{'usageKey': 5558679, 'acceptedUsageKey': 733...
# 50  SPECIES                                               NULL
# 51  SPECIES                                               NULL
# 52  SPECIES                                               NULL
# 53  SPECIES  [{'usageKey': 5557623, 'acceptedUsageKey': 555...
# 54  SPECIES                                               NULL
# 55  SPECIES                                               NULL
# 56  SPECIES                                               NULL
# 57  SPECIES  [{'usageKey': 2738096, 'scientificName': 'Astr...
# 58  SPECIES  [{'usageKey': 8490339, 'acceptedUsageKey': 273...
# 59  SPECIES                                               NULL
# 60  SPECIES                                               NULL
# 61  SPECIES                                               NULL
# 62  SPECIES  [{'usageKey': 7388007, 'acceptedUsageKey': 536...
# 63  SPECIES                                               NULL
# 64  SPECIES  [{'usageKey': 7782491, 'acceptedUsageKey': 292...
# 65  SPECIES  [{'usageKey': 5601148, 'scientificName': 'Axin...

# %%
# Nombres excluídos por no ser aceptados o con coincidencia no exacta
gbif_species_df = gbif_species_df[['inputName', 'species', 'genus', 'family', 'matchType', 'status', 'synonym', 'speciesKey', 'usageKey', 'rank', 'alternatives']]
gbif_species_non_processed_df = gbif_species_df.loc[~((gbif_species_df["matchType"]=="EXACT") & (gbif_species_df["status"]=="ACCEPTED"))]

gbif_species_non_processed_df.to_csv(INPUT_CHECKLIST_NON_PROCESSED)

# %%
# Se separa la lista de llaves

# Se filtran las llaves (en caso de ser necesario)
key_list = gbif_species_df.loc[(gbif_species_df["matchType"]=="EXACT") & (gbif_species_df["status"]=="ACCEPTED")].usageKey.tolist()
# key_list = gbif_taxa_df.usageKey.tolist()

key_list

# %% [markdown]
# Se construye una consulta para descarga en el portal de GBIF

# %%
# Se construye una consulta para descarga en el portal de GBIF
download_query = {}
download_query["creator"] = GBIF_USER_NAME
download_query["notificationAddresses"] = [GBIF_NOTIFICATION_ADDRESSES]
download_query["sendNotification"] = True
download_query["format"] = GBIF_DOWNLOAD_FORMAT
download_query["predicate"] =   {"type":"and", "predicates": 
                                 [
                                    {"type":"equals", "key":"HAS_COORDINATE",       "value":"true"},
                                    {"type":"equals", "key":"HAS_GEOSPATIAL_ISSUE", "value":"false"}, 
                                    {"type":"in",     "key": "TAXON_KEY",           "values":key_list}
                                 ]
                                }

download_query

# %%
# Submit query to GBIF API
create_download_given_query(GBIF_USER_NAME, GBIF_PASSWORD, download_query)

# Respuesta esperada:
# ok
# <Response [201]>

# %% [markdown]
# **After downloading the file from the GBIF portal if has to be unzipped and renamed with the name defined in OCCURRENCES_CSV**

# %%
occurrences_df = pd.read_csv(OCCURRENCES_CSV, sep='\t')

occurrences_df

# %%
# Change "eventDate" data type to dateTime
occurrences_df["eventDate"] = pd.to_datetime(occurrences_df["eventDate"])

# %%
# ==================== CREACIÓN DEL DATAFRAME DE ÁREAS PROTEGIDAS ====================
wdpa_gdf = gpd.read_file(PROTECTED_AREAS_LAYER, encoding="latin-1")
wdpa_gdf.index.name = "index_wdpa"


# ==================== CREACIÓN DE LOS ARCHIVOS DE SALIDA ====================

# Archivo CSV
results_csv = open(OUTPUT_CSV, mode='w', newline='', encoding="latin-1")
results_csv_writer = csv.writer(results_csv, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
results_csv_writer.writerow(['Nombre cientifico de entrada', 
                             'Familia (GBIF)', 
                             'Genero (GBIF)', 
                             'Especie (GBIF)', 
                             'EOO (km2)', 
                             'AOO (km2)',
                             'Altitud minima (m)', 
                             'Altitud maxima (m)',
                             'Países', 
                             'Areas protegidas',
                             'Mapa de registros de presencia', 
                             'Mapa agrupado'])

# Archivo HTML
results_html = open(OUTPUT_HTML, mode='w', newline='', encoding="latin-1")
results_html.write("<!DOCTYPE html>")
results_html.write('<html lang="es">')
results_html.write("<head>")
results_html.write("<title>Evaluacion de arboles de Mesoamerica</title>")
results_html.write("<style>table, th, td {border: 1px solid black;}</style>")
results_html.write("</head>")
results_html.write("<body>")
results_html.write("<table>")
results_html.write("<tr><th>Nombre cientifico de entrada</th><th>Familia (GBIF)</th><th>Genero (GBIF)</th><th>Especie (GBIF)</th><th>EOO (km2)</th><th>AOO (km2)</th><th>Altitud minima (m)</th><th>Altitud maxima (m)</th><th>Paises</th><th>Areas protegidas</th><th>Mapa de registros de presencia</th><th>Mapa agrupado</th></tr>")
results_html.write("<tbody>")


# ==================== RECORRIDO DE LA LISTA DE ESPECIES ====================

for index, row in gbif_species_df.iterrows():
    species_input = row["inputName"]
    family_gbif = row["family"]
    genus_gbif = row["genus"]
    species_gbif = row["species"]
    print(species_gbif)

    current_taxon_df = occurrences_df[occurrences_df['species'] == species_gbif]    

    
    # ==================== ESTRUCTURAS PARA EL CÁLCULO DEL EOO Y DEL AOO ====================    

    # Lista de puntos para el cálculo del EOO
    eoo_points = []   
    
    # Lista de valores de (x,y) para el cálculo del AOO
    aoo_x_values = []
    aoo_y_values = []   
    
    
    # ==================== ESTRUCTURAS PARA EL CÁLCULO DE LAS ALTITUDES MÍNIMA Y MÁXIMA ====================    

    altitude_values = []

    
    # ==================== ESTRUCTURAS PARA LA GENERACIÓN DE LA LISTA DE PAÍSES ====================    
    
    # Conjunto de códigos de países en los que hay registros de presencia
    countries = set()
    

    # ==================== ESTRUCTURAS PARA LA GENERACIÓN DE LA LISTA DE ÁREAS PROTEGIDAS ====================    
    
    # Arreglo de códigos de países en los que hay registros de presencia    
    current_taxon_geom = [Point(xy) for xy in zip(current_taxon_df["decimalLongitude"], 
                                                  current_taxon_df["decimalLatitude"])]
    current_taxon_gdf = gpd.GeoDataFrame(current_taxon_df, 
                                         crs={"init": "epsg:4326"}, 
                                         geometry=current_taxon_geom)
    wdpa_ocuppied = gpd.sjoin(wdpa_gdf, current_taxon_gdf, how="inner", op='intersects')
    protected_areas = wdpa_ocuppied.NAME.unique()    
           
        
    # ==================== INICIALIZACIÓN DE MAPAS ====================
    
    # Mapa de registros de presencia
    occurrences_map = folium.Map(location=[9.63, -84], 
                                 tiles='OpenStreetMap', 
                                 attr='OpenStreetMap', 
                                 zoom_start=5, 
                                 control_scale=True)
    folium.TileLayer(tiles='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/MapServer/tile/{z}/{y}/{x}',
                     name='ESRI World Imagery',
                     attr='ESRI World Imagery').add_to(occurrences_map)
    
    # Mapa de registros de presencia agrupados (cluster)
    cluster_map = folium.Map(location=[9.63, -84], 
                             tiles='OpenStreetMap', 
                             attr='OpenStreetMap', 
                             zoom_start=5, 
                             control_scale=True)
    folium.TileLayer(tiles='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer/MapServer/tile/{z}/{y}/{x}',
                     name='ESRI World Imagery',
                     attr='ESRI World Imagery').add_to(cluster_map)    
    occurrences_cluster = plugins.MarkerCluster().add_to(cluster_map)
        
    
    # ==================== RECORRIDO DE LOS REGISTROS DE PRESENCIA ====================
    for lat, lng, alt, country, m, label in zip(current_taxon_df.decimalLatitude,
                               current_taxon_df.decimalLongitude,
                               current_taxon_df.elevation,
                               current_taxon_df.countryCode,
                               current_taxon_df.eventDate.dt.month,
                               "<strong>Localidad:</strong> "       + current_taxon_df.locality.astype(str)   + "\n"    +
                               "<strong>Elevación:</strong> "       + current_taxon_df.elevation.astype(str)  + " m \n" +
                               "<strong>Fecha:</strong> "           + current_taxon_df.eventDate.astype(str)  + "\n"    +
                               "<strong>Recolectores:</strong> "    + current_taxon_df.recordedBy.astype(str) + "\n"    +
                               "<strong>Identificadores:</strong> " + current_taxon_df.identifiedBy.astype(str)):

        # Adición de valores para el cálculo de las altitudes mínima y máxima
        altitude_values.append(alt)
        
        # Adición de puntos para el cálculo del EOO
        x,y = transform(INPUT_PROJECTION, OUTPUT_PROJECTION, lng, lat)
        eoo_point = []
        eoo_point.append(x)
        eoo_point.append(y)
        eoo_points.append(eoo_point)        
        
        # Adición de valores x,y para el cálculo del AOO
        x,y = transform(INPUT_PROJECTION, OUTPUT_PROJECTION, lng, lat)
        aoo_x_values.append(x)
        aoo_y_values.append(y)
        
        # Adición de códigos de países
        countries.add(country)      
        
        # Adición de registros de presencia al mapa de registros de presencia
        folium.CircleMarker(location=[lat, lng], 
                            radius=3, 
                            color='red', 
                            fill=True,
                            popup=label,
                            fill_color='darkred',
                            fill_opacity=0.6).add_to(occurrences_map)
        
        # Adición de registros de presencia agrupados al mapa de registros de presencia agrupados (cluster)
        folium.Marker(
            location=[lat, lng],
            icon=None,
            popup=label,
        ).add_to(occurrences_cluster)
        
    
    # Cálculo de las altitudes mínima y máxima
    altitude_min = min(altitude_values)
    if (np.isnan(altitude_min)):
        altitude_min_str = ""
    else:
        altitude_min_str = "{:.2f}".format(altitude_min)
    altitude_max = max(altitude_values)
    if (np.isnan(altitude_max)):
        altitude_max_str = ""
    else:
        altitude_max_str = "{:.2f}".format(altitude_max)
    
    print("Altitud mínima:", altitude_min_str)
    print("Altitud máxima:", altitude_max_str)
    
    # Cálculo del EOO
    a = np.array(eoo_points)
    hull = ConvexHull(a)
    eoo = hull.volume / 1000000
    print("Área de extensión de presencia (EOO):", "{:.2f}".format(eoo), "km2")
    #plt.plot(a[:,0], a[:,1], 'o')
    #for simplex in hull.simplices:
    #    plt.plot(a[simplex, 0], a[simplex, 1], 'k-')  
    #plt.savefig(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-grafico_eoo.png", bbox_inches='tight')    
  
    # Cálculo del AOO
    x = np.array(aoo_x_values)
    y = np.array(aoo_y_values)
    gridx = np.arange(AOO_GRID_X_MIN, AOO_GRID_X_MAX, AOO_GRID_CELL_X_WIDTH)
    gridy = np.arange(AOO_GRID_Y_MIN, AOO_GRID_Y_MAX, AOO_GRID_CELL_Y_WIDTH)
    grid, _, _ = np.histogram2d(x, y, bins=[gridx, gridy])
    occupied_cells = (grid > 0) 
    aoo = len(grid[occupied_cells]) * (AOO_GRID_CELL_AREA / 1000000)
    print("Área de ocupación (AOO):", "{:.2f}".format(aoo), "km2")
    #plt.figure()
    #plt.plot(x, y, 'ro')
    #plt.grid(True)
    ## plt.show()    
    #plt.savefig(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-grafico_aoo.png", bbox_inches='tight')     
    
    # Lista de países con registros de presencia
    countries = sorted(countries)
    print("Países con registros de presencia:", countries)
    
    # Lista de áreas protegidas con registros de presencia
    protected_areas = sorted(protected_areas)
    print("Áreas protegidas con registros de presencia:", protected_areas)      
        
    # Adición de controles de capas
    folium.LayerControl().add_to(occurrences_map)
    folium.LayerControl().add_to(cluster_map)
   
    
    # Grabado de archivos HTML con los mapas
    occurrences_map.save(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-mapa_registros_presencia.html")
    cluster_map.save(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-mapa_agrupado.html")  
    
    # Adición de línea en el archivo CSV de salida
    results_csv_writer.writerow([species_input, 
                                 family_gbif, 
                                 genus_gbif, 
                                 species_gbif, 
                                 "{:.2f}".format(eoo), 
                                 "{:.2f}".format(aoo),
                                 altitude_min_str, 
                                 altitude_max_str,                                  
                                 ', '.join(countries),
                                 ', '.join(protected_areas),
                                 '=HYPERLINK("'+OUTPUT_BASE_URL + family_gbif.upper() + "_" + species_input.replace(" ", "_") + '-mapa_registros_presencia.html' + '", "' + 'Enlace al mapa")',
                                 '=HYPERLINK("'+OUTPUT_BASE_URL + family_gbif.upper() + "_" + species_input.replace(" ", "_") + '-mapa_agrupado.html'            + '", "' + 'Enlace al mapa")'])
    
    # Adición de línea en el archivo HTML de salida
    results_html.write("<tr>")
    results_html.write("<td>"+ species_input                 +"</td>")
    results_html.write("<td>"+ family_gbif                   +"</td>")
    results_html.write("<td>"+ genus_gbif                    +"</td>")
    results_html.write("<td>"+ species_gbif                  +"</td>")
    results_html.write("<td>"+ "{:.2f}".format(eoo)          +"</td>")
    results_html.write("<td>"+ "{:.2f}".format(aoo)          +"</td>")
    results_html.write("<td>"+ altitude_min_str              +"</td>")
    results_html.write("<td>"+ altitude_max_str              +"</td>")    
    results_html.write("<td>"+ ', '.join(countries)          +"</td>")
    results_html.write("<td>"+ ', '.join(protected_areas)    +"</td>")
    results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL + family_gbif.upper() + '_' + species_input.replace(' ', '_') + '-mapa_registros_presencia.html' +'">Enlace</a>' + "</td>")
    results_html.write("<td>"+ '<a href="' + OUTPUT_BASE_URL + family_gbif.upper() + '_' + species_input.replace(' ', '_') + '-mapa_agrupado.html'            +'">Enlace</a>' + "</td>")
    results_html.write("</tr>")
    
    # Archivo de registros de presencia de la especie en archivo CSV
    current_taxon_df = current_taxon_df[['basisOfRecord', 'species', 'catalogNumber', 'recordNumber', 'decimalLatitude', 'decimalLongitude', 'locality', 'year', 'recordedBy']]
    current_taxon_df.columns = ['BasisOfRec', 'Binomial', 'CatalogNo', 'CollectID', 'Dec_Lat', 'Dec_Long', 'Dist_comm', 'Event_Year', 'recordedBy']
    current_taxon_df.insert(3,  "Citation",  "GBIF")
    current_taxon_df.insert(5,  "Compiler",  "Manuel Vargas")
    current_taxon_df.insert(6,  "Data_sens", "")    
    current_taxon_df.insert(11, "Origin", 1)    
    current_taxon_df.insert(12, "Presence", 1)
    current_taxon_df.insert(13, "Seasonal", 1)        
    current_taxon_df.insert(14, "Sens_comm", "")
    current_taxon_df.insert(15, "SpatialRef", "WGS84")
    current_taxon_df.insert(16, "YrCompiled", 2019)    
    current_taxon_df.to_csv(OUTPUT_DIR + family_gbif.upper() + "_" + species_input.replace(" ", "_") + "-registros_presencia.csv")
    
# ==================== CIERRE DE LOS ARCHIVOS DE SALIDA ====================

# Archivo CSV
results_csv.close()

# Archivo HTML
results_html.write("</tbody></table></body></html>")
results_html.close()
